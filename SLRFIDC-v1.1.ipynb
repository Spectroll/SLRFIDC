# %%
"""
Versão 1.1:
Melhoria no sistema de extração dos PDFs, sem usar LlamaParser, apenas bibliotecas de PDF. Também inclusa extração de tabelas
Modelo de Embedding atualizado para text-embedding-3-small
Divisão dos chunks ainda realizada em modelo de blocos de tamanho fixo
Com ajuda do GPT, tentamos implementar um esquema de busca inteligente dos documentos, citando nome específico e retornando contexto.
Número de resultados retornados com as queries foi aumentado 3->20 
"""

# %% [markdown]
# # Preparação dos Documentos

# %%
import pdfplumber
#import pytesseract
#import pdf2image
import pandas as pd
import tiktoken
import chromadb
import openai
import json
import os
import re
from openai import OpenAI
from langchain_openai import OpenAIEmbeddings

# %%
CHUNK_SIZE = 1000
OFFSET = 200

tokenizer = tiktoken.get_encoding("cl100k_base")
openai_client = OpenAI(api_key= os.environ["OPENAI_API_KEY"])

# Conexão com o cliente do banco de dados ChromaDB
chromadb_path = "G:/Drives compartilhados/RISCO E COMPLIANCE/Relatórios de Risco/Risco/FIDCS/SCRIPTS_RISCO/Projeto IA/Base ChromaDB/"
chroma_client = chromadb.PersistentClient(path= chromadb_path)
collection    = chroma_client.get_or_create_collection(name= "Regulamentos_V1.1")

# %%
# Checa todo o conteúdo inserido no ChromaDB
collection.get()
# Out:
# {'ids': ['CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_0',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_1',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_2',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_3',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_4',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_5',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_6',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_7',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_8',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_9',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_10',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_11',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_12',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_13',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_14',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_15',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_16',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_17',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_18',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_19',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_20',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_21',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_22',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_23',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_24',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_25',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_26',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_27',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_28',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_29',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_30',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_31',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_32',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_33',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_34',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_35',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_36',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_37',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_38',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_39',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_40',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_41',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_42',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_43',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_44',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_45',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_46',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_47',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_48',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_49',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_50',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_51',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_52',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_53',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_54',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_55',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_56',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_57',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_58',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_59',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_60',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_61',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_62',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_63',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_64',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_65',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_66',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_67',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_68',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_69',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_70',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_71',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_72',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_73',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_74',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_75',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_76',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_77',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_78',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_79',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_80',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_81',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_82',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_83',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_84',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_85',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_86',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_87',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_88',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_89',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_90',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_91',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_92',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_93',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_94',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_95',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_96',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_97',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_98',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_99',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_100',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_101',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_102',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_103',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_104',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_105',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_106',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_107',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_108',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_109',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_110',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_111',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_112',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_113',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_114',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_115',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_116',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_117',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_118',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_119',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_120',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_121',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_122',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_123',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_124',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_125',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_126',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_127',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_128',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_129',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_130',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_131',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_132',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_133',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_134',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_135',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_136',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_137',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_138',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_139',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_140',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_141',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_142',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_143',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_144',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_145',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_146',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_147',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_148',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_149',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_150',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_151',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_152',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_153',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_154',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_155',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_156',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_157',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_158',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_159',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_160',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_161',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_162',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_163',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_164',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_165',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_166',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_167',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_168',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_169',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_170',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_171',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_172',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_173',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_174',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_175',
#   'Regulamento Concrédito II.pdf_chunk_0',
#   'Regulamento Concrédito II.pdf_chunk_1',
#   'Regulamento Concrédito II.pdf_chunk_2',
#   'Regulamento Concrédito II.pdf_chunk_3',
#   'Regulamento Concrédito II.pdf_chunk_4',
#   'Regulamento Concrédito II.pdf_chunk_5',
#   'Regulamento Concrédito II.pdf_chunk_6',
#   'Regulamento Concrédito II.pdf_chunk_7',
#   'Regulamento Concrédito II.pdf_chunk_8',
#   'Regulamento Concrédito II.pdf_chunk_9',
#   'Regulamento Concrédito II.pdf_chunk_10',
#   'Regulamento Concrédito II.pdf_chunk_11',
#   'Regulamento Concrédito II.pdf_chunk_12',
#   'Regulamento Concrédito II.pdf_chunk_13',
#   'Regulamento Concrédito II.pdf_chunk_14',
#   'Regulamento Concrédito II.pdf_chunk_15',
#   'Regulamento Concrédito II.pdf_chunk_16',
#   'Regulamento Concrédito II.pdf_chunk_17',
#   'Regulamento Concrédito II.pdf_chunk_18',
#   'Regulamento Concrédito II.pdf_chunk_19',
#   'Regulamento Concrédito II.pdf_chunk_20',
#   'Regulamento Concrédito II.pdf_chunk_21',
#   'Regulamento Concrédito II.pdf_chunk_22',
#   'Regulamento Concrédito II.pdf_chunk_23',
#   'Regulamento Concrédito II.pdf_chunk_24',
#   'Regulamento Concrédito II.pdf_chunk_25',
#   'Regulamento Concrédito II.pdf_chunk_26',
#   'Regulamento Concrédito II.pdf_chunk_27',
#   'Regulamento Concrédito II.pdf_chunk_28',
#   'Regulamento Concrédito II.pdf_chunk_29',
#   'Regulamento Concrédito II.pdf_chunk_30',
#   'Regulamento Concrédito II.pdf_chunk_31',
#   'Regulamento Concrédito II.pdf_chunk_32',
#   'Regulamento Concrédito II.pdf_chunk_33',
#   'Regulamento Concrédito II.pdf_chunk_34',
#   'Regulamento Concrédito II.pdf_chunk_35',
#   'Regulamento Concrédito II.pdf_chunk_36',
#   'Regulamento Concrédito II.pdf_chunk_37',
#   'Regulamento Concrédito II.pdf_chunk_38',
#   'Regulamento Concrédito II.pdf_chunk_39',
#   'Regulamento Concrédito II.pdf_chunk_40',
#   'Regulamento Concrédito II.pdf_chunk_41',
#   'Regulamento Concrédito II.pdf_chunk_42',
#   'Regulamento Concrédito II.pdf_chunk_43',
#   'Regulamento Concrédito II.pdf_chunk_44',
#   'Regulamento Concrédito II.pdf_chunk_45',
#   'Regulamento Concrédito II.pdf_chunk_46',
#   'Regulamento Concrédito II.pdf_chunk_47',
#   'Regulamento Concrédito II.pdf_chunk_48',
#   'Regulamento Concrédito II.pdf_chunk_49',
#   'Regulamento Concrédito II.pdf_chunk_50',
#   'Regulamento Concrédito II.pdf_chunk_51',
#   'Regulamento Concrédito II.pdf_chunk_52',
#   'Regulamento Concrédito II.pdf_chunk_53',
#   'Regulamento Concrédito II.pdf_chunk_54',
#   'Regulamento Concrédito II.pdf_chunk_55',
#   'Regulamento Concrédito II.pdf_chunk_56',
#   'Regulamento Concrédito II.pdf_chunk_57',
#   'Regulamento Concrédito II.pdf_chunk_58',
#   'Regulamento Concrédito II.pdf_chunk_59',
#   'Regulamento Concrédito II.pdf_chunk_60',
#   'Regulamento Concrédito II.pdf_chunk_61',
#   'Regulamento Concrédito II.pdf_chunk_62',
#   'Regulamento Concrédito II.pdf_chunk_63',
#   'Regulamento Concrédito II.pdf_chunk_64',
#   'Regulamento Concrédito II.pdf_chunk_182',
#   'Regulamento Concrédito II.pdf_chunk_183',
#   'Regulamento Concrédito II.pdf_chunk_184',
#   'Regulamento Concrédito II.pdf_chunk_185',
#   'Regulamento Concrédito II.pdf_chunk_186',
#   'Regulamento Concrédito II.pdf_chunk_187',
#   'Regulamento Concrédito II.pdf_chunk_188',
#   'Regulamento Concrédito II.pdf_chunk_189',
#   'Regulamento Concrédito II.pdf_chunk_190',
#   'Regulamento Concrédito II.pdf_chunk_191',
#   'Regulamento Concrédito II.pdf_chunk_192',
#   'Regulamento Concrédito II.pdf_chunk_193',
#   'Regulamento Concrédito II.pdf_chunk_194',
#   'Regulamento Concrédito II.pdf_chunk_195',
#   'Regulamento Concrédito II.pdf_chunk_196',
#   'Regulamento Concrédito II.pdf_chunk_197',
#   'Regulamento Concrédito II.pdf_chunk_198',
#   'Regulamento Concrédito II.pdf_chunk_199',
#   'Regulamento Concrédito II.pdf_chunk_200',
#   'Regulamento Concrédito II.pdf_chunk_201',
#   'Regulamento Concrédito II.pdf_chunk_202',
#   'Regulamento Concrédito II.pdf_chunk_203',
#   'Regulamento Poupacred II.pdf_chunk_0',
#   'Regulamento Poupacred II.pdf_chunk_1',
#   'Regulamento Poupacred II.pdf_chunk_2',
#   'Regulamento Poupacred II.pdf_chunk_3',
#   'Regulamento Poupacred II.pdf_chunk_4',
#   'Regulamento Poupacred II.pdf_chunk_5',
#   'Regulamento Poupacred II.pdf_chunk_6',
#   'Regulamento Poupacred II.pdf_chunk_7',
#   'Regulamento Poupacred II.pdf_chunk_8',
#   'Regulamento Poupacred II.pdf_chunk_9',
#   'Regulamento Poupacred II.pdf_chunk_10',
#   'Regulamento Poupacred II.pdf_chunk_11',
#   'Regulamento Poupacred II.pdf_chunk_12',
#   'Regulamento Poupacred II.pdf_chunk_13',
#   'Regulamento Poupacred II.pdf_chunk_14',
#   'Regulamento Poupacred II.pdf_chunk_15',
#   'Regulamento Poupacred II.pdf_chunk_16',
#   'Regulamento Poupacred II.pdf_chunk_17',
#   'Regulamento Poupacred II.pdf_chunk_18',
#   'Regulamento Poupacred II.pdf_chunk_19',
#   'Regulamento Poupacred II.pdf_chunk_20',
#   'Regulamento Poupacred II.pdf_chunk_21',
#   'Regulamento Poupacred II.pdf_chunk_22',
#   'Regulamento Poupacred II.pdf_chunk_23',
#   'Regulamento Poupacred II.pdf_chunk_24',
#   'Regulamento Poupacred II.pdf_chunk_25',
#   'Regulamento Poupacred II.pdf_chunk_26',
#   'Regulamento Poupacred II.pdf_chunk_27',
#   'Regulamento Poupacred II.pdf_chunk_28',
#   'Regulamento Poupacred II.pdf_chunk_29',
#   'Regulamento Poupacred II.pdf_chunk_30',
#   'Regulamento Poupacred II.pdf_chunk_31',
#   'Regulamento Poupacred II.pdf_chunk_32',
#   'Regulamento Poupacred II.pdf_chunk_33',
#   'Regulamento Poupacred II.pdf_chunk_34',
#   'Regulamento Poupacred II.pdf_chunk_35',
#   'Regulamento Poupacred II.pdf_chunk_36',
#   'Regulamento Poupacred II.pdf_chunk_37',
#   'Regulamento Poupacred II.pdf_chunk_38',
#   'Regulamento Poupacred II.pdf_chunk_39',
#   'Regulamento Poupacred II.pdf_chunk_40',
#   'Regulamento Poupacred II.pdf_chunk_41',
#   'Regulamento Poupacred II.pdf_chunk_42',
#   'Regulamento Poupacred II.pdf_chunk_43',
#   'Regulamento Poupacred II.pdf_chunk_44',
#   'Regulamento Poupacred II.pdf_chunk_45',
#   'Regulamento Poupacred II.pdf_chunk_46',
#   'Regulamento Poupacred II.pdf_chunk_47',
#   'Regulamento Poupacred II.pdf_chunk_48',
#   'Regulamento Poupacred II.pdf_chunk_49',
#   'Regulamento Poupacred II.pdf_chunk_50',
#   'Regulamento Poupacred II.pdf_chunk_51',
#   'Regulamento Poupacred II.pdf_chunk_52',
#   'Regulamento Poupacred II.pdf_chunk_53',
#   'Regulamento Poupacred II.pdf_chunk_54',
#   'Regulamento Poupacred II.pdf_chunk_55',
#   'Regulamento Poupacred II.pdf_chunk_56',
#   'Regulamento Poupacred II.pdf_chunk_57',
#   'Regulamento Poupacred II.pdf_chunk_58',
#   'Regulamento Poupacred II.pdf_chunk_59',
#   'Regulamento Poupacred II.pdf_chunk_60',
#   'Regulamento Poupacred II.pdf_chunk_61',
#   'Regulamento Poupacred II.pdf_chunk_62',
#   'Regulamento Poupacred II.pdf_chunk_63',
#   'Regulamento Poupacred II.pdf_chunk_64',
#   'Regulamento Poupacred II.pdf_chunk_65',
#   'Regulamento Poupacred II.pdf_chunk_66',
#   'Regulamento Poupacred II.pdf_chunk_67',
#   'Regulamento Poupacred II.pdf_chunk_68',
#   'Regulamento Poupacred II.pdf_chunk_69',
#   'Regulamento Poupacred II.pdf_chunk_70',
#   'Regulamento Poupacred II.pdf_chunk_71',
#   'Regulamento Poupacred II.pdf_chunk_72',
#   'Regulamento Poupacred II.pdf_chunk_73',
#   'Regulamento Poupacred II.pdf_chunk_74',
#   'Regulamento Poupacred II.pdf_chunk_75',
#   'Regulamento Poupacred II.pdf_chunk_76',
#   'Regulamento Poupacred II.pdf_chunk_77',
#   'Regulamento Poupacred II.pdf_chunk_78',
#   'Regulamento Poupacred II.pdf_chunk_79',
#   'Regulamento Poupacred II.pdf_chunk_80',
#   'Regulamento Poupacred II.pdf_chunk_81',
#   'Regulamento Poupacred II.pdf_chunk_82',
#   'Regulamento Poupacred II.pdf_chunk_83',
#   'Regulamento Poupacred II.pdf_chunk_84',
#   'Regulamento Poupacred II.pdf_chunk_85',
#   'Regulamento Poupacred II.pdf_chunk_86',
#   'Regulamento Poupacred II.pdf_chunk_87',
#   'Regulamento Poupacred II.pdf_chunk_88',
#   'Regulamento Poupacred II.pdf_chunk_89',
#   'Regulamento Poupacred II.pdf_chunk_90',
#   'Regulamento Poupacred II.pdf_chunk_91',
#   'Regulamento Poupacred II.pdf_chunk_92',
#   'Regulamento Poupacred II.pdf_chunk_93',
#   'Regulamento Poupacred II.pdf_chunk_94',
#   'Regulamento Poupacred II.pdf_chunk_95',
#   'Regulamento Poupacred II.pdf_chunk_96',
#   'Regulamento Poupacred II.pdf_chunk_97',
#   'Regulamento Poupacred II.pdf_chunk_98',
#   'Regulamento Poupacred II.pdf_chunk_99',
#   'Regulamento Poupacred II.pdf_chunk_100',
#   'Regulamento Poupacred II.pdf_chunk_101',
#   'Regulamento Poupacred II.pdf_chunk_102',
#   'Regulamento Poupacred II.pdf_chunk_103',
#   'Regulamento Poupacred II.pdf_chunk_104',
#   'Regulamento Poupacred II.pdf_chunk_105',
#   'Regulamento Poupacred II.pdf_chunk_106',
#   'Regulamento Poupacred II.pdf_chunk_107',
#   'Regulamento Poupacred II.pdf_chunk_108',
#   'Regulamento Poupacred II.pdf_chunk_109',
#   'Regulamento Poupacred II.pdf_chunk_110',
#   'Regulamento Poupacred II.pdf_chunk_111',
#   'Regulamento Poupacred II.pdf_chunk_112',
#   'Regulamento Poupacred II.pdf_chunk_113',
#   'Regulamento Poupacred II.pdf_chunk_114',
#   'Regulamento Poupacred II.pdf_chunk_115',
#   'Regulamento Poupacred II.pdf_chunk_116',
#   'Regulamento Poupacred II.pdf_chunk_117',
#   'Regulamento Poupacred II.pdf_chunk_118',
#   'Regulamento Poupacred II.pdf_chunk_119',
#   'Regulamento Poupacred II.pdf_chunk_120',
#   'Regulamento Poupacred II.pdf_chunk_121',
#   'Regulamento Poupacred II.pdf_chunk_122',
#   'Regulamento Poupacred II.pdf_chunk_123',
#   'Regulamento Poupacred II.pdf_chunk_124',
#   'Regulamento Poupacred II.pdf_chunk_125',
#   'Regulamento Poupacred II.pdf_chunk_126',
#   'Regulamento Poupacred II.pdf_chunk_127',
#   'Regulamento Poupacred II.pdf_chunk_128',
#   'Regulamento Poupacred II.pdf_chunk_129',
#   'Regulamento Poupacred II.pdf_chunk_130',
#   'Regulamento Poupacred II.pdf_chunk_131',
#   'Regulamento Poupacred II.pdf_chunk_132',
#   'Regulamento Poupacred II.pdf_chunk_133',
#   'Regulamento Poupacred II.pdf_chunk_134',
#   'Regulamento Poupacred II.pdf_chunk_135',
#   'Regulamento Poupacred II.pdf_chunk_136',
#   'Regulamento Poupacred II.pdf_chunk_137',
#   'Regulamento Poupacred II.pdf_chunk_138',
#   'Regulamento Poupacred II.pdf_chunk_139',
#   'Regulamento Poupacred II.pdf_chunk_140',
#   'Regulamento Poupacred II.pdf_chunk_141',
#   'Regulamento Poupacred II.pdf_chunk_142',
#   'Regulamento Poupacred II.pdf_chunk_143',
#   'Regulamento Poupacred II.pdf_chunk_144',
#   'Regulamento Poupacred II.pdf_chunk_145',
#   'Regulamento Poupacred II.pdf_chunk_146',
#   'Regulamento Poupacred II.pdf_chunk_147',
#   'Regulamento Poupacred II.pdf_chunk_148',
#   'Regulamento Poupacred II.pdf_chunk_149',
#   'Regulamento Poupacred II.pdf_chunk_150',
#   'Regulamento Poupacred II.pdf_chunk_151',
#   'Regulamento Poupacred II.pdf_chunk_152',
#   'Regulamento Poupacred II.pdf_chunk_153',
#   'Regulamento Poupacred II.pdf_chunk_154',
#   'Regulamento Poupacred II.pdf_chunk_155',
#   'Regulamento Poupacred II.pdf_chunk_156',
#   'Regulamento Poupacred II.pdf_chunk_157',
#   'Regulamento Poupacred II.pdf_chunk_158',
#   'Regulamento Poupacred II.pdf_chunk_159',
#   'Regulamento Poupacred II.pdf_chunk_160',
#   'Regulamento Poupacred II.pdf_chunk_161',
#   'Regulamento Poupacred II.pdf_chunk_162',
#   'Regulamento Poupacred II.pdf_chunk_163',
#   'Regulamento Poupacred II.pdf_chunk_164',
#   'Regulamento Poupacred II.pdf_chunk_165',
#   'Regulamento Poupacred II.pdf_chunk_166',
#   'Regulamento Poupacred II.pdf_chunk_167',
#   'Regulamento Poupacred II.pdf_chunk_168',
#   'Regulamento Poupacred II.pdf_chunk_169',
#   'Regulamento Poupacred II.pdf_chunk_170',
#   'Regulamento Poupacred II.pdf_chunk_171',
#   'Regulamento Poupacred II.pdf_chunk_172',
#   'Regulamento Poupacred II.pdf_chunk_173',
#   'Regulamento Poupacred II.pdf_chunk_174',
#   'Regulamento Poupacred II.pdf_chunk_175',
#   'Regulamento Poupacred II.pdf_chunk_176',
#   'Regulamento Poupacred II.pdf_chunk_177',
#   'Regulamento Poupacred II.pdf_chunk_178',
#   'Regulamento Poupacred II.pdf_chunk_179',
#   'Regulamento Poupacred II.pdf_chunk_180',
#   'Regulamento Poupacred II.pdf_chunk_181',
#   'Regulamento Poupacred II.pdf_chunk_182',
#   'Regulamento Poupacred II.pdf_chunk_183',
#   'Regulamento Poupacred II.pdf_chunk_184',
#   'Regulamento Poupacred II.pdf_chunk_185',
#   'Regulamento Poupacred II.pdf_chunk_186',
#   'Regulamento Poupacred II.pdf_chunk_187',
#   'Regulamento Poupacred II.pdf_chunk_188',
#   'Regulamento Poupacred II.pdf_chunk_189',
#   'Regulamento Poupacred II.pdf_chunk_190',
#   'Regulamento Poupacred II.pdf_chunk_191',
#   'Regulamento Poupacred II.pdf_chunk_192',
#   'Regulamento Poupacred II.pdf_chunk_193',
#   'Regulamento Poupacred II.pdf_chunk_194',
#   'Regulamento Poupacred II.pdf_chunk_195',
#   'Regulamento Poupacred II.pdf_chunk_196',
#   'Regulamento Poupacred II.pdf_chunk_197',
#   'Regulamento Poupacred II.pdf_chunk_198',
#   'Regulamento Poupacred II.pdf_chunk_199',
#   'Regulamento Poupacred II.pdf_chunk_200',
#   'Regulamento Poupacred II.pdf_chunk_201',
#   'Regulamento Poupacred II.pdf_chunk_202',
#   'Regulamento Poupacred II.pdf_chunk_203',
#   'Regulamento Poupacred II.pdf_chunk_204',
#   'Regulamento Poupacred II.pdf_chunk_205',
#   'Regulamento Poupacred II.pdf_chunk_206',
#   'Regulamento Poupacred II.pdf_chunk_207',
#   'Regulamento Poupacred II.pdf_chunk_208',
#   'Regulamento Poupacred II.pdf_chunk_209'],
#  'embeddings': None,
#  'documents': ['Docusign Envelope ID: 2E621B1E-0D2F-4755-9F17-8D79AC1DF7C1\nREGULAMENTO DO\nCONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS\nCREDITÓRIOS RESPONSABILIDADE LIMITADA\nCNPJ/MF em constituição\nPágina 4 de 49\nDocusign Envelope ID: 2E621B1E-0D2F-4755-9F17-8D79AC1DF7C1\nDEFINIÇÕES\nPara fins do disposto neste Regulamento, os termos e expressões indicados em letra maiúscula neste\nRegulamento, no singular ou no plural, terão os respectivos significados a eles atribuídos a seguir:\n“Agência de Classificação de Agência de classificação de risco que pode ser contratada pela\nRisco” Gestora, em nome do Fundo, para realizar a avaliação de risco\ndas Cotas, nos termos dispostos neste Regulamento;\n“Agente de Cobrança” CONCRETA CONSULTORIA E GESTÃO DE NEGÓCIOS\nLTDA., pessoa jurídica de direito privado, com sede na Cidade\nde Belo Horizonte, Estado de Minas Gerais, à Avenida Raja\nGabaglia nº 2.000, Pavimento 4, Bloco 1, Sala 417, Bairro\nAlpes, CEP 30494-170, inscrita no CNPJ/MF sob o nº\n43.468.812/0001-79\n“A',
#   'e na Cidade\nde Belo Horizonte, Estado de Minas Gerais, à Avenida Raja\nGabaglia nº 2.000, Pavimento 4, Bloco 1, Sala 417, Bairro\nAlpes, CEP 30494-170, inscrita no CNPJ/MF sob o nº\n43.468.812/0001-79\n“Anexo da Classe” São os Anexos da respectiva Classe Única deste\nRegulamento, dos quais constam as regras específicas\naplicáveis à cada Classe e respectivas Subclasses;\n“Administradora”: ID CORRETORA DE TÍTULOS E VALORES MOBILIÁRIOS\nS.A., com sede na Cidade de São Paulo, Estado de São Paulo,\nna Avenida Presidente Juscelino Kubitschek nº 1726, conjunto\n194, 19º andar, inscrita no CNPJ/MF sob nº 16.695.922/0001-\n09, devidamente autorizada pela CVM a prestar os serviços de\ntesouraria e escrituração de cotas, por meio do Ato\nDeclaratório nº 19.047, de 31 de agosto de 2021;\n“Assembleia de Cotistas”: Assembleia de Cotistas do Fundo;\n“Ativos” São todos os ativos da Carteira, considerando-se, para tanto,\nos Direitos Creditórios, os Fundos Investidos, os Ativos\nLíquidos e os Outros Ativos;\n“Ativos Lí',
#   'quidos” São os ativos para gestão de liquidez que podem ser\ncomprados pela Gestora;\n“Auditoria Independente”: Empresa de auditoria independente devidamente contratada\npela Administradora;\n“Boletim de Subscrição”: O Boletim de Subscrição assinado por cada investidor para\naquisição das Cotas emitidas pelo Fundo;\nPágina 5 de 49\nDocusign Envelope ID: 2E621B1E-0D2F-4755-9F17-8D79AC1DF7C1\n“B3 – CETIP”: A B3 – Segmento CETIP UTVM;\n“Carteira”: A carteira de investimentos, formada por todos os Ativos da\nClasse;\n“CDI”: Certificado de Depósitos Interbancário;\n“Chamada(s) de Capital”: Chamadas de capital para aporte de recursos mediante\nintegralização de Cotas, nos termos deste Regulamento e seu\nAnexo;\n“CMN” O Conselho Monetário Nacional;\n“Código ANBIMA”: O Código ANBIMA de Administração de Recursos de\nTerceiros;\n“Consultoria Especializada”: CONCRETA CONSULTORIA E GESTÃO DE NEGÓCIOS\nLTDA., pessoa jurídica de direito privado, com sede na Cidade\nde Belo Horizonte, Estado de Minas Gerais, à Avenida R',
ID: 2E621B1E-0D2F-4755-9F17-8D79AC1DF7C1\n“IGP-M” Índice Geral de Preços do Mercado, divulgado pela Fundação\nGetúlio Vargas, ou outro índice que venha a substituí-lo;\n“Índice de Subordinação” Em conjunto ou isoladamente, o Índice de Subordinação\nJúnior, o Índice de Subordinação Mezanino e o Índice de\nSubordinação Subordinadas, conforme aplicável;\n“Patrimônio Líquido”: Soma algébrica de disponível do Fundo com o valor da\nCarteira, mais os valores a receber, menos as suas\nexigibilidades;\n“Plano de Liquidação” Plano a ser elaborado para fins de liquidação da Classe;\n“Prazo de Duração”: Tem o significado do Artigo 3º deste Regulamento;\n“Regulamento”: O presente regulamento do Fundo e seu Anexo;\n“Remuneração Alvo”: Conforme descrito em cada Suplemento;\n“Resolução CMN nº 2.907” Resolução CMN nº 2.907, de 29 de novembro de 2001,\nconforme alterada;\n“Resolução CVM 30”: Resolução CVM nº 30, de 11 de maio de 2021;\n“Resolução CVM nº 160”: Resolução da CVM nº 160, de 13 de julho de 2022, conforme',
#   '\nalterada;\n“Resolução CVM nº 175” Resolução CVM nº 175, de 23 de dezembro de 2022, conforme\nalterada;\n“Taxa de Administração”: Taxa devida à Administradora, conforme prevista neste\nRegulamento e seu Anexo;\n“Taxa de Gestão”: Taxa devida à Gestora, conforme prevista neste Regulamento\ne seu Anexo;\n“Termos de Cessão” Termos celebrados entre o Fundo e/ou a Classe e a respectiva\nCedente, com interveniência da Gestora e da Administradora,\nconforme modelo anexo aos Contratos de Cessão, por meio\ndos quais a respectiva Cedente cede Direitos Creditórios ao\nFundo e/ou a Classe;\n“Termos de Endosso” Termos celebrados entre o Fundo e/ou a Classe e o respectivo\nPágina 8 de 49\nDocusign Envelope ID: 2E621B1E-0D2F-4755-9F17-8D79AC1DF7C1\nendossante, com interveniência da Gestora e da\nAdministradora, conforme modelo anexo aos Contratos de\nEndosso, por meio dos quais o respectivo Endossante\nendossa Direitos Creditórios ao Fundo e/ou a Classe;\n“Suplemento” Suplemento das Subclasses do Fundo.\nPágina 9 de 49\nD',
#   'ocusign Envelope ID: 2E621B1E-0D2F-4755-9F17-8D79AC1DF7C1\nREGULAMENTO DO CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS\nCREDITÓRIOS RESPONSABILIDADE LIMITADA\nCNPJ/MF em constituição\nO CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS\nRESPONSABILIDADE LIMITADA, é uma comunhão de recursos, constituído sob a forma de\ncondomínio de natureza especial, regido pelo presente Regulamento, seu Anexo e, ainda, pelas\ndisposições legais e normativas que lhe forem aplicáveis, em especial a Resolução CMN 2.907, a\nResolução CVM nº 175 e seu Anexo Normativo II e o Código ANBIMA.\nOs termos definidos e expressões adotadas com iniciais em letras maiúsculas no presente\nRegulamento, e em seus anexos, terão o significado a eles atribuídos no Anexo I a este\nRegulamento, aplicável tanto no singular quanto no plural e o masculino incluirá o feminino e vice\nversa. Adicionalmente, (i) as referências a “Fundo” ou a “Fundo de Investimento” alcançam todas as\nsuas classes de cotas; (ii) as refe',

#  'included': [<IncludeEnum.documents: 'documents'>,
#   <IncludeEnum.metadatas: 'metadatas'>]}

# %%
def count_tokens(text):
    return len(tokenizer.encode(text))

def split_document(document_text):
    documents = []
    for i in range(0, len(document_text), CHUNK_SIZE):
        start = i
        end = i + CHUNK_SIZE
        if start != 0:
            start = start - OFFSET
            end =  end - OFFSET
        documents.append(document_text[start: end])
    return documents

# Obtenção dos embeddings usando Langchain
def get_embedding_langchain(text):

    embedding = OpenAIEmbeddings(
        model= "text-embedding-3-small",
        chunk_size= CHUNK_SIZE
    )

    emb = embedding.embed_query(text)

    return emb

# Obtenção dos embeddings usando diretamente a API da OpenAI
def get_embedding_openai(text, client):

    emb = client.embeddings.create(
        input= text,
        model= "text-embedding-3-small"
    )

    return emb.data[0].embedding

# Extração de texto dos arquivos PDF
def extract_text_from_pdf(pdf_path):
    full_text = []

    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            full_text.append(page.extract_text() or "")

    return "\n".join(full_text)

# Extração das tabelas dos arquivos PDF
# Tabelas serão extraídas diferentemente dos blocos de texto
def extract_tables_from_pdf(pdf_path):
    data_list = []

    with pdfplumber.open(pdf_path) as pdf:
        for page_num, page in enumerate(pdf.pages):
            tables = page.extract_tables()
            for table in tables:
                df = pd.DataFrame(table[1:], columns=table[0])  # Usa a primeira linha como cabeçalho
                data_list.append(df)

    return data_list

# Guarda os dados extraidos dos documentos no ChromaDB
def insert_chromadb(data, source, client):

    chunks = split_document(data)

    print(chunks)

    for idx, chunk in enumerate(chunks):

        embedding = get_embedding_openai(chunk, client)

        collection.add(
            ids=[f"{source}_chunk_{idx}"],
            documents=[chunk],
            metadatas=[{"source": source, "chunk_index": idx}],
            embeddings=[embedding]
        )

# %%
def run():
    print("Preparando Documentos...")
    data_path = 'G:/Drives compartilhados/GESTAO/_Operacional/Planilhas Gestão/Scripts/temp/temp_regulamentos/Teste 1.1'

    documents_names = [f for f in os.listdir(data_path) if f.endswith('.pdf')]
    documents_names_size = len(documents_names)

    for i, document_name in enumerate(documents_names):

        print(f"{i+1}/{documents_names_size}: {document_name}")

        doc_path = os.path.join(data_path, document_name)

        document_text = extract_text_from_pdf(os.path.join(data_path, document_name))
        if document_text.strip():
            insert_chromadb(document_text, document_name, openai_client)

        tables = extract_tables_from_pdf(doc_path)
        if tables:
            for idx, df in enumerate(tables):
                json_data = df.to_json(orient= "records")
                insert_chromadb(json_data, document_name, openai_client)

if __name__ == "__main__":
    run()
    pass
# Out:
# Preparando Documentos...
# 1/1: Regulamento Poupacred II.pdf
# ['REGULAMENTO DO\nFUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS POUPACRED II RESPONSABILIDADE\nLIMITADA\nCNPJ/MF Nº 57.377.181/0001-97\nVigente a partir de 24 janeiro de 2025\nSUMÁRIO\nPARTE GERAL ................................................................................................................................ 4\nCAPÍTULO I – DO FUNDO .......................................................................................................... 4\nCAPÍTULO II – DAS DEFINIÇÕES ................................................................................................ 4\nCAPÍTULO III - DO OBJETIVO DO FUNDO E DAS CLASSES DE COTAS ....................................... 8\nCAPÍTULO IV – DOS PRESTADORES DE SERVIÇOS ESSENCIAIS DO FUNDO ............................. 8\nCAPÍTULO V – DOS DEMAIS PRESTADORES DE SERVIÇOS .................................................... 13\nDO FUNDO .................................................................................................................', 'ESTADORES DE SERVIÇOS .................................................... 13\nDO FUNDO .............................................................................................................................. 13\nCAPÍTULO VI – DAS RESPONSABILIDADES DOS PRESTADORES DE SERVIÇO ........................ 13\nCAPÍTULO VII – DA SUBSTITUIÇÃO DOS PRESTADORES DE SERVIÇOS ESSENCIAIS .............. 14\nCAPÍTULO VIII - DA ASSEMBLEIA GERAL DE COTISTAS .......................................................... 14\nCAPÍTULO IX – DOS ENCARGOS DO FUNDO .......................................................................... 18\nCAPÍTULO X – DAS INFORMAÇÕES ........................................................................................ 19\nCAPÍTULO XI – DA DIVULGAÇÃO DE INFORMAÇÕES ............................................................. 22\nCAPÍTULO XII – DAS DEMONSTRAÇÕES CONTÁBEIS E RELATÓRIOS DE AUDITORIA ........... 23\nCAPÍTULO XIII – DA LIQUIDAÇÃO DO FUNDO ............................', '............................................ 23\nCAPÍTULO XIV – DO FORO ...................................................................................................... 23\nANEXO I ....................................................................................................................................... 24\nCARACTERÍSTICAS DA ÚNICA CLASSE ........................................................................................ 24\nI – DO PÚBLICO-ALVO E DA RESPONSABILIDADE DOS COTISTAS ......................................... 24\nII – DO REGIME DA CLASSE ..................................................................................................... 24\nIII – DO PRAZO DE DURAÇÃO ................................................................................................. 24\nIV – DAS DEFINIÇÕES .............................................................................................................. 24\nV – DA POLÍTICA DE INVESTIMENTOS ............................', '........................................................ 27\nVI – DAS CONDIÇÕES DE ENDOSSO E DOS CRITÉRIOS DE ELEGIBILIDADE ............................ 30\nCAPÍTULO VII – DOS PRESTADORES DE SERVIÇOS ESPECÍFICOS DA CLASSE ........................ 30\nVIII – DA NATUREZA, DOS PROCESSOS DE ORIGINAÇÃO DOS DIREITOS CREDITÓRIOS E DA\nPOLÍTICA DE CONCESSÃO DE CRÉDITO .................................................................................. 31\nIX – DA POLÍTICA DE COBRANÇA DOS DIREITOS CREDITÓRIOS ELEGÍVEIS E DOS DIREITOS\nCREDITÓRIOS INADIMPLIDOS ................................................................................................ 31\nX – DA VERIFICAÇÃO DE LASTRO ........................................................................................... 33\nXI – DAS TAXAS ....................................................................................................................... 34\nXII – DAS SUBORDINAÇÕES MÍNIMAS ..... ...
# ['[{"Patrim\\u00f4nio L\\u00edquido":"De R$ 0 a R$ 250.000.000,00","Taxa (a.a.)":"0,13%"},{"Patrim\\u00f4nio L\\u00edquido":"De R$ 250.000.000,01 a R$ 500.000.000,00","Taxa (a.a.)":"0,11%"},{"Patrim\\u00f4nio L\\u00edquido":"De R$ 500.000.000,01 a R$ 750.000.000,00","Taxa (a.a.)":"0,09%"},{"Patrim\\u00f4nio L\\u00edquido":"R$ 750.000.000,01 a R$ 1.000.000.000,00","Taxa (a.a.)":"0,07%"},{"Patrim\\u00f4nio L\\u00edquido":"Acima de R$ 1.000.000.000,01","Taxa (a.a.)":"0,05%"}]']
# Insert of existing embedding ID: Regulamento Poupacred II.pdf_chunk_0
# Add of existing embedding ID: Regulamento Poupacred II.pdf_chunk_0

# %%
# Checa todo o conteúdo inserido no ChromaDB
collection.get()
# Out:
# {'ids': ['CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_0',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_1',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_2',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_3',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_4',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_5',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_6',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_7',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_8',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_9',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_10',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_11',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_12',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_13',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_14',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_15',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_16',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_17',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_18',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_19',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_20',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_21',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_22',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_23',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk_24',
#   'CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA.pdf_chunk
#   'Regulamento Poupacred II.pdf_chunk_6',
#   'Regulamento Poupacred II.pdf_chunk_7',
#   'Regulamento Poupacred II.pdf_chunk_8',
#   'Regulamento Poupacred II.pdf_chunk_9',
#   'Regulamento Poupacred II.pdf_chunk_10',
#   'Regulamento Poupacred II.pdf_chunk_11',
#   'Regulamento Poupacred II.pdf_chunk_12',
#   'Regulamento Poupacred II.pdf_chunk_13',
#   'Regulamento Poupacred II.pdf_chunk_14',
#   'Regulamento Poupacred II.pdf_chunk_15',
#   'Regulamento Poupacred II.pdf_chunk_16',
#   'Regulamento Poupacred II.pdf_chunk_17',
#   'Regulamento Poupacred II.pdf_chunk_18',
#   'Regulamento Poupacred II.pdf_chunk_19',
#   'Regulamento Poupacred II.pdf_chunk_20',
#   'Regulamento Poupacred II.pdf_chunk_21',
#   'Regulamento Poupacred II.pdf_chunk_22',
#   'Regulamento Poupacred II.pdf_chunk_23',
#   'Regulamento Poupacred II.pdf_chunk_24',
#   'Regulamento Poupacred II.pdf_chunk_25',
#   'Regulamento Poupacred II.pdf_chunk_26',
#   'Regulamento Poupacred II.pdf_chunk_27',
#   'Regulamento Poupacred II.pdf_chunk_28',
#   'Regulamento Poupacred II.pdf_chunk_29',
#   'Regulamento Poupacred II.pdf_chunk_30',
#   'Regulamento Poupacred II.pdf_chunk_31',
#   'Regulamento Poupacred II.pdf_chunk_32',
#   'Regulamento Poupacred II.pdf_chunk_33',
#   'Regulamento Poupacred II.pdf_chunk_34',
#   'Regulamento Poupacred II.pdf_chunk_35',
#   'Regulamento Poupacred II.pdf_chunk_36',
#   'Regulamento Poupacred II.pdf_chunk_37',
#   'Regulamento Poupacred II.pdf_chunk_38',
#   'Regulamento Poupacred II.pdf_chunk_39',
#   'Regulamento Poupacred II.pdf_chunk_40',
#   'Regulamento Poupacred II.pdf_chunk_41',
#   'Regulamento Poupacred II.pdf_chunk_42',
#   'Regulamento Poupacred II.pdf_chunk_43',
#   'Regulamento Poupacred II.pdf_chunk_44',
#   'Regulamento Poupacred II.pdf_chunk_45',
#   'Regulamento Poupacred II.pdf_chunk_46',
#   'Regulamento Poupacred II.pdf_chunk_47',
#   'Regulamento Poupacred II.pdf_chunk_48',
#   'Regulamento Poupacred II.pdf_chunk_49',
#   'Regulamento Poupacred II.pdf_chunk_50',
#   'Regulamento Poupacred II.pdf_chunk_51',
#   'Regulamento Poupacred II.pdf_chunk_52',
#   'Regulamento Poupacred II.pdf_chunk_53',
#   'Regulamento Poupacred II.pdf_chunk_54',
#   'Regulamento Poupacred II.pdf_chunk_55',
#   'Regulamento Poupacred II.pdf_chunk_56',
#   'Regulamento Poupacred II.pdf_chunk_57',
#   'Regulamento Poupacred II.pdf_chunk_58',
#   'Regulamento Poupacred II.pdf_chunk_59',
#   'Regulamento Poupacred II.pdf_chunk_60',
#   'Regulamento Poupacred II.pdf_chunk_61',
#   'Regulamento Poupacred II.pdf_chunk_62',
#   'Regulamento Poupacred II.pdf_chunk_63',
#   'Regulamento Poupacred II.pdf_chunk_64',
#   'Regulamento Poupacred II.pdf_chunk_65',
#   'Regulamento Poupacred II.pdf_chunk_66',
#   'Regulamento Poupacred II.pdf_chunk_67',
#   'Regulamento Poupacred II.pdf_chunk_68',
#   'Regulamento Poupacred II.pdf_chunk_69',
#   'Regulamento Poupacred II.pdf_chunk_70',
#   'Regulamento Poupacred II.pdf_chunk_71',
#   'Regulamento Poupacred II.pdf_chunk_72',
#   'Regulamento Poupacred II.pdf_chunk_73',
#   'Regulamento Poupacred II.pdf_chunk_74',
#   'Regulamento Poupacred II.pdf_chunk_75',
#   'Regulamento Poupacred II.pdf_chunk_76',
#   'Regulamento Poupacred II.pdf_chunk_77',
#   'Regulamento Poupacred II.pdf_chunk_78',
#   'Regulamento Poupacred II.pdf_chunk_79',
#   'Regulamento Poupacred II.pdf_chunk_80',
#   'Regulamento Poupacred II.pdf_chunk_81',
#   'Regulamento Poupacred II.pdf_chunk_82',
#   'Regulamento Poupacred II.pdf_chunk_83',
#   'Regulamento Poupacred II.pdf_chunk_84',
#   'Regulamento Poupacred II.pdf_chunk_85',
#   'Regulamento Poupacred II.pdf_chunk_86',
#   'Regulamento Poupacred II.pdf_chunk_87',
#   'Regulamento Poupacred II.pdf_chunk_88',
#   'Regulamento Poupacred II.pdf_chunk_89',
#   'Regulamento Poupacred II.pdf_chunk_90',
#   'Regulamento Poupacred II.pdf_chunk_91',
#   'Regulamento Poupacred II.pdf_chunk_92',
#   'Regulamento Poupacred II.pdf_chunk_93',
#   'Regulamento Poupacred II.pdf_chunk_94',
#   'Regulamento Poupacred II.pdf_chunk_95',
#   'Regulamento Poupacred II.pdf_chunk_96',
#   'Regulamento Poupacred II.pdf_chunk_97',
#   'Regulamento Poupacred II.pdf_chunk_98',
#   'Regulamento Poupacred II.pdf_chunk_99',
#   'Regulamento Poupacred II.pdf_chunk_100',
#   'Regulamento Poupacred II.pdf_chunk_101',
#   'Regulamento Poupacred II.pdf_chunk_102',
#   'Regulamento Poupacred II.pdf_chunk_103',
#   'Regulamento Poupacred II.pdf_chunk_104',
#   'Regulamento Poupacred II.pdf_chunk_105',
#   'Regulamento Poupacred II.pdf_chunk_106',
#   'Regulamento Poupacred II.pdf_chunk_107',
#   'Regulamento Poupacred II.pdf_chunk_108',
#   'Regulamento Poupacred II.pdf_chunk_109',
#   'Regulamento Poupacred II.pdf_chunk_110',
#   'Regulamento Poupacred II.pdf_chunk_111',
#   'Regulamento Poupacred II.pdf_chunk_112',
#   'Regulamento Poupacred II.pdf_chunk_113',
#   'Regulamento Poupacred II.pdf_chunk_114',
#   'Regulamento Poupacred II.pdf_chunk_115',
#   'Regulamento Poupacred II.pdf_chunk_116',
#   'Regulamento Poupacred II.pdf_chunk_117',
#   'Regulamento Poupacred II.pdf_chunk_118',
#   'Regulamento Poupacred II.pdf_chunk_119',
#   'Regulamento Poupacred II.pdf_chunk_120',
#   'Regulamento Poupacred II.pdf_chunk_121',
#   'Regulamento Poupacred II.pdf_chunk_122',
#   'Regulamento Poupacred II.pdf_chunk_123',
#   'Regulamento Poupacred II.pdf_chunk_124',
#   'Regulamento Poupacred II.pdf_chunk_125',
#   'Regulamento Poupacred II.pdf_chunk_126',
#   'Regulamento Poupacred II.pdf_chunk_127',
#   'Regulamento Poupacred II.pdf_chunk_128',
#   'Regulamento Poupacred II.pdf_chunk_129',
#   'Regulamento Poupacred II.pdf_chunk_130',
#   'Regulamento Poupacred II.pdf_chunk_131',
#   'Regulamento Poupacred II.pdf_chunk_132',
#   'Regulamento Poupacred II.pdf_chunk_133',
#   'Regulamento Poupacred II.pdf_chunk_134',
#   'Regulamento Poupacred II.pdf_chunk_135',
#   'Regulamento Poupacred II.pdf_chunk_136',
#   'Regulamento Poupacred II.pdf_chunk_137',
#   'Regulamento Poupacred II.pdf_chunk_138',
#   'Regulamento Poupacred II.pdf_chunk_139',
#   'Regulamento Poupacred II.pdf_chunk_140',
#   'Regulamento Poupacred II.pdf_chunk_141',
#   'Regulamento Poupacred II.pdf_chunk_142',
#   'Regulamento Poupacred II.pdf_chunk_143',
#   'Regulamento Poupacred II.pdf_chunk_144',
#   'Regulamento Poupacred II.pdf_chunk_145',
#   'Regulamento Poupacred II.pdf_chunk_146',
#   'Regulamento Poupacred II.pdf_chunk_147',
#   'Regulamento Poupacred II.pdf_chunk_148',
#   'Regulamento Poupacred II.pdf_chunk_149',
#   'Regulamento Poupacred II.pdf_chunk_150',
#   'Regulamento Poupacred II.pdf_chunk_151',
#   'Regulamento Poupacred II.pdf_chunk_152',
#   'Regulamento Poupacred II.pdf_chunk_153',
#   'Regulamento Poupacred II.pdf_chunk_154',
#   'Regulamento Poupacred II.pdf_chunk_155',
#   'Regulamento Poupacred II.pdf_chunk_156',
#   'Regulamento Poupacred II.pdf_chunk_157',
#   'Regulamento Poupacred II.pdf_chunk_158',
#   'Regulamento Poupacred II.pdf_chunk_159',
#   'Regulamento Poupacred II.pdf_chunk_160',
#   'Regulamento Poupacred II.pdf_chunk_161',
#   'Regulamento Poupacred II.pdf_chunk_162',
#   'Regulamento Poupacred II.pdf_chunk_163',
#   'Regulamento Poupacred II.pdf_chunk_164',
#   'Regulamento Poupacred II.pdf_chunk_165',
#   'Regulamento Poupacred II.pdf_chunk_166',
#   'Regulamento Poupacred II.pdf_chunk_167',
#   'Regulamento Poupacred II.pdf_chunk_168',
#   'Regulamento Poupacred II.pdf_chunk_169',
#   'Regulamento Poupacred II.pdf_chunk_170',
#   'Regulamento Poupacred II.pdf_chunk_171',
#   'Regulamento Poupacred II.pdf_chunk_172',
#   'Regulamento Poupacred II.pdf_chunk_173',
#   'Regulamento Poupacred II.pdf_chunk_174',
#   'Regulamento Poupacred II.pdf_chunk_175',
#   'Regulamento Poupacred II.pdf_chunk_176',
#   'Regulamento Poupacred II.pdf_chunk_177',
#   'Regulamento Poupacred II.pdf_chunk_178',
#   'Regulamento Poupacred II.pdf_chunk_179',
#   'Regulamento Poupacred II.pdf_chunk_180',
#   'Regulamento Poupacred II.pdf_chunk_181',
#   'Regulamento Poupacred II.pdf_chunk_182',
#   'Regulamento Poupacred II.pdf_chunk_183',
#   'Regulamento Poupacred II.pdf_chunk_184',
#   'Regulamento Poupacred II.pdf_chunk_185',
#   'Regulamento Poupacred II.pdf_chunk_186',
#   'Regulamento Poupacred II.pdf_chunk_187',
#   'Regulamento Poupacred II.pdf_chunk_188',
#   'Regulamento Poupacred II.pdf_chunk_189',
#   'Regulamento Poupacred II.pdf_chunk_190',
#   'Regulamento Poupacred II.pdf_chunk_191',
#   'Regulamento Poupacred II.pdf_chunk_192',
#   'Regulamento Poupacred II.pdf_chunk_193',
#   'Regulamento Poupacred II.pdf_chunk_194',
#   'Regulamento Poupacred II.pdf_chunk_195',
#   'Regulamento Poupacred II.pdf_chunk_196',
#   'Regulamento Poupacred II.pdf_chunk_197',
#   'Regulamento Poupacred II.pdf_chunk_198',
#   'Regulamento Poupacred II.pdf_chunk_199',
#   'Regulamento Poupacred II.pdf_chunk_200',
#   'Regulamento Poupacred II.pdf_chunk_201',
#   'Regulamento Poupacred II.pdf_chunk_202',
#   'Regulamento Poupacred II.pdf_chunk_203',
#   'Regulamento Poupacred II.pdf_chunk_204',
#   'Regulamento Poupacred II.pdf_chunk_205',
#   'Regulamento Poupacred II.pdf_chunk_206',
#   'Regulamento Poupacred II.pdf_chunk_207',
#   'Regulamento Poupacred II.pdf_chunk_208',
#   'Regulamento Poupacred II.pdf_chunk_209'],
#  'embeddings': None,
#  'documents': ['Docusign Envelope ID: 2E621B1E-0D2F-4755-9F17-8D79AC1DF7C1\nREGULAMENTO DO\nCONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS\nCREDITÓRIOS RESPONSABILIDADE LIMITADA\nCNPJ/MF em constituição\nPágina 4 de 49\nDocusign Envelope ID: 2E621B1E-0D2F-4755-9F17-8D79AC1DF7C1\nDEFINIÇÕES\nPara fins do disposto neste Regulamento, os termos e expressões indicados em letra maiúscula neste\nRegulamento, no singular ou no plural, terão os respectivos significados a eles atribuídos a seguir:\n“Agência de Classificação de Agência de classificação de risco que pode ser contratada pela\nRisco” Gestora, em nome do Fundo, para realizar a avaliação de risco\ndas Cotas, nos termos dispostos neste Regulamento;\n“Agente de Cobrança” CONCRETA CONSULTORIA E GESTÃO DE NEGÓCIOS\nLTDA., pessoa jurídica de direito privado, com sede na Cidade\nde Belo Horizonte, Estado de Minas Gerais, à Avenida Raja\nGabaglia nº 2.000, Pavimento 4, Bloco 1, Sala 417, Bairro\nAlpes, CEP 30494-170, inscrita no CNPJ/MF sob o nº\n43.468.812/0001-79\n“A',
#   'e na Cidade\nde Belo Horizonte, Estado de Minas Gerais, à Avenida Raja\nGabaglia nº 2.000, Pavimento 4, Bloco 1, Sala 417, Bairro\nAlpes, CEP 30494-170, inscrita no CNPJ/MF sob o nº\n43.468.812/0001-79\n“Anexo da Classe” São os Anexos da respectiva Classe Única deste\nRegulamento, dos quais constam as regras específicas\naplicáveis à cada Classe e respectivas Subclasses;\n“Administradora”: ID CORRETORA DE TÍTULOS E VALORES MOBILIÁRIOS\nS.A., com sede na Cidade de São Paulo, Estado de São
#   '\nalterada;\n“Resolução CVM nº 175” Resolução CVM nº 175, de 23 de dezembro de 2022, conforme\nalterada;\n“Taxa de Administração”: Taxa devida à Administradora, conforme prevista neste\nRegulamento e seu Anexo;\n“Taxa de Gestão”: Taxa devida à Gestora, conforme prevista neste Regulamento\ne seu Anexo;\n“Termos de Cessão” Termos celebrados entre o Fundo e/ou a Classe e a respectiva\nCedente, com interveniência da Gestora e da Administradora,\nconforme modelo anexo aos Contratos de Cessão, por meio\ndos quais a respectiva Cedente cede Direitos Creditórios ao\nFundo e/ou a Classe;\n“Termos de Endosso” Termos celebrados entre o Fundo e/ou a Classe e o respectivo\nPágina 8 de 49\nDocusign Envelope ID: 2E621B1E-0D2F-4755-9F17-8D79AC1DF7C1\nendossante, com interveniência da Gestora e da\nAdministradora, conforme modelo anexo aos Contratos de\nEndosso, por meio dos quais o respectivo Endossante\nendossa Direitos Creditórios ao Fundo e/ou a Classe;\n“Suplemento” Suplemento das Subclasses do Fundo.\nPágina 9 de 49\nD',
#   'ocusign Envelope ID: 2E621B1E-0D2F-4755-9F17-8D79AC1DF7C1\nREGULAMENTO DO CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS\nCREDITÓRIOS RESPONSABILIDADE LIMITADA\nCNPJ/MF em constituição\nO CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS\nRESPONSABILIDADE LIMITADA, é uma comunhão de recursos, constituído sob a forma de\ncondomínio de natureza especial, regido pelo presente Regulamento, seu Anexo e, ainda, pelas\ndisposições legais e normativas que lhe forem aplicáveis, em especial a Resolução CMN 2.907, a\nResolução CVM nº 175 e seu Anexo Normativo II e o Código ANBIMA.\nOs termos definidos e expressões adotadas com iniciais em letras maiúsculas no presente\nRegulamento, e em seus anexos, terão o significado a eles atribuídos no Anexo I a este\nRegulamento, aplicável tanto no singular quanto no plural e o masculino incluirá o feminino e vice\nversa. Adicionalmente, (i) as referências a “Fundo” ou a “Fundo de Investimento” alcançam todas as\nsuas classes de cotas; (ii) as refe',
#   'rências a “Classe” e a “Classe de cotas” alcançam os fundos de\ninvestimento que emitem cotas em classe única; (iii) as referências a “Regulamento” e a\n“Regulamento do Fundo” alcançam os anexos descritivos das classes de cotas; e (iv) referências a\ndisposições legais serão interpretadas como referências a tais disposições conforme alteradas.\nEste Fundo foi constituído por deliberação realizada em conjunto por seus Prestadores de Serviços\nEssenciais, os responsáveis pela aprovação, no mesmo ato, deste Regulamento e seus anexos.\nAdicionalmente, destaca-se que mediante a aprovação dos Prestadores de Serviços Essenciais,\nobservada a necessidade de realização das demais adaptações necessárias ao presente\nRegulamento e aos respectivos Anexos, a partir da entrada em vigor das regras específicas da\nResolução CVM nº 175 com prazo de vigência a partir de 2024, como, por exemplo o artigo 5º da\nResolução CVM nº 175, o Fundo poderá criar diferentes Classes de cotas, com patrimônio\nsegregado, e respe',
# ...
#   {'chunk_index': 172, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 173, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 174, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 175, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 176, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 177, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 178, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 179, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 180, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 181, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 182, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 183, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 184, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 185, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 186, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 187, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 188, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 189, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 190, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 191, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 192, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 193, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 194, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 195, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 196, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 197, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 198, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 199, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 200, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 201, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 202, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 203, 'source': 'Regulamento Concrédito II.pdf'},
#   {'chunk_index': 0, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 1, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 2, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 3, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 4, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 5, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 6, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 7, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 8, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 9, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 10, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 11, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 12, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 13, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 14, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 15, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 16, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 17, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 18, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 19, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 20, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 21, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 22, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 23, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 24, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 25, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 26, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 27, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 28, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 29, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 30, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 31, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 32, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 33, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 34, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 35, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 36, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 37, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 38, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 39, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 40, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 41, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 42, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 43, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 44, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 45, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 46, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 47, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 48, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 49, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 50, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 51, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 52, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 53, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 54, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 55, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 56, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 57, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 58, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 59, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 60, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 61, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 62, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 63, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 64, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 65, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 66, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 67, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 68, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 69, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 70, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 71, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 72, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 73, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 74, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 75, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 76, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 77, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 78, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 79, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 80, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 81, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 82, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 83, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 84, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 85, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 86, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 87, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 88, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 89, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 90, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 91, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 92, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 93, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 94, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 95, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 96, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 97, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 98, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 99, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 100, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 101, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 102, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 103, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 104, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 105, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 106, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 107, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 108, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 109, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 110, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 111, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 112, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 113, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 114, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 115, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 116, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 117, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 118, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 119, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 120, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 121, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 122, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 123, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 124, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 125, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 126, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 127, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 128, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 129, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 130, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 131, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 132, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 133, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 134, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 135, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 136, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 137, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 138, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 139, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 140, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 141, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 142, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 143, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 144, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 145, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 146, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 147, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 148, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 149, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 150, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 151, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 152, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 153, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 154, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 155, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 156, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 157, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 158, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 159, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 160, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 161, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 162, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 163, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 164, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 165, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 166, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 167, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 168, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 169, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 170, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 171, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 172, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 173, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 174, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 175, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 176, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 177, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 178, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 179, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 180, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 181, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 182, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 183, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 184, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 185, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 186, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 187, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 188, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 189, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 190, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 191, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 192, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 193, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 194, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 195, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 196, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 197, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 198, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 199, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 200, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 201, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 202, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 203, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 204, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 205, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 206, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 207, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 208, 'source': 'Regulamento Poupacred II.pdf'},
#   {'chunk_index': 209, 'source': 'Regulamento Poupacred II.pdf'}],
#  'included': [<IncludeEnum.documents: 'documents'>,
#   <IncludeEnum.metadatas: 'metadatas'>]}

# %%
def delete_existing_chunks(source):
    existing_chunks = collection.get()["ids"]

    for chunk_id in existing_chunks:
        if chunk_id.startswith(source):
            collection.delete(ids=[chunk_id])
            print(f"🗑️ Chunk {chunk_id} deletado.")

# Exemplo: Deletar apenas os chunks do documento "CONCRETO-CONSIGNADO"
#delete_existing_chunks("CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO")

# %% [markdown]
# # Implementação da RAG

# %%
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_openai import ChatOpenAI

def detect_document_mention(query, available_sources):
    for source in available_sources:
        if re.search(re.escape(source), query, re.IGNORECASE):  # Busca pelo nome do documento na pergunta
            return source
    return None  # Retorna None se nenhum documento for encontrado

# Função que pesquisa pelos documentos relevantes baseando-se no contexto da pergunta
def search_document(question, client):

    print("Pesquisando documentos relevantes...")

    query_embedding = get_embedding_openai(question, client)

    results = collection.query(
        query_embeddings= [query_embedding],
        n_results= 20
    )

    for doc, meta in zip(results["documents"][0], results["metadatas"][0]):
        print(f"\nFonte: {meta['source']} - Tipo: {meta['type']}")
        print(doc[:1000])  

def ask_llm(query, client):

    stored_data = collection.get(include=["metadatas"])
    available_sources = {meta["source"] for meta in stored_data["metadatas"]}  # Obtém nomes únicos dos documentos

    # Verifica se o usuário mencionou um documento específico
    specific_document = detect_document_mention(query, available_sources)

    # Definição do filtro para busca no ChromaDB
    search_filter = {"source": specific_document} if specific_document else None  # Filtra apenas se um documento for citado

    # Busca informações no ChromaDB
    embedding = get_embedding_openai(query, client)

    results = collection.query(
        query_embeddings=[embedding],
        n_results=20,
        where= search_filter
    )

    # Organiza os resultados agrupando por 'source' (nome do documento)
    retrieved_docs = results["documents"][0]
    metadatas = results["metadatas"][0]

    grouped_docs = {}  # Dicionário para agrupar os chunks pelo nome do documento

    for doc, meta in zip(retrieved_docs, metadatas):
        source = meta["source"]  # Nome do documento original
        if source not in grouped_docs:
            grouped_docs[source] = []
        grouped_docs[source].append(doc)  # Adiciona o chunk ao documento correspondente

    # Criar um contexto consolidado por documento
    context = "\n\n".join([
        f"🔹 Documento: {source}\n" + "\n".join(chunks)
        for source, chunks in grouped_docs.items()
    ])

    modelo = ChatOpenAI(model = "gpt-4o-mini", temperature= 0, max_tokens= 4096)

    prompt = f"""
    Você é um assistente especializado em responder perguntas sobre vários documentos PDF armazenados em um banco de dados.
    Cada documento está dividido em múltiplos IDs, diferenciando-se apenas pelo número ao final.
    Documentos cujos IDs tenham nomes diferente não possuem relação alguma um com o outro.
    Quando for dado o nome de um fundo de investimento, forneça informação contida apenas naquele chunk. Não misture informação de diferentes documentos
    Considere os seguintes documentos: 
    {context}
    
    Caso não seja mencionado nenhum nome de fundo, responda considerando **todos** os documentos mencionados acima.
    """
    #Se não for encontrado nenhum documento semelhante ao nome dado, informe.
    messages=[
    SystemMessage(content= prompt),
    HumanMessage( content= query)
    ]

    answer = modelo.invoke(messages)

    return answer.content
    # return response["choices"][0]["message"]["content"]

# %% [markdown]
# # Aplicação do LLM

# %%
# question = """
# Quais são os gestores dos fundos Concreto e Concrédito II?
# """

question = """
Quem são as gestoras dos FIDC GVN?
"""

print(ask_llm(question, openai_client))
# Out:
# Não há informações sobre um fundo de investimento chamado "FIDC GVN" nos documentos mencionados. Os documentos disponíveis tratam de outros fundos, como o "CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS RESPONSABILIDADE LIMITADA", que é gerido pela CONCRETA GESTORA DE RECURSOS LTDA. e co-gestorado pela BLESS CAPITAL GESTORA DE RECURSOS LTDA., e o "FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS CONCRÉDITO II", que é gerido pela CULTINVEST ASSET MANAGEMENT LTDA.
#
# Se precisar de informações sobre esses ou outros fundos, por favor, me avise!

# %% [markdown]
# ## Aplicação do LLM (ANTIGO)

# %%
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_openai import ChatOpenAI

modelo_antigo = ChatOpenAI(model = "gpt-4o-mini", temperature= 0, max_tokens= 4096)

prompt = """Você é um assistente de IA que responde as dúvidas dos usuários com bases nos documentos abaixo.
Os documentos abaixo apresentam as fontes atualizadas e devem ser consideradas como verdade. Sempre que uma
pergunta oferecer o nome de um FIDC, você deve procurar pela melhor correspondência deste nome na lista de documentos.
Cite a fonte quando fornecer a informação.
Documentos:
{documents}
""" #Caso o nome citado na pergunta não exista na lista de documentos, responda que ele não foi encontrado.

prompt = prompt.format(documents= documents_str)

messages=[
  SystemMessage(content= prompt),
  HumanMessage(content= question)
]

# %%
answer = modelo_antigo.invoke(messages)

# %%
answer.content
# Out:
# "Com base nos documentos disponíveis, não encontrei menções aos termos 'Saque aniversário', 'FGTS', 'INSS', 'Consignado' ou 'Saque-Aniversário FGTS'. Portanto, não há documentos que incluam qualquer um desses termos."
