# %%
"""
Versão 1.1:
Melhoria no sistema de extração dos PDFs, sem usar LlamaParser, apenas bibliotecas de PDF. Também inclusa extração de tabelas
Modelo de Embedding atualizado para text-embedding-3-small
Divisão dos chunks ainda realizada em modelo de blocos de tamanho fixo
Com ajuda do GPT, tentamos implementar um esquema de busca inteligente dos documentos, citando nome específico e retornando contexto.
Número de resultados retornados com as queries foi aumentado 3->20 
"""

# %% [markdown]
# # Preparação dos Documentos

# %%
import pdfplumber
#import pytesseract
#import pdf2image
import pandas as pd
import tiktoken
import chromadb
import openai
import json
import os
import re
from openai import OpenAI
from langchain_openai import OpenAIEmbeddings
from dotenv import find_dotenv, load_dotenv

# %%
CHUNK_SIZE = 1000
OFFSET = 200

load_dotenv(find_dotenv())
tokenizer = tiktoken.get_encoding("cl100k_base")
openai_client = OpenAI(api_key= os.getenv("OPENAI_API_KEY"))

# Conexão com o cliente do banco de dados ChromaDB
chromadb_path = "C:/Users/Lucas/Desktop/Repositories/SLRFIDC/Base ChromaDB/"
chroma_client = chromadb.PersistentClient(path= chromadb_path)
collection    = chroma_client.get_or_create_collection(name= "Regulamentos")

# %%
# Checa todo o conteúdo inserido no ChromaDB
collection.get()
# Out:
# {'ids': ['Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_0',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_1',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_2',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_3',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_4',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_5',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_6',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_7',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_8',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_9',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_10',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_11',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_12',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_13',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_14',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_15',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_16',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_17',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_18',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_19',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_20',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_21',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_22',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_23',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_24',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_25',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_26',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_27',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_28',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_29',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_30',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_31',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_32',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_33',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_34',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_35',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_36',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_37',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_38',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_39',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_40',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_41',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_42',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_43',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_44',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_45',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_46',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_47',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_48',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_49',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_50',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_51',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_52',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_53',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_54',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_55',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_56',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_57',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_58',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_59',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_60',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_61',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_62',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_63',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_64',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_65',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_66',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_67',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_68',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_69',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_70',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_71',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_72',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_73',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_74',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_75',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_76',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_77',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_78',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_79',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_80',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_81',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_82',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_83',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_84',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_85',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_86',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_87',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_88',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_89',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_90',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_91',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_92',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_93',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_94',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_95',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_96',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_97',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_98',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_99',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_100',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_101',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_102',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_103',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_104',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_105',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_106',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_107',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_108',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_109',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_110',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_111',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_112',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_113',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_114',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_115',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_116',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_117',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_118',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_119',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_120',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_121',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_122',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_123',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_124',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_125',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_126',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_127',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_128',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_129',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_130',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_131',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_132',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_133',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_134',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_135',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_136',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_137',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_138',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_139',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_140',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_141',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_142',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_143',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_144',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_145',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_146',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_147',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_148',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_149',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_150',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_151',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_152',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_153',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_154',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_155',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_156',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_157',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_158',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_159',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_160',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_161',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_162',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_163',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_164',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_165',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_166',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_167',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_168',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_169',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_170',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_171',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_172',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_173',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_174',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_175',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_176',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_177',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_178',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_179',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_180',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_181',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_182',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_183',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_184',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_185',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_186',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_187',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_188',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_189',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_190',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_191',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_192',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_193',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_194',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_195',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_196',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_197',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_0',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_1',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_2',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_3',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_4',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_5',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_6',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_7',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_8',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_9',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_10',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_11',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_12',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_13',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_14',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_15',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_16',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_17',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_18',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_19',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_20',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_21',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_22',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_23',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_24',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_25',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_26',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_27',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_28',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_29',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_30',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_31',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_32',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_33',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_34',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_35',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_36',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_37',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_38',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_39',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_40',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_41',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_42',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_43',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_44',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_45',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_46',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_47',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_48',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_49',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_50',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_51',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_52',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_53',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_54',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_55',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_56',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_57',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_58',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_59',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_60',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_61',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_62',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_63',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_64',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_65',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_66',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_67',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_68',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_69',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_70',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_71',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_72',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_73',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_74',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_75',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_76',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_77',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_78',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_79',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_80',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_81',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_82',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_83',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_84',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_85',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_86',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_87',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_88',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_89',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_90',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_91',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_92',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_93',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_94',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_95',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_96',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_97',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_98',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_99',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_100',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_101',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_102',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_103',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_104',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_105',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_106',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_107',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_108',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_109',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_110',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_111',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_112',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_113',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_114',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_115',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_116',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_117',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_118',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_119',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_120',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_121',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_122',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_123',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_124',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_125',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_126',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_127',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_128',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_129',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_130',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_131',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_132',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_133',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_134',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_135',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_136',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_137',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_138',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_139',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_140',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_141',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_142',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_143',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_144',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_145',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_146',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_147',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_148',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_149',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_150',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_151',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_152',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_153',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_154',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_155',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_156',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_157',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_158',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_159',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_160',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_161',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_162',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_163',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_164',
#   'Regulamento FIDC GVN (1).pdf_chunk_0',
#   'Regulamento FIDC GVN (1).pdf_chunk_1',
#   'Regulamento FIDC GVN (1).pdf_chunk_2',
#   'Regulamento FIDC GVN (1).pdf_chunk_3',
#   'Regulamento FIDC GVN (1).pdf_chunk_4',
#   'Regulamento FIDC GVN (1).pdf_chunk_5',
#   'Regulamento FIDC GVN (1).pdf_chunk_6',
#   'Regulamento FIDC GVN (1).pdf_chunk_7',
#   'Regulamento FIDC GVN (1).pdf_chunk_8',
#   'Regulamento FIDC GVN (1).pdf_chunk_9',
#   'Regulamento FIDC GVN (1).pdf_chunk_10',
#   'Regulamento FIDC GVN (1).pdf_chunk_11',
#   'Regulamento FIDC GVN (1).pdf_chunk_12',
#   'Regulamento FIDC GVN (1).pdf_chunk_13',
#   'Regulamento FIDC GVN (1).pdf_chunk_14',
#   'Regulamento FIDC GVN (1).pdf_chunk_15',
#   'Regulamento FIDC GVN (1).pdf_chunk_16',
#   'Regulamento FIDC GVN (1).pdf_chunk_17',
#   'Regulamento FIDC GVN (1).pdf_chunk_18',
#   'Regulamento FIDC GVN (1).pdf_chunk_19',
#   'Regulamento FIDC GVN (1).pdf_chunk_20',
#   'Regulamento FIDC GVN (1).pdf_chunk_21',
#   'Regulamento FIDC GVN (1).pdf_chunk_22',
#   'Regulamento FIDC GVN (1).pdf_chunk_23',
#   'Regulamento FIDC GVN (1).pdf_chunk_24',
#   'Regulamento FIDC GVN (1).pdf_chunk_25',
#   'Regulamento FIDC GVN (1).pdf_chunk_26',
#   'Regulamento FIDC GVN (1).pdf_chunk_27',
#   'Regulamento FIDC GVN (1).pdf_chunk_28',
#   'Regulamento FIDC GVN (1).pdf_chunk_29',
#   'Regulamento FIDC GVN (1).pdf_chunk_30',
#   'Regulamento FIDC GVN (1).pdf_chunk_31',
#   'Regulamento FIDC GVN (1).pdf_chunk_32',
#   'Regulamento FIDC GVN (1).pdf_chunk_33',
#   'Regulamento FIDC GVN (1).pdf_chunk_34',
#   'Regulamento FIDC GVN (1).pdf_chunk_35',
#   'Regulamento FIDC GVN (1).pdf_chunk_36',
#   'Regulamento FIDC GVN (1).pdf_chunk_37',
#   'Regulamento FIDC GVN (1).pdf_chunk_38',
#   'Regulamento FIDC GVN (1).pdf_chunk_39',
#   'Regulamento FIDC GVN (1).pdf_chunk_40',
#   'Regulamento FIDC GVN (1).pdf_chunk_41',
#   'Regulamento FIDC GVN (1).pdf_chunk_42',
#   'Regulamento FIDC GVN (1).pdf_chunk_43',
#   'Regulamento FIDC GVN (1).pdf_chunk_44',
#   'Regulamento FIDC GVN (1).pdf_chunk_45',
#   'Regulamento FIDC GVN (1).pdf_chunk_46',
#   'Regulamento FIDC GVN (1).pdf_chunk_47',
#   'Regulamento FIDC GVN (1).pdf_chunk_48',
#   'Regulamento FIDC GVN (1).pdf_chunk_49',
#   'Regulamento FIDC GVN (1).pdf_chunk_50',
#   'Regulamento FIDC GVN (1).pdf_chunk_51',
#   'Regulamento FIDC GVN (1).pdf_chunk_52',
#   'Regulamento FIDC GVN (1).pdf_chunk_53',
#   'Regulamento FIDC GVN (1).pdf_chunk_54',
#   'Regulamento FIDC GVN (1).pdf_chunk_55',
#   'Regulamento FIDC GVN (1).pdf_chunk_56',
#   'Regulamento FIDC GVN (1).pdf_chunk_57',
#   'Regulamento FIDC GVN (1).pdf_chunk_58',
#   'Regulamento FIDC GVN (1).pdf_chunk_59',
#   'Regulamento FIDC GVN (1).pdf_chunk_60',
#   'Regulamento FIDC GVN (1).pdf_chunk_61',
#   'Regulamento FIDC GVN (1).pdf_chunk_62',
#   'Regulamento FIDC GVN (1).pdf_chunk_63',
#   'Regulamento FIDC GVN (1).pdf_chunk_64',
#   'Regulamento FIDC GVN (1).pdf_chunk_65',
#   'Regulamento FIDC GVN (1).pdf_chunk_66',
#   'Regulamento FIDC GVN (1).pdf_chunk_67',
#   'Regulamento FIDC GVN (1).pdf_chunk_68',
#   'Regulamento FIDC GVN (1).pdf_chunk_69',
#   'Regulamento FIDC GVN (1).pdf_chunk_70',
#   'Regulamento FIDC GVN (1).pdf_chunk_71',
#   'Regulamento FIDC GVN (1).pdf_chunk_72',
#   'Regulamento FIDC GVN (1).pdf_chunk_73',
#   'Regulamento FIDC GVN (1).pdf_chunk_74',
#   'Regulamento FIDC GVN (1).pdf_chunk_75',
#   'Regulamento FIDC GVN (1).pdf_chunk_76',
#   'Regulamento FIDC GVN (1).pdf_chunk_77',
#   'Regulamento FIDC GVN (1).pdf_chunk_78',
#   'Regulamento FIDC GVN (1).pdf_chunk_79',
#   'Regulamento FIDC GVN (1).pdf_chunk_80',
#   'Regulamento FIDC GVN (1).pdf_chunk_81',
#   'Regulamento FIDC GVN (1).pdf_chunk_82',
#   'Regulamento FIDC GVN (1).pdf_chunk_83',
#   'Regulamento FIDC GVN (1).pdf_chunk_84',
#   'Regulamento FIDC GVN (1).pdf_chunk_85',
#   'Regulamento FIDC GVN (1).pdf_chunk_86',
#   'Regulamento FIDC GVN (1).pdf_chunk_87',
#   'Regulamento FIDC GVN (1).pdf_chunk_88',
#   'Regulamento FIDC GVN (1).pdf_chunk_89',
#   'Regulamento FIDC GVN (1).pdf_chunk_90',
#   'Regulamento FIDC GVN (1).pdf_chunk_91',
#   'Regulamento FIDC GVN (1).pdf_chunk_92',
#   'Regulamento FIDC GVN (1).pdf_chunk_93',
#   'Regulamento FIDC GVN (1).pdf_chunk_94',
#   'Regulamento FIDC GVN (1).pdf_chunk_95',
#   'Regulamento FIDC GVN (1).pdf_chunk_96',
#   'Regulamento FIDC GVN (1).pdf_chunk_97',
#   'Regulamento FIDC GVN (1).pdf_chunk_98',
#   'Regulamento FIDC GVN (1).pdf_chunk_99',
#   'Regulamento FIDC GVN (1).pdf_chunk_100',
#   'Regulamento FIDC GVN (1).pdf_chunk_101',
#   'Regulamento FIDC GVN (1).pdf_chunk_102',
#   'Regulamento FIDC GVN (1).pdf_chunk_103',
#   'Regulamento FIDC GVN (1).pdf_chunk_104',
#   'Regulamento FIDC GVN (1).pdf_chunk_105',
#   'Regulamento FIDC GVN (1).pdf_chunk_106',
#   'Regulamento FIDC GVN (1).pdf_chunk_107',
#   'Regulamento FIDC GVN (1).pdf_chunk_108',
#   'Regulamento FIDC GVN (1).pdf_chunk_109',
#   'Regulamento FIDC GVN (1).pdf_chunk_110',
#   'Regulamento FIDC GVN (1).pdf_chunk_111',
#   'Regulamento FIDC GVN (1).pdf_chunk_112',
#   'Regulamento FIDC GVN (1).pdf_chunk_113',
#   'Regulamento FIDC GVN (1).pdf_chunk_114',
#   'Regulamento FIDC GVN (1).pdf_chunk_115',
#   'Regulamento FIDC GVN (1).pdf_chunk_116',
#   'Regulamento FIDC GVN (1).pdf_chunk_117',
#   'Regulamento FIDC GVN (1).pdf_chunk_118',
#   'Regulamento FIDC GVN (1).pdf_chunk_119',
#   'Regulamento FIDC GVN (1).pdf_chunk_120',
#   'Regulamento FIDC GVN (1).pdf_chunk_121',
#   'Regulamento FIDC GVN (1).pdf_chunk_122',
#   'Regulamento FIDC GVN (1).pdf_chunk_123',
#   'Regulamento FIDC GVN (1).pdf_chunk_124',
#   'Regulamento FIDC GVN (1).pdf_chunk_125',
#   'Regulamento FIDC GVN (1).pdf_chunk_126',
#   'Regulamento FIDC GVN (1).pdf_chunk_127',
#   'Regulamento FIDC GVN (1).pdf_chunk_128',
#   'Regulamento FIDC GVN (1).pdf_chunk_129',
#   'Regulamento FIDC GVN (1).pdf_chunk_130',
#   'Regulamento FIDC GVN (1).pdf_chunk_131',
#   'Regulamento FIDC GVN (1).pdf_chunk_132',
#   'Regulamento FIDC GVN (1).pdf_chunk_133',
#   'Regulamento FIDC GVN (1).pdf_chunk_134',
#   'Regulamento FIDC GVN (1).pdf_chunk_135',
#   'Regulamento FIDC GVN (1).pdf_chunk_136',
#   'Regulamento FIDC GVN (1).pdf_chunk_137',
#   'Regulamento FIDC GVN (1).pdf_chunk_138',
#   'Regulamento FIDC GVN (1).pdf_chunk_139',
#   'Regulamento FIDC GVN (1).pdf_chunk_140',
#   'Regulamento FIDC GVN (1).pdf_chunk_141',
#   'Regulamento FIDC GVN (1).pdf_chunk_142',
#   'Regulamento FIDC GVN (1).pdf_chunk_143',
#   'Regulamento FIDC GVN (1).pdf_chunk_144',
#   'Regulamento FIDC GVN (1).pdf_chunk_145',
#   'Regulamento FIDC GVN (1).pdf_chunk_146',
#   'Regulamento FIDC GVN (1).pdf_chunk_147',
#   'Regulamento FIDC GVN (1).pdf_chunk_148',
#   'Regulamento FIDC GVN (1).pdf_chunk_149',
#   'Regulamento FIDC GVN (1).pdf_chunk_150',
#   'Regulamento FIDC GVN (1).pdf_chunk_151',
#   'Regulamento FIDC GVN (1).pdf_chunk_152',
#   'Regulamento FIDC GVN (1).pdf_chunk_153',
#   'Regulamento FIDC GVN (1).pdf_chunk_154',
#   'Regulamento FIDC GVN (1).pdf_chunk_155',
#   'Regulamento FIDC GVN (1).pdf_chunk_156',
#   'Regulamento FIDC GVN (1).pdf_chunk_157',
#   'Regulamento FIDC GVN (1).pdf_chunk_158',
#   'Regulamento FIDC GVN (1).pdf_chunk_159',
#   'Regulamento FIDC GVN (1).pdf_chunk_160',
#   'Regulamento FIDC GVN (1).pdf_chunk_161',
#   'Regulamento FIDC GVN (1).pdf_chunk_162',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_0',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_1',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_2',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_3',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_4',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_5',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_6',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_7',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_8',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_9',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_10',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_11',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_12',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_13',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_14',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_15',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_16',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_17',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_18',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_19',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_20',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_21',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_22',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_23',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_24',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_25',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_26',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_27',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_28',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_29',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_30',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_31',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_32',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_33',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_34',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_35',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_36',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_37',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_38',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_39',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_40',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_41',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_42',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_43',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_44',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_45',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_46',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_47',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_48',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_49',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_50',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_51',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_52',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_53',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_54',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_55',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_56',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_57',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_58',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_59',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_60',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_61',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_62',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_63',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_64',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_65',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_66',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_67',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_68',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_69',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_70',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_71',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_72',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_73',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_74',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_75',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_76',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_77',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_78',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_79',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_80',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_81',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_82',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_83',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_84',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_85',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_86',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_87',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_88',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_89',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_90',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_91',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_92',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_93',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_94',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_95',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_96',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_97',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_98',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_99',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_100',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_101',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_102',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_103',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_104',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_105',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_106',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_107',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_108',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_109',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_110',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_111',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_112',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_113',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_114',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_115',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_116',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_117',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_118',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_119',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_120',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_121',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_122',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_123',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_124',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_125',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_126',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_127',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_128',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_129',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_130',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_131',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_132',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_133',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_134',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_135',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_136',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_137',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_138',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_139',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_140',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_141',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_142',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_143',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_144',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_145',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_146',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_147',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_148',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_149',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_150',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_151',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_152',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_153',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_154',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_155',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_156',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_157',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_158',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_159',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_160',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_161',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_162',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_163',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_164',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_165',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_166',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_167',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_168',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_169',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_170',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_171',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_172',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_173',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_174',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_175',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_176',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_177',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_178',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_179',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_180',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_181',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_182',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_183',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_184',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_185',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_186',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_187',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_188',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_189',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_190',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_191',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_192',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_193',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_194',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_195',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_196',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_197',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_198',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_199',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_200',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_201',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_202',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_203',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_204'],
#  'embeddings': None,
#  'documents': ['REGULAMENTO\nDO\nFUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS CONCRÉDITO RESPONSABILIDADE\nILIMITADA\nCNPJ/MF Nº 52.511.329/0001-10\nVIGENTE A PARTIR DE 22 DEMARÇO DE 2024.\nREGULAMENTO DO\nFUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS CONCRÉDITO RESPONSABILIDADE\nILIMITADA\nPARTE GERAL\nCAPÍTULO I – DO FUNDO\nO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS CONCRÉDITO RESPONSABILIDADE\nILIMITADA\n1.1. é um fundo de investimento em direitos creditórios constituído sob a forma de\ncondomínio de natureza especial fechado, com prazo de duração indeterminado, regido pelo\npresente Regulamento (o “Regulamento”), pela Resolução CMN 2.907, pela Resolução CVM 175\ne pelas demais disposições legais e regulamentares que lhe forem aplicáveis.\n1.2. O exercício social do FUNDO tem duração de 01 (um) ano, com término em abril de cada\nano.\nCAPÍTULO II – DAS DEFINIÇÕES\n2.1. Sem prejuízo de definições específicas previstas nos Anexos das respectivas\nClasses, os termos e expressões previstos neste Regulamento, indicado',
#   'm abril de cada\nano.\nCAPÍTULO II – DAS DEFINIÇÕES\n2.1. Sem prejuízo de definições específicas previstas nos Anexos das respectivas\nClasses, os termos e expressões previstos neste Regulamento, indicados em letra maiúscula, no\nsingular ou no plural, terão os significados a seguir atribuídos:\nAcordo Operacional: É o acordo operacional celebrado entre a ADMINISTRADORA e\na GESTORA;\nADMINISTRADORA: BANCO DAYCOVAL S.A., instituição financeira autorizada pela\nCVM para o exercício profissional de administração de carteiras\nde valores mobiliários, na categoria de administrador\nfiduciário, por meio do Ato Declaratório CVM nº 17.552, de 5\nde dezembro de 2019, com sede na cidade de São Paulo,\nEstado de São Paulo, na Avenida Paulista, nº 1.793, CEP 01311-\n200, inscrita no CNPJ sob o nº 62.232.889/0001-90, ou quem\nlhe vier a suceder;\n“Alocação Mínima” Percentual mínimo de 67% (setenta e sete por cento) do\nPatrimônio Líquido a ser mantido em Direitos Creditórios\nCedidos, conforme definido pelo Conselh',
#   'o Monetário Nacional\ne Comissão de Valores Mobiliários\nANBIMA: é a Associação Brasileira das Entidades dos Mercados\nFinanceiro e de Capitais;\nAnexo(s): significa(m) a(s) parte(s) do Regulamento do FUNDO essenciais\nà constituição de Classes de Cotas, que regem o funcionamento\ndas Classes de modo complementar ao disciplinado pelo\nRegulamento;\nApêndices: partes do Anexo que disciplinam as características específicas\nde cada Subclasse de Cotas;\nApensos: partes do(s) Apêndice(s) que preveem os modelos de\nsuplementos das Subclasses;\nAssembleia Geral de Cotistas: significa a assembleia para a qual são convocados todos os\ncotistas do FUNDO;\nAssembleia Especial de Cotistas: significa a assembleia para a qual são convocados somente os\ncotistas de determinada Classe ou Subclasse de Cotas;\nAuditor Independente: é a empresa de auditoria independente contratada pela\nADMINISTRADORA, nos termos deste Regulamento, ou sua\nsucessora a qualquer título, encarregada da revisão das\ndemonstrações financeiras ',
#   'do FUNDO, das contas de cada\nClasse do FUNDO e da análise de sua situação e da atuação da\nADMINISTRADORA e da GESTORA;\nB3 é a B3 S.A. – Brasil, Bolsa, Balcão.\nBACEN: o Banco Central do Brasil;\nClasse: Significa cada classe de Cotas emitidas pelo FUNDO, que\npodem contar com direitos e obrigações distintos, devendo a\nADMINISTRADORA constituir um patrimônio segregado para\ncada classe de cotas;\nCMN: Conselho Monetário Nacional;\nConta da Classe: a conta corrente ou conta de pagamento de titularidade de\ncada Classe do FUNDO;\nCotas: todas as Cotas emitidas pelo FUNDO, independente de Classe,\nsubclasse ou Série;\nCotas Seniores: as cotas de subclasse sênior de quaisquer séries emitidas pelo\nFUNDO, que não se subordinam às demais classes de Cotas\npara efeito de amortização, resgate e distribuição de\nrendimentos da carteira do FUNDO;\nCotas Subordinadas: as Cotas Subordinadas Júnior e as Cotas Subordinadas\nMezanino, quando referidas em conjunto;\nCotas Subordinadas Júnior: as cotas de subclasse sub',
#   'ordinada emitidas pelo FUNDO, que\nse subordinam às Cotas Seniores para efeito de amortização,\nresgate e distribuição de rendimentos da carteira do FUNDO;\nCotas Subordinadas Mezanino: as cotas de subclasse subordinada mezanino de quaisquer\nséries emitidas pelo FUNDO, que se subordinam às Cotas\nSeniores e que têm prioridade em relação às Cotas\nSubordinadas Junior para efeito de amortização, resgate e\ndistribuição dos rendimentos da carteira do FUNDO;\nCotista: o investidor que venha adquirir Cotas de emissão do FUNDO;\nCotista Sênior: o investidor que venha adquirir Cotas Seniores de emissão do\nFUNDO;\nCotista Subordinado Júnior: o investidor que venha adquirir Cotas Subordinadas Júnior de\nemissão do FUNDO;\nCotista Subordinado Mezanino: o investidor que venha adquirir Cotas Subordinadas Mezanino\nde emissão do FUNDO;\nCUSTODIANTE: BANCO DAYCOVAL S.A., instituição financeira autorizada pela\nCVM para o exercício profissional de custódia de valores\nmobiliários por meio do Ato Declaratório CVM nº',
#   ' 1.085, de 30\nde agosto de 1989, com sede na cidade de São Paulo, Estado\nde São Paulo, na Avenida Paulista, nº 1.793, CEP 01311-200,\ninscrita no CNPJ sob o nº 62.232.889/0001-90, ou seu sucessor\na qualquer título;\nCVM: a Comissão de Valores Mobiliários;\nDia Útil: todo e qualquer dia que não seja sábado, domingo ou feriado\nnacional ou, ainda, dias em que, por qualquer motivo, não haja\nexpediente bancário ou dias em que não funcionar o mercado\nfinanceiro em âmbito nacional, na cidade São Paulo/SP;\nEncargos: despesas específicas que podem ser debitadas diretamente da\nClasse de Cotas, não estando inclusas nas taxas destinadas aos\nprestadores de serviços essenciais;\nEventos de Liquidação do Fundo: as situações descritas no Capítulo XIII da Parte Geral;\nFUNDO: o FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS\nCONCRÉDITO RESPONSABILIDADE ILIMITADA;\nGESTORA: CULTINVEST ASSET MANAGEMENT LTDA., sociedade\nautorizada pela CVM para o exercício profissional de\nadministração de carteiras de valores mob',
#   'iliários, na categoria\nde gestor de recursos, por meio do Ato Declaratório CVM nº\n11.321, de 8 de outubro de 2010, com sede na cidade de São\nPaulo, Estado de São Paulo, na Rua Afonso de Freitas, nº 559,\nconjunto 41, CEP 04006-052, inscrita no CNPJ sob o nº\n12.160.857/0001-58, ou sua sucessora a qualquer título;\nInstrução CVM 489: a Instrução CVM nº 489, de 14 de janeiro de 2011 e suas\nalterações;\nInvestidor Profissional: são os investidores profissionais, conforme definidos na\nResolução CVM 30;\nInvestidor Qualificado: são os investidores qualificados, conforme definidos na\nResolução CVM 30;\nManual de Provisionamento: é a Política Interna de Metodologias de Provisão de Perdas da\nADMINISTRADORA registrado junto a ANBIMA;\nOferta Automática: é toda e qualquer distribuição pública de Cotas sob o regime\ndo rito de registro automático de distribuição, nos termos da\nResolução CVM 160;\nOferta Ordinária: é toda e qualquer distribuição pública de Cotas sob o regime\ndo rito de registro ordinário d',
# ...
#   {'chunk_index': 149, 'source': 'Regulamento FIDC GVN (1).pdf'},
#   {'chunk_index': 150, 'source': 'Regulamento FIDC GVN (1).pdf'},
#   {'chunk_index': 151, 'source': 'Regulamento FIDC GVN (1).pdf'},
#   {'source': 'Regulamento FIDC GVN (1).pdf', 'chunk_index': 152},
#   {'source': 'Regulamento FIDC GVN (1).pdf', 'chunk_index': 153},
#   {'source': 'Regulamento FIDC GVN (1).pdf', 'chunk_index': 154},
#   {'chunk_index': 155, 'source': 'Regulamento FIDC GVN (1).pdf'},
#   {'source': 'Regulamento FIDC GVN (1).pdf', 'chunk_index': 156},
#   {'chunk_index': 157, 'source': 'Regulamento FIDC GVN (1).pdf'},
#   {'source': 'Regulamento FIDC GVN (1).pdf', 'chunk_index': 158},
#   {'chunk_index': 159, 'source': 'Regulamento FIDC GVN (1).pdf'},
#   {'chunk_index': 160, 'source': 'Regulamento FIDC GVN (1).pdf'},
#   {'chunk_index': 161, 'source': 'Regulamento FIDC GVN (1).pdf'},
#   {'source': 'Regulamento FIDC GVN (1).pdf', 'chunk_index': 162},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 0},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 1},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 2},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 3},
#   {'chunk_index': 4, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 5, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 6, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 7, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 8},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 9},
#   {'chunk_index': 10, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 11, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 12, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 13},
#   {'chunk_index': 14, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 15},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 16},
#   {'chunk_index': 17, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 18, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 19},
#   {'chunk_index': 20, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 21},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 22},
#   {'chunk_index': 23, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 24, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 25, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 26},
#   {'chunk_index': 27, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 28, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 29, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 30},
#   {'chunk_index': 31, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 32, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 33, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 34},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 35},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 36},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 37},
#   {'chunk_index': 38, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 39, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 40, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 41},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 42},
#   {'chunk_index': 43, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 44},
#   {'chunk_index': 45, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 46, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 47},
#   {'chunk_index': 48, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 49, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 50},
#   {'chunk_index': 51, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 52, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 53, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 54, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 55, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 56},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 57},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 58},
#   {'chunk_index': 59, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 60},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 61},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 62},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 63},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 64},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 65},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 66},
#   {'chunk_index': 67, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 68, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 69},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 70},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 71},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 72},
#   {'chunk_index': 73, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 74, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 75},
#   {'chunk_index': 76, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 77, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 78},
#   {'chunk_index': 79, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 80},
#   {'chunk_index': 81, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 82},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 83},
#   {'chunk_index': 84, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 85},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 86},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 87},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 88},
#   {'chunk_index': 89, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 90},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 91},
#   {'chunk_index': 92, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 93, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 94, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 95},
#   {'chunk_index': 96, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 97},
#   {'chunk_index': 98, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 99, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 100},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 101},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 102},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 103},
#   {'chunk_index': 104, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 105},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 106},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 107},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 108},
#   {'chunk_index': 109, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 110},
#   {'chunk_index': 111, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 112, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 113},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 114},
#   {'chunk_index': 115, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 116},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 117},
#   {'chunk_index': 118, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 119, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 120, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 121},
#   {'chunk_index': 122, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 123},
#   {'chunk_index': 124, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 125, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 126, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 127, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 128},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 129},
#   {'chunk_index': 130, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 131, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 132},
#   {'chunk_index': 133, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 134},
#   {'chunk_index': 135, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 136},
#   {'chunk_index': 137, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 138, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 139, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 140, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 141},
#   {'chunk_index': 142, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 143, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 144, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 145},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 146},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 147},
#   {'chunk_index': 148, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 149, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 150, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 151, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 152},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 153},
#   {'chunk_index': 154, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 155, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 156},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 157},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 158},
#   {'chunk_index': 159, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 160},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 161},
#   {'chunk_index': 162, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 163},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 164},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 165},
#   {'chunk_index': 166, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 167, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 168, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 169, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 170, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 171},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 172},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 173},
#   {'chunk_index': 174, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 175},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 176},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 177},
#   {'chunk_index': 178, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 179, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 180, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 181, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 182, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 183},
#   {'chunk_index': 184, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 185, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 186},
#   {'chunk_index': 187, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 188},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 189},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 190},
#   {'chunk_index': 191, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 192},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 193},
#   {'chunk_index': 194, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 195},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 196},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 197},
#   {'chunk_index': 198, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 199, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 200},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 201},
#   {'chunk_index': 202, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 203, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 204}]}

# %%
def count_tokens(text):
    return len(tokenizer.encode(text))

def split_document(document_text):
    documents = []
    for i in range(0, len(document_text), CHUNK_SIZE):
        start = i
        end = i + CHUNK_SIZE
        if start != 0:
            start = start - OFFSET
            end =  end - OFFSET
        documents.append(document_text[start: end])
    return documents

# Obtenção dos embeddings usando Langchain
def get_embedding_langchain(text):

    embedding = OpenAIEmbeddings(
        model= "text-embedding-3-small",
        chunk_size= CHUNK_SIZE
    )

    emb = embedding.embed_query(text)

    return emb

# Obtenção dos embeddings usando diretamente a API da OpenAI
def get_embedding_openai(text, client):

    emb = client.embeddings.create(
        input= text,
        model= "text-embedding-3-small"
    )

    return emb.data[0].embedding

# Extração de texto dos arquivos PDF
def extract_text_from_pdf(pdf_path):
    full_text = []

    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            full_text.append(page.extract_text() or "")

    return "\n".join(full_text)

# Extração das tabelas dos arquivos PDF
# Tabelas serão extraídas diferentemente dos blocos de texto
def extract_tables_from_pdf(pdf_path):
    data_list = []

    with pdfplumber.open(pdf_path) as pdf:
        for page_num, page in enumerate(pdf.pages):
            tables = page.extract_tables()
            for table in tables:
                df = pd.DataFrame(table[1:], columns=table[0])  # Usa a primeira linha como cabeçalho
                data_list.append(df)

    return data_list

# Guarda os dados extraidos dos documentos no ChromaDB
def insert_chromadb(data, source, client):

    chunks = split_document(data)

    print(chunks)

    for idx, chunk in enumerate(chunks):

        embedding = get_embedding_openai(chunk, client)

        collection.add(
            ids=[f"{source}_chunk_{idx}"],
            documents=[chunk],
            metadatas=[{"source": source, "chunk_index": idx}],
            embeddings=[embedding]
        )

# %%
def run():
    print("Preparando Documentos...")
    data_path = 'C:/Users/Lucas/Desktop/Repositories/SLRFIDC/Regulamentos'

    documents_names = [f for f in os.listdir(data_path) if f.endswith('.pdf')]
    documents_names_size = len(documents_names)

    for i, document_name in enumerate(documents_names):

        print(f"{i+1}/{documents_names_size}: {document_name}")

        doc_path = os.path.join(data_path, document_name)

        document_text = extract_text_from_pdf(os.path.join(data_path, document_name))
        if document_text.strip():
            insert_chromadb(document_text, document_name, openai_client)

        tables = extract_tables_from_pdf(doc_path)
        if tables:
            for idx, df in enumerate(tables):
                json_data = df.to_json(orient= "records")
                insert_chromadb(json_data, document_name, openai_client)

if __name__ == "__main__":
    run()
    pass
# Out:
# Preparando Documentos...
# 1/4: Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf
# ['REGULAMENTO\nDO\nFUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS CONCRÉDITO RESPONSABILIDADE\nILIMITADA\nCNPJ/MF Nº 52.511.329/0001-10\nVIGENTE A PARTIR DE 22 DEMARÇO DE 2024.\nREGULAMENTO DO\nFUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS CONCRÉDITO RESPONSABILIDADE\nILIMITADA\nPARTE GERAL\nCAPÍTULO I – DO FUNDO\nO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS CONCRÉDITO RESPONSABILIDADE\nILIMITADA\n1.1. é um fundo de investimento em direitos creditórios constituído sob a forma de\ncondomínio de natureza especial fechado, com prazo de duração indeterminado, regido pelo\npresente Regulamento (o “Regulamento”), pela Resolução CMN 2.907, pela Resolução CVM 175\ne pelas demais disposições legais e regulamentares que lhe forem aplicáveis.\n1.2. O exercício social do FUNDO tem duração de 01 (um) ano, com término em abril de cada\nano.\nCAPÍTULO II – DAS DEFINIÇÕES\n2.1. Sem prejuízo de definições específicas previstas nos Anexos das respectivas\nClasses, os termos e expressões previstos neste Regulamento, indicado', 'm abril de cada\nano.\nCAPÍTULO II – DAS DEFINIÇÕES\n2.1. Sem prejuízo de definições específicas previstas nos Anexos das respectivas\nClasses, os termos e expressões previstos neste Regulamento, indicados em letra maiúscula, no\nsingular ou no plural, terão os significados a seguir atribuídos:\nAcordo Operacional: É o acordo operacional celebrado entre a ADMINISTRADORA e\na GESTORA;\nADMINISTRADORA: BANCO DAYCOVAL S.A., instituição financeira autorizada pela\nCVM para o exercício profissional de administração de carteiras\nde valores mobiliários, na categoria de administrador\nfiduciário, por meio do Ato Declaratório CVM nº 17.552, de 5\nde dezembro de 2019, com sede na cidade de São Paulo,\nEstado de São Paulo, na Avenida Paulista, nº 1.793, CEP 01311-\n200, inscrita no CNPJ sob o nº 62.232.889/0001-90, ou quem\nlhe vier a suceder;\n“Alocação Mínima” Percentual mínimo de 67% (setenta e sete por cento) do\nPatrimônio Líquido a ser mantido em Direitos Creditórios\nCedidos, conforme definido pelo Conselh', 'o Monetário Nacional\ne Comissão de Valores Mobiliários\nANBIMA: é a Associação Brasileira das Entidades dos Mercados\nFinanceiro e de Capitais;\nAnexo(s): significa(m) a(s) parte(s) do Regulamento do FUNDO essenciais\nà constituição de Classes de Cotas, que regem o funcionamento\ndas Classes de modo complementar ao disciplinado pelo\nRegulamento;\nApêndices: partes do Anexo que disciplinam as características específicas\nde cada Subclasse de Cotas;\nApensos: partes do(s) Apêndice(s) que preveem os modelos de\nsuplementos das Subclasses;\nAssembleia Geral de Cotistas: significa a assembleia para a qual são convocados todos os\ncotistas do FUNDO;\nAssembleia Especial de Cotistas: significa a assembleia para a qual são convocados somente os\ncotistas de determinada Classe ou Subclasse de Cotas;\nAuditor Independente: é a empresa de auditoria independente contratada pela\nADMINISTRADORA, nos termos deste Regulamento, ou sua\nsucessora a qualquer título, encarregada da revisão das\ndemonstrações financeiras ', 'do FUNDO, das contas de cada\nClasse do FUNDO e da análise de sua situação e da atuação da\nADMINISTRADORA e da GESTORA;\nB3 é a B3 S.A. – Brasil, Bolsa, Balcão.\nBACEN: o Banco Central do Brasil;\nClasse: Significa cada classe de Cotas emitidas pelo FUNDO, que\npodem contar com direitos e obrigações distintos, devendo a\nADMINISTRADORA constituir um patrimônio segregado para\ncada classe de cotas;\nCMN: Conselho Monetário Nacional;\nConta da Classe: a conta corrente ou conta de pagamento de titularidade de\ncada Classe do FUNDO;\nCotas: todas as Cotas emitidas pelo FUNDO, independente de Classe,\nsubclasse ou Série;\nCotas Seniores: as cotas de subclasse sênior de quaisquer séries emitidas pelo\nFUNDO, que não se subordinam às demais classes de Cotas\npara efeito de amortização, resgate e distribuição de\nrendimentos da carteira do FUNDO;\nCotas Subordinadas: as Cotas Subordinadas Júnior e as Cotas Subordinadas\nM ...
# ['[{"Patrim\\u00f4nio L\\u00edquido":"De R$ 0 a R$ 250.000.000,00","Taxa (a.a.)":"0,13%"},{"Patrim\\u00f4nio L\\u00edquido":"De R$ 250.000.000,01 a R$ 500.000.000,00","Taxa (a.a.)":"0,11%"},{"Patrim\\u00f4nio L\\u00edquido":"De R$ 500.000.000,01 a R$ 750.000.000,00","Taxa (a.a.)":"0,09%"},{"Patrim\\u00f4nio L\\u00edquido":"R$ 750.000.000,01 a R$ 1.000.000.000,00","Taxa (a.a.)":"0,07%"},{"Patrim\\u00f4nio L\\u00edquido":"Acima de R$ 1.000.000.000,01","Taxa (a.a.)":"0,05%"}]']
# ['[{"Patrim\\u00f4nio L\\u00edquido":"De R$ 0 a R$ 300.000.000,00","Taxa (a.a.)":"0,63%"},{"Patrim\\u00f4nio L\\u00edquido":"De R$ 300.000.000,01 a R$ 500.000.000,00","Taxa (a.a.)":"0,50%"},{"Patrim\\u00f4nio L\\u00edquido":"Acima de R$ 500.000.000,00","Taxa (a.a.)":"0,40%"}]']
# ['[{"Valor Total das Cotas Efetivamente Integralizadas*":"De R$ 0 a R$ 300.000.000,00","Taxa (flat)":"1,20%"},{"Valor Total das Cotas Efetivamente Integralizadas*":"Acima de R$ 300.000.000,01","Taxa (flat)":"1%"}]']
# 2/4: PH FIDC FGTS_Regulamento_20230710_vf.pdf
# ['REGULAMENTO\nDO\nFUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS PH TECH\nCNPJ nº 51. 051.330/0001-47\n01 de dezembro de 2023\nSUMÁRIO\nCAPÍTULO I - DO FUNDO E DO PÚBLICO-ALVO ....................................................................... 3\nCAPÍTULO II - DO OBJETIVO DO FUNDO .................................................................................. 3\nCAPÍTULO III - DA POLÍTICA DE INVESTIMENTO, COMPOSIÇÃO E DIVERSIFICAÇÃO DA CARTEIRA\n......................................................................................................................................................... 3\nCAPÍTULO IV – DAS CONDIÇÕES DE CESSÃO/ENDOSSO E DOS CRITÉRIOS DE ELEGIBILIDADE\n.......................................................................................................................................................... 5\nCAPÍTULO V – DO PREÇO DE AQUISIÇÃO DOS DIREITOS CREDITÓRIOS............................ 6\nCAPÍTULO VI– DA POLÍTICA DE CONCESSÃO DE CRÉDITO .......................', '................................... 5\nCAPÍTULO V – DO PREÇO DE AQUISIÇÃO DOS DIREITOS CREDITÓRIOS............................ 6\nCAPÍTULO VI– DA POLÍTICA DE CONCESSÃO DE CRÉDITO ................................................... 6\nCAPÍTULO VII– DA POLÍTICA DE COBRANÇA DOS DIREITOS CREDITÓRIOS ...................... 7\nCAPÍTULO VIII – DAS CARACTERÍSITICAS DAS COTAS ........................................................... 7\nCAPÍTULO IX – DA AMORTIZAÇÃO DE COTAS ......................................................................... 9\nCAPÍTULO X – DAS SUBORDINAÇÃOS MÍNIMAS .................................................................... 10\nCAPÍTULO XI - DA ADMINISTRAÇÃO E DAS RESPONSABILIDADES DA ADMINISTRADORA 11\nCAPÍTULO XII – DA GESTÃO E DA POLÍTICA DE EXERCÍCIO DE DIREITO DE VOTO DA GESTORA\n........................................................................................................................................................ 14\nCAPÍTULO XIII –DO AGENTE DE COBRA', 'NÇA .......................................................................... 14\nCAPÍTULO XIV - DA CUSTÓDIA, CONTROLADORIA E ESCRITURAÇÃO ............................... 15\nCAPÍTULO XV – DA SUBSTITUIÇÃO DOS PRESTADORES DE SERVIÇOS ............................. 16\nCAPÍTULO XVI – DA TAXA DE ADMINISTRAÇÃO .................................................................... 16\nCAPÍTULO XVII – DA AVALIAÇÃO DOS ATIVOS E DO PATRIMÔNIO LÍQUIDO DO FUNDO18\nCAPÍTULO XVIII – DOS FATORES DE RISCO ............................................................................ 18\nCAPÍTULO XIX - DA ASSEMBLEIA GERAL ............................................................................... 33\nCAPÍTULO XX – DOS EVENTOS DE AVALIAÇÃO .................................................................... 36\nCAPÍTULO XXI – DA LIQUIDAÇÃO DO FUNDO ....................................................................... 37\nCAPÍTULO XXII – DA ORDEM DE APLICAÇÃO DOS RECUROS ......................................', '....... 39\nCAPÍTULO XXIII - DOS ENCARGOS DO FUNDO ...................................................................... 39\nCAPÍTULO XXIV - DA PUBLICIDADE E DA REMESSA DE DOCUMENTOS ........................... 40\nCAPÍTULO XXV – DO FORO ........................................................................................................ 41\nANEXO I – DEFINIÇÕES ............................................................................................................. 42\nANEXO II – DESCRIÇÃO DA NATUREZA DOS DIREITOS CREDITÓRIOS, DO PROCESSO DE\nORIGINAÇÃO DOS DIREITOS CREDITÓRIOS E DA POLÍTICA DE CONCESSÃO DE CRÉDITO PELO\nORIGINADOR .............................................................................................................................. 49\nANEXO III – POLÍTICA DE COBRANÇA DOS DIREITOS CREDITÓRIOS INADIMPLIDOS .. 50\nANEXO IV – PARÂMETROS PARA A VERIFICAÇÃO DO LASTRO POR AMOSTRAGEM ........52\nANEXO V – MODELO D ...
# ['[{"Patrim\\u00f4nio L\\u00edquido":"De R$ 0 a R$ 250.000.000,00","Taxa (a.a.)":"0,13%"},{"Patrim\\u00f4nio L\\u00edquido":"De R$ 250.000.000,01 a R$ 500.000.000,00","Taxa (a.a.)":"0,11%"},{"Patrim\\u00f4nio L\\u00edquido":"De R$ 500.000.000,01 a R$ 750.000.000,00","Taxa (a.a.)":"0,09%"},{"Patrim\\u00f4nio L\\u00edquido":"R$ 750.000.000,01 a R$ 1.000.000.000,00","Taxa (a.a.)":"0,07%"},{"Patrim\\u00f4nio L\\u00edquido":"Acima de R$ 1.000.000.000,01","Taxa (a.a.)":"0,05%"}]']
# ['[{"Valor Total das Cotas Efetivamente\\nIntegralizadas*":"De R$ 0 a R$ 100.000.000,00","Taxa (flat)":"1,20%"}]']
# 3/4: Regulamento FIDC GVN (1).pdf
# ['REGULAMENTO DO GVN FUNDO DE INVESTIMENTO EM DIREITOS\nCREDITÓRIOS\n08 de fevereiro de 2023\nO GVN Fundo de Investimento em Direitos Creditórios é um fundo de investimento em\ndireitos creditórios constituído sob a forma de condomínio de natureza especial,\ndisciplinado pela Resolução CMN nº 2.907/01 e pela Instrução CVM nº 356/01, e regido\npelo presente Regulamento e pelas demais disposições legais e regulamentares\naplicáveis.\nOs termos e expressões utilizados neste Regulamento iniciados por letra maiúscula têm\no significado a eles atribuído no Anexo I ao presente Regulamento, aplicável tanto no\nsingular quanto no plural.\n1. OBJETIVO\n1.1 O Fundo tem por objetivo proporcionar rendimentos aos Cotistas por\nmeio da aquisição, preponderantemente, de Direitos Creditórios que atendam à política\nde investimento, composição e diversificação da carteira do Fundo descrita no presente\nRegulamento.\n1.2 Para fins do disposto no Código ANBIMA de Regulação e Melhores\nPráticas para Administração de Recursos', 'estimento, composição e diversificação da carteira do Fundo descrita no presente\nRegulamento.\n1.2 Para fins do disposto no Código ANBIMA de Regulação e Melhores\nPráticas para Administração de Recursos de Terceiros, o Fundo é classificado como um\nfundo de investimento em direitos creditórios do tipo “Financeiro”, com foco de atuação\n“Crédito Pessoal”.\n2. FORMA DE CONSTITUIÇÃO E PÚBLICO-ALVO\n2.1 O Fundo é constituído sob a forma de condomínio fechado, de modo que\nas Cotas somente serão resgatadas ao término dos respectivos Prazos de Duração ou em\ncaso de liquidação do Fundo. Será permitida a amortização das Cotas nos termos da\ncláusula 16 do presente Regulamento.\n2.2 O Fundo é destinado a investidores profissionais, conforme definidos no\nartigo 11 da Resolução CVM nº 30/21, que busquem rentabilidade, no longo prazo,\ncompatível com a política de investimento, composição e diversificação de sua carteira e\nque aceitem os riscos associados aos investimentos realizados pelo Fundo.\n3. PRAZO DE', ' DURAÇÃO\n3.1 O funcionamento do Fundo terá início na primeira Data de Integralização\nInicial. O Fundo terá prazo indeterminado de duração.\n1\nBT - 2236/7 - 2137005v1\n4. ADMINISTRADORA\n4.1 O Fundo é administrado pelo Banco Daycoval S.A., instituição financeira\nautorizada pela CVM para o exercício profissional de administração de carteiras de\nvalores mobiliários, na categoria de administrador fiduciário, por meio do Ato\nDeclaratório CVM nº 17.552, de 5 de dezembro de 2019, com sede na cidade de São\nPaulo, Estado de São Paulo, na Avenida Paulista, nº 1.793, CEP 01311-200, inscrita no\nCNPJ sob o nº 62.232.889/0001-90.\n5. OBRIGAÇÕES, VEDAÇÕES E RESPONSABILIDADES DA\nADMINISTRADORA\n5.1 A Administradora, observadas as limitações estabelecidas neste\nRegulamento e nas disposições legais e regulamentares pertinentes, tem amplos e gerais\npoderes para praticar todos os atos necessários à administração do Fundo, bem como\npara exercer os direitos inerentes aos ativos de titularidade do Fundo, sem prej', 'uízo dos\ndireitos e obrigações de terceiros contratados para prestação de serviços ao Fundo.\n5.2 Sem prejuízo de outras obrigações legais e regulamentares a que a\nAdministradora está sujeita, a Administradora obriga-se a:\n(a) observar as obrigações e as vedações estabelecidas nos artigos 34 a 36 da\nInstrução CVM nº 356/01;\n(b) divulgar todas as informações exigidas pela regulamentação pertinente e por este\nRegulamento;\n(c) informar os Cotistas sobre eventual rebaixamento da classificação de risco das\nCotas Seniores ou das Cotas Subordinadas Mezanino, nos termos do presente\nRegulamento, conforme o disposto no artigo 46, §1º, inciso I, da Instrução CVM\nnº 356/01;\n(d) monitorar, nos termos previstos neste Regulamento:\n(1) o enquadramento da Alocação Mínima e da Relação Mínima;\n(2) a composição da Reserva de Despesas e Encargos; e\n(3) a ocorrência de qualquer dos Eventos de Avaliação ou dos Eventos de\nLiquidação ...
# ['[{"Faixa do Patrim\\u00f4nio L\\u00edquido":"At\\u00e9 R$250 milh\\u00f5es (inclusive)","Taxa (percentual ao ano)":"0,58% (cinquenta e oito cent\\u00e9simos por\\ncento)"},{"Faixa do Patrim\\u00f4nio L\\u00edquido":"De R$250 (exclusive) a 500 milh\\u00f5es\\n(inclusive)","Taxa (percentual ao ano)":"0,56% (cinquenta e seis cent\\u00e9simos por\\ncento)"},{"Faixa do Patrim\\u00f4nio L\\u00edquido":"De R$500 (exclusive) a 750 milh\\u00f5es\\n(inclusive)","Taxa (percentual ao ano)":"0,54% (cinquenta e quatro cent\\u00e9simos por\\ncento)"},{"Faixa do Patrim\\u00f4nio L\\u00edquido":"De R$750 milh\\u00f5es (exclusive) a 1\\nbilh\\u00e3o (inclusive)","Taxa (percentual ao ano)":"0,52% (cinquenta e dois cent\\u00e9simos por\\ncento)"},{"Faixa do Patrim\\u00f4nio L\\u00edquido":"Acima de R$1 bilh\\u00e3o","Taxa (percentual ao ano)":"0,5% (cinco d\\u00e9cimos por cento)"}]']
# ['[{"caso a raz\\u00e3o entre o total de Pr\\u00e9-Pagamento e o saldo devedor dos Direitos Credit\\u00f3rios":"Cedidos, apurados no \\u00faltimo Dia \\u00datil de cada m\\u00eas, seja superior a 1,7% (um inteiro e"},{"caso a raz\\u00e3o entre o total de Pr\\u00e9-Pagamento e o saldo devedor dos Direitos Credit\\u00f3rios":"sete d\\u00e9cimos por cento);"}]']
# 4/4: Regulamento Poupacred 24.04.2024.pdf
# ['REGULAMENTO DO\nFUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS POUPACRED RESPONSABILIDADE\nILIMITADA\nCNPJ/MF Nº 53.270.792/0001-80\nVigente a partir de 24/04/2024\nSUMÁRIO\nPARTE GERAL ................................................................................................................................ 4\nCAPÍTULO I – DO FUNDO .............................................................................................. 4\nCAPÍTULO II – DAS DEFINIÇÕES ..................................................................................... 4\nCAPÍTULO III - DO OBJETIVO DO FUNDO E DAS CLASSES DE COTAS .................................. 8\nCAPÍTULO IV – DOS PRESTADORES DE SERVIÇOS ESSENCIAIS DO FUNDO ......................... 8\nCAPÍTULO V – DOS DEMAIS PRESTADORES DE SERVIÇOS .............................................. 13\nDO FUNDO ............................................................................................................... 13\nCAPÍTULO VI – DAS RESPONSABILIDADES DOS PRESTA', '.......................... 13\nDO FUNDO ............................................................................................................... 13\nCAPÍTULO VI – DAS RESPONSABILIDADES DOS PRESTADORES DE SERVIÇO ..................... 14\nCAPÍTULO VII – DA SUBSTITUIÇÃO DOS PRESTADORES DE SERVIÇOS ESSENCIAIS ............ 14\nCAPÍTULO VIII - DA ASSEMBLEIA GERAL DE COTISTAS ................................................... 15\nCAPÍTULO IX – DOS ENCARGOS DO FUNDO ................................................................. 18\nCAPÍTULO X – DAS INFORMAÇÕES .............................................................................. 20\nCAPÍTULO XI – DA DIVULGAÇÃO DE INFORMAÇÕES ..................................................... 22\nCAPÍTULO XII – DAS DEMONSTRAÇÕES CONTÁBEIS E RELATÓRIOS DE AUDITORIA .......... 23\nCAPÍTULO XIII – DA LIQUIDAÇÃO DO FUNDO ............................................................... 23\nCAPÍTULO XIV – DO FORO .........................................', '................................................. 23\nANEXO I ....................................................................................................................................... 25\nCARACTERÍSTICAS DA ÚNICA CLASSE ........................................................................................ 25\nI – DO PÚBLICO-ALVO E DA RESPONSABILIDADE DOS COTISTAS .................................... 25\nII – DO REGIME DA CLASSE ......................................................................................... 25\nIII – DO PRAZO DE DURAÇÃO ..................................................................................... 25\nIV – DAS DEFINIÇÕES ................................................................................................. 25\nV – DA POLÍTICA DE INVESTIMENTOS .......................................................................... 28\nVI – DAS CONDIÇÕES DE ENDOSSO E DOS CRITÉRIOS DE ELEGIBILIDADE ........................ 31\nCAPÍTULO VII – DOS PRESTA', 'DORES DE SERVIÇOS ESPECÍFICOS DA CLASSE ..................... 32\nVIII – DA NATUREZA, DOS PROCESSOS DE ORIGINAÇÃO DOS DIREITOS CREDITÓRIOS E DA\nPOLÍTICA DE CONCESSÃO DE CRÉDITO ........................................................................ 33\nIX – DA POLÍTICA DE COBRANÇA DOS DIREITOS CREDITÓRIOS ELEGÍVEIS E DOS DIREITOS\nCREDITÓRIOS INADIMPLIDOS ..................................................................................... 33\nX – DA VERIFICAÇÃO DE LASTRO ................................................................................. 35\nXI – DAS TAXAS ......................................................................................................... 35\nXII – DAS SUBORDINAÇÕES MÍNIMAS ......................................................................... 37\nXIII - DA ASSEMBLEIA ESPECIAL DE COTISTAS DA CLASSE, DA FORMA DE COMUNICAÇÃO\nDA ADMINISTRADORA E DOS PROCEDIMENTOS APLICÁVEIS ÀS MANIFESTAÇÕES DE\nVONTAD ...
# ['[{"Patrim\\u00f4nio L\\u00edquido":"De R$ 0 a R$ 250.000.000,00","Taxa (a.a.)":"0,13%"},{"Patrim\\u00f4nio L\\u00edquido":"De R$ 250.000.000,01 a R$ 500.000.000,00","Taxa (a.a.)":"0,11%"},{"Patrim\\u00f4nio L\\u00edquido":"De R$ 500.000.000,01 a R$ 750.000.000,00","Taxa (a.a.)":"0,09%"},{"Patrim\\u00f4nio L\\u00edquido":"R$ 750.000.000,01 a R$ 1.000.000.000,00","Taxa (a.a.)":"0,07%"},{"Patrim\\u00f4nio L\\u00edquido":"Acima de R$ 1.000.000.000,01","Taxa (a.a.)":"0,05%"}]']
# ['[{"Patrim\\u00f4nio L\\u00edquido":"De R$ 0 a R$ 300.000.000,00","Taxa (a.a.)":"0,63%"},{"Patrim\\u00f4nio L\\u00edquido":"De R$ 300.000.000,01 a R$ 500.000.000,00","Taxa (a.a.)":"0,50%"},{"Patrim\\u00f4nio L\\u00edquido":"Acima de R$ 500.000.000,01","Taxa (a.a.)":"0,40%"}]']
# ['[{"Valor Total das Cotas Efetivamente Integralizadas*":"De R$ 0 a R$ 300.000.000,00","Taxa (flat)":"1,20%"},{"Valor Total das Cotas Efetivamente Integralizadas*":"Acima de R$ 300.000.000,01","Taxa (flat)":"1%"}]']

# %%
# Checa todo o conteúdo inserido no ChromaDB
collection.get()
# Out:
# {'ids': ['Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_0',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_1',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_2',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_3',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_4',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_5',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_6',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_7',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_8',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_9',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_10',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_11',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_12',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_13',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_14',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_15',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_16',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_17',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_18',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_19',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_20',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_21',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_22',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_23',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_24',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_25',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_26',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_27',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_28',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_29',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_30',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_31',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_32',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_33',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_34',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_35',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_36',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_37',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_38',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_39',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_40',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_41',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_42',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_43',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_44',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_45',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_46',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_47',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_48',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_49',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_50',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_51',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_52',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_53',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_54',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_55',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_56',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_57',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_58',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_59',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_60',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_61',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_62',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_63',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_64',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_65',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_66',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_67',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_68',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_69',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_70',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_71',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_72',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_73',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_74',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_75',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_76',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_77',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_78',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_79',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_80',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_81',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_82',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_83',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_84',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_85',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_86',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_87',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_88',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_89',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_90',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_91',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_92',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_93',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_94',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_95',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_96',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_97',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_98',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_99',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_100',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_101',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_102',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_103',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_104',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_105',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_106',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_107',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_108',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_109',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_110',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_111',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_112',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_113',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_114',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_115',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_116',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_117',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_118',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_119',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_120',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_121',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_122',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_123',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_124',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_125',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_126',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_127',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_128',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_129',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_130',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_131',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_132',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_133',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_134',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_135',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_136',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_137',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_138',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_139',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_140',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_141',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_142',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_143',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_144',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_145',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_146',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_147',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_148',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_149',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_150',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_151',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_152',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_153',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_154',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_155',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_156',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_157',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_158',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_159',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_160',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_161',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_162',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_163',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_164',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_165',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_166',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_167',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_168',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_169',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_170',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_171',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_172',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_173',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_174',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_175',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_176',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_177',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_178',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_179',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_180',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_181',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_182',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_183',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_184',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_185',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_186',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_187',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_188',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_189',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_190',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_191',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_192',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_193',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_194',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_195',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_196',
#   'Concrédito_FIDC_Regulamento 22032024 (limpo VF).pdf_chunk_197',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_0',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_1',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_2',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_3',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_4',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_5',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_6',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_7',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_8',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_9',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_10',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_11',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_12',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_13',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_14',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_15',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_16',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_17',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_18',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_19',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_20',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_21',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_22',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_23',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_24',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_25',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_26',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_27',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_28',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_29',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_30',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_31',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_32',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_33',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_34',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_35',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_36',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_37',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_38',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_39',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_40',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_41',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_42',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_43',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_44',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_45',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_46',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_47',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_48',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_49',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_50',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_51',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_52',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_53',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_54',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_55',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_56',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_57',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_58',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_59',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_60',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_61',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_62',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_63',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_64',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_65',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_66',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_67',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_68',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_69',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_70',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_71',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_72',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_73',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_74',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_75',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_76',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_77',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_78',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_79',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_80',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_81',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_82',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_83',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_84',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_85',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_86',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_87',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_88',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_89',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_90',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_91',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_92',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_93',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_94',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_95',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_96',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_97',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_98',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_99',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_100',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_101',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_102',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_103',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_104',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_105',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_106',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_107',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_108',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_109',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_110',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_111',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_112',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_113',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_114',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_115',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_116',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_117',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_118',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_119',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_120',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_121',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_122',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_123',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_124',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_125',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_126',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_127',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_128',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_129',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_130',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_131',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_132',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_133',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_134',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_135',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_136',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_137',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_138',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_139',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_140',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_141',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_142',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_143',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_144',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_145',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_146',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_147',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_148',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_149',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_150',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_151',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_152',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_153',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_154',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_155',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_156',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_157',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_158',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_159',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_160',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_161',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_162',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_163',
#   'PH FIDC FGTS_Regulamento_20230710_vf.pdf_chunk_164',
#   'Regulamento FIDC GVN (1).pdf_chunk_0',
#   'Regulamento FIDC GVN (1).pdf_chunk_1',
#   'Regulamento FIDC GVN (1).pdf_chunk_2',
#   'Regulamento FIDC GVN (1).pdf_chunk_3',
#   'Regulamento FIDC GVN (1).pdf_chunk_4',
#   'Regulamento FIDC GVN (1).pdf_chunk_5',
#   'Regulamento FIDC GVN (1).pdf_chunk_6',
#   'Regulamento FIDC GVN (1).pdf_chunk_7',
#   'Regulamento FIDC GVN (1).pdf_chunk_8',
#   'Regulamento FIDC GVN (1).pdf_chunk_9',
#   'Regulamento FIDC GVN (1).pdf_chunk_10',
#   'Regulamento FIDC GVN (1).pdf_chunk_11',
#   'Regulamento FIDC GVN (1).pdf_chunk_12',
#   'Regulamento FIDC GVN (1).pdf_chunk_13',
#   'Regulamento FIDC GVN (1).pdf_chunk_14',
#   'Regulamento FIDC GVN (1).pdf_chunk_15',
#   'Regulamento FIDC GVN (1).pdf_chunk_16',
#   'Regulamento FIDC GVN (1).pdf_chunk_17',
#   'Regulamento FIDC GVN (1).pdf_chunk_18',
#   'Regulamento FIDC GVN (1).pdf_chunk_19',
#   'Regulamento FIDC GVN (1).pdf_chunk_20',
#   'Regulamento FIDC GVN (1).pdf_chunk_21',
#   'Regulamento FIDC GVN (1).pdf_chunk_22',
#   'Regulamento FIDC GVN (1).pdf_chunk_23',
#   'Regulamento FIDC GVN (1).pdf_chunk_24',
#   'Regulamento FIDC GVN (1).pdf_chunk_25',
#   'Regulamento FIDC GVN (1).pdf_chunk_26',
#   'Regulamento FIDC GVN (1).pdf_chunk_27',
#   'Regulamento FIDC GVN (1).pdf_chunk_28',
#   'Regulamento FIDC GVN (1).pdf_chunk_29',
#   'Regulamento FIDC GVN (1).pdf_chunk_30',
#   'Regulamento FIDC GVN (1).pdf_chunk_31',
#   'Regulamento FIDC GVN (1).pdf_chunk_32',
#   'Regulamento FIDC GVN (1).pdf_chunk_33',
#   'Regulamento FIDC GVN (1).pdf_chunk_34',
#   'Regulamento FIDC GVN (1).pdf_chunk_35',
#   'Regulamento FIDC GVN (1).pdf_chunk_36',
#   'Regulamento FIDC GVN (1).pdf_chunk_37',
#   'Regulamento FIDC GVN (1).pdf_chunk_38',
#   'Regulamento FIDC GVN (1).pdf_chunk_39',
#   'Regulamento FIDC GVN (1).pdf_chunk_40',
#   'Regulamento FIDC GVN (1).pdf_chunk_41',
#   'Regulamento FIDC GVN (1).pdf_chunk_42',
#   'Regulamento FIDC GVN (1).pdf_chunk_43',
#   'Regulamento FIDC GVN (1).pdf_chunk_44',
#   'Regulamento FIDC GVN (1).pdf_chunk_45',
#   'Regulamento FIDC GVN (1).pdf_chunk_46',
#   'Regulamento FIDC GVN (1).pdf_chunk_47',
#   'Regulamento FIDC GVN (1).pdf_chunk_48',
#   'Regulamento FIDC GVN (1).pdf_chunk_49',
#   'Regulamento FIDC GVN (1).pdf_chunk_50',
#   'Regulamento FIDC GVN (1).pdf_chunk_51',
#   'Regulamento FIDC GVN (1).pdf_chunk_52',
#   'Regulamento FIDC GVN (1).pdf_chunk_53',
#   'Regulamento FIDC GVN (1).pdf_chunk_54',
#   'Regulamento FIDC GVN (1).pdf_chunk_55',
#   'Regulamento FIDC GVN (1).pdf_chunk_56',
#   'Regulamento FIDC GVN (1).pdf_chunk_57',
#   'Regulamento FIDC GVN (1).pdf_chunk_58',
#   'Regulamento FIDC GVN (1).pdf_chunk_59',
#   'Regulamento FIDC GVN (1).pdf_chunk_60',
#   'Regulamento FIDC GVN (1).pdf_chunk_61',
#   'Regulamento FIDC GVN (1).pdf_chunk_62',
#   'Regulamento FIDC GVN (1).pdf_chunk_63',
#   'Regulamento FIDC GVN (1).pdf_chunk_64',
#   'Regulamento FIDC GVN (1).pdf_chunk_65',
#   'Regulamento FIDC GVN (1).pdf_chunk_66',
#   'Regulamento FIDC GVN (1).pdf_chunk_67',
#   'Regulamento FIDC GVN (1).pdf_chunk_68',
#   'Regulamento FIDC GVN (1).pdf_chunk_69',
#   'Regulamento FIDC GVN (1).pdf_chunk_70',
#   'Regulamento FIDC GVN (1).pdf_chunk_71',
#   'Regulamento FIDC GVN (1).pdf_chunk_72',
#   'Regulamento FIDC GVN (1).pdf_chunk_73',
#   'Regulamento FIDC GVN (1).pdf_chunk_74',
#   'Regulamento FIDC GVN (1).pdf_chunk_75',
#   'Regulamento FIDC GVN (1).pdf_chunk_76',
#   'Regulamento FIDC GVN (1).pdf_chunk_77',
#   'Regulamento FIDC GVN (1).pdf_chunk_78',
#   'Regulamento FIDC GVN (1).pdf_chunk_79',
#   'Regulamento FIDC GVN (1).pdf_chunk_80',
#   'Regulamento FIDC GVN (1).pdf_chunk_81',
#   'Regulamento FIDC GVN (1).pdf_chunk_82',
#   'Regulamento FIDC GVN (1).pdf_chunk_83',
#   'Regulamento FIDC GVN (1).pdf_chunk_84',
#   'Regulamento FIDC GVN (1).pdf_chunk_85',
#   'Regulamento FIDC GVN (1).pdf_chunk_86',
#   'Regulamento FIDC GVN (1).pdf_chunk_87',
#   'Regulamento FIDC GVN (1).pdf_chunk_88',
#   'Regulamento FIDC GVN (1).pdf_chunk_89',
#   'Regulamento FIDC GVN (1).pdf_chunk_90',
#   'Regulamento FIDC GVN (1).pdf_chunk_91',
#   'Regulamento FIDC GVN (1).pdf_chunk_92',
#   'Regulamento FIDC GVN (1).pdf_chunk_93',
#   'Regulamento FIDC GVN (1).pdf_chunk_94',
#   'Regulamento FIDC GVN (1).pdf_chunk_95',
#   'Regulamento FIDC GVN (1).pdf_chunk_96',
#   'Regulamento FIDC GVN (1).pdf_chunk_97',
#   'Regulamento FIDC GVN (1).pdf_chunk_98',
#   'Regulamento FIDC GVN (1).pdf_chunk_99',
#   'Regulamento FIDC GVN (1).pdf_chunk_100',
#   'Regulamento FIDC GVN (1).pdf_chunk_101',
#   'Regulamento FIDC GVN (1).pdf_chunk_102',
#   'Regulamento FIDC GVN (1).pdf_chunk_103',
#   'Regulamento FIDC GVN (1).pdf_chunk_104',
#   'Regulamento FIDC GVN (1).pdf_chunk_105',
#   'Regulamento FIDC GVN (1).pdf_chunk_106',
#   'Regulamento FIDC GVN (1).pdf_chunk_107',
#   'Regulamento FIDC GVN (1).pdf_chunk_108',
#   'Regulamento FIDC GVN (1).pdf_chunk_109',
#   'Regulamento FIDC GVN (1).pdf_chunk_110',
#   'Regulamento FIDC GVN (1).pdf_chunk_111',
#   'Regulamento FIDC GVN (1).pdf_chunk_112',
#   'Regulamento FIDC GVN (1).pdf_chunk_113',
#   'Regulamento FIDC GVN (1).pdf_chunk_114',
#   'Regulamento FIDC GVN (1).pdf_chunk_115',
#   'Regulamento FIDC GVN (1).pdf_chunk_116',
#   'Regulamento FIDC GVN (1).pdf_chunk_117',
#   'Regulamento FIDC GVN (1).pdf_chunk_118',
#   'Regulamento FIDC GVN (1).pdf_chunk_119',
#   'Regulamento FIDC GVN (1).pdf_chunk_120',
#   'Regulamento FIDC GVN (1).pdf_chunk_121',
#   'Regulamento FIDC GVN (1).pdf_chunk_122',
#   'Regulamento FIDC GVN (1).pdf_chunk_123',
#   'Regulamento FIDC GVN (1).pdf_chunk_124',
#   'Regulamento FIDC GVN (1).pdf_chunk_125',
#   'Regulamento FIDC GVN (1).pdf_chunk_126',
#   'Regulamento FIDC GVN (1).pdf_chunk_127',
#   'Regulamento FIDC GVN (1).pdf_chunk_128',
#   'Regulamento FIDC GVN (1).pdf_chunk_129',
#   'Regulamento FIDC GVN (1).pdf_chunk_130',
#   'Regulamento FIDC GVN (1).pdf_chunk_131',
#   'Regulamento FIDC GVN (1).pdf_chunk_132',
#   'Regulamento FIDC GVN (1).pdf_chunk_133',
#   'Regulamento FIDC GVN (1).pdf_chunk_134',
#   'Regulamento FIDC GVN (1).pdf_chunk_135',
#   'Regulamento FIDC GVN (1).pdf_chunk_136',
#   'Regulamento FIDC GVN (1).pdf_chunk_137',
#   'Regulamento FIDC GVN (1).pdf_chunk_138',
#   'Regulamento FIDC GVN (1).pdf_chunk_139',
#   'Regulamento FIDC GVN (1).pdf_chunk_140',
#   'Regulamento FIDC GVN (1).pdf_chunk_141',
#   'Regulamento FIDC GVN (1).pdf_chunk_142',
#   'Regulamento FIDC GVN (1).pdf_chunk_143',
#   'Regulamento FIDC GVN (1).pdf_chunk_144',
#   'Regulamento FIDC GVN (1).pdf_chunk_145',
#   'Regulamento FIDC GVN (1).pdf_chunk_146',
#   'Regulamento FIDC GVN (1).pdf_chunk_147',
#   'Regulamento FIDC GVN (1).pdf_chunk_148',
#   'Regulamento FIDC GVN (1).pdf_chunk_149',
#   'Regulamento FIDC GVN (1).pdf_chunk_150',
#   'Regulamento FIDC GVN (1).pdf_chunk_151',
#   'Regulamento FIDC GVN (1).pdf_chunk_152',
#   'Regulamento FIDC GVN (1).pdf_chunk_153',
#   'Regulamento FIDC GVN (1).pdf_chunk_154',
#   'Regulamento FIDC GVN (1).pdf_chunk_155',
#   'Regulamento FIDC GVN (1).pdf_chunk_156',
#   'Regulamento FIDC GVN (1).pdf_chunk_157',
#   'Regulamento FIDC GVN (1).pdf_chunk_158',
#   'Regulamento FIDC GVN (1).pdf_chunk_159',
#   'Regulamento FIDC GVN (1).pdf_chunk_160',
#   'Regulamento FIDC GVN (1).pdf_chunk_161',
#   'Regulamento FIDC GVN (1).pdf_chunk_162',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_0',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_1',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_2',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_3',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_4',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_5',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_6',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_7',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_8',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_9',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_10',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_11',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_12',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_13',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_14',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_15',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_16',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_17',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_18',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_19',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_20',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_21',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_22',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_23',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_24',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_25',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_26',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_27',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_28',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_29',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_30',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_31',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_32',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_33',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_34',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_35',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_36',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_37',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_38',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_39',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_40',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_41',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_42',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_43',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_44',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_45',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_46',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_47',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_48',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_49',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_50',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_51',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_52',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_53',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_54',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_55',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_56',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_57',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_58',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_59',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_60',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_61',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_62',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_63',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_64',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_65',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_66',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_67',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_68',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_69',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_70',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_71',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_72',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_73',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_74',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_75',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_76',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_77',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_78',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_79',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_80',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_81',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_82',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_83',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_84',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_85',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_86',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_87',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_88',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_89',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_90',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_91',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_92',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_93',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_94',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_95',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_96',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_97',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_98',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_99',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_100',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_101',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_102',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_103',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_104',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_105',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_106',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_107',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_108',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_109',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_110',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_111',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_112',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_113',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_114',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_115',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_116',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_117',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_118',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_119',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_120',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_121',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_122',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_123',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_124',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_125',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_126',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_127',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_128',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_129',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_130',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_131',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_132',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_133',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_134',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_135',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_136',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_137',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_138',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_139',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_140',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_141',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_142',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_143',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_144',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_145',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_146',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_147',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_148',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_149',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_150',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_151',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_152',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_153',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_154',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_155',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_156',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_157',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_158',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_159',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_160',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_161',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_162',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_163',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_164',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_165',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_166',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_167',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_168',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_169',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_170',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_171',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_172',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_173',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_174',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_175',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_176',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_177',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_178',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_179',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_180',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_181',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_182',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_183',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_184',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_185',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_186',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_187',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_188',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_189',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_190',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_191',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_192',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_193',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_194',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_195',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_196',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_197',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_198',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_199',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_200',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_201',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_202',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_203',
#   'Regulamento Poupacred 24.04.2024.pdf_chunk_204'],
#  'embeddings': None,
#  'documents': ['REGULAMENTO\nDO\nFUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS CONCRÉDITO RESPONSABILIDADE\nILIMITADA\nCNPJ/MF Nº 52.511.329/0001-10\nVIGENTE A PARTIR DE 22 DEMARÇO DE 2024.\nREGULAMENTO DO\nFUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS CONCRÉDITO RESPONSABILIDADE\nILIMITADA\nPARTE GERAL\nCAPÍTULO I – DO FUNDO\nO FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS CONCRÉDITO RESPONSABILIDADE\nILIMITADA\n1.1. é um fundo de investimento em direitos creditórios constituído sob a forma de\ncondomínio de natureza especial fechado, com prazo de duração indeterminado, regido pelo\npresente Regulamento (o “Regulamento”), pela Resolução CMN 2.907, pela Resolução CVM 175\ne pelas demais disposições legais e regulamentares que lhe forem aplicáveis.\n1.2. O exercício social do FUNDO tem duração de 01 (um) ano, com término em abril de cada\nano.\nCAPÍTULO II – DAS DEFINIÇÕES\n2.1. Sem prejuízo de definições específicas previstas nos Anexos das respectivas\nClasses, os termos e expressões previstos neste Regulamento, indicado',
#   'm abril de cada\nano.\nCAPÍTULO II – DAS DEFINIÇÕES\n2.1. Sem prejuízo de definições específicas previstas nos Anexos das respectivas\nClasses, os termos e expressões previstos neste Regulamento, indicados em letra maiúscula, no\nsingular ou no plural, terão os significados a seguir atribuídos:\nAcordo Operacional: É o acordo operacional celebrado entre a ADMINISTRADORA e\na GESTORA;\nADMINISTRADORA: BANCO DAYCOVAL S.A., instituição financeira autorizada pela\nCVM para o exercício profissional de administração de carteiras\nde valores mobiliários, na categoria de administrador\nfiduciário, por meio do Ato Declaratório CVM nº 17.552, de 5\nde dezembro de 2019, com sede na cidade de São Paulo,\nEstado de São Paulo, na Avenida Paulista, nº 1.793, CEP 01311-\n200, inscrita no CNPJ sob o nº 62.232.889/0001-90, ou quem\nlhe vier a suceder;\n“Alocação Mínima” Percentual mínimo de 67% (setenta e sete por cento) do\nPatrimônio Líquido a ser mantido em Direitos Creditórios\nCedidos, conforme definido pelo Conselh',
#   'o Monetário Nacional\ne Comissão de Valores Mobiliários\nANBIMA: é a Associação Brasileira das Entidades dos Mercados\nFinanceiro e de Capitais;\nAnexo(s): significa(m) a(s) parte(s) do Regulamento do FUNDO essenciais\nà constituição de Classes de Cotas, que regem o funcionamento\ndas Classes de modo complementar ao disciplinado pelo\nRegulamento;\nApêndices: partes do Anexo que disciplinam as características específicas\nde cada Subclasse de Cotas;\nApensos: partes do(s) Apêndice(s) que preveem os modelos de\nsuplementos das Subclasses;\nAssembleia Geral de Cotistas: significa a assembleia para a qual são convocados todos os\ncotistas do FUNDO;\nAssembleia Especial de Cotistas: significa a assembleia para a qual são convocados somente os\ncotistas de determinada Classe ou Subclasse de Cotas;\nAuditor Independente: é a empresa de auditoria independente contratada pela\nADMINISTRADORA, nos termos deste Regulamento, ou sua\nsucessora a qualquer título, encarregada da revisão das\ndemonstrações financeiras ',
#   'do FUNDO, das contas de cada\nClasse do FUNDO e da análise de sua situação e da atuação da\nADMINISTRADORA e da GESTORA;\nB3 é a B3 S.A. – Brasil, Bolsa, Balcão.\nBACEN: o Banco Central do Brasil;\nClasse: Significa cada classe de Cotas emitidas pelo FUNDO, que\npodem contar com direitos e obrigações distintos, devendo a\nADMINISTRADORA constituir um patrimônio segregado para\ncada classe de cotas;\nCMN: Conselho Monetário Nacional;\nConta da Classe: a conta corrente ou conta de pagamento de titularidade de\ncada Classe do FUNDO;\nCotas: todas as Cotas emitidas pelo FUNDO, independente de Classe,\nsubclasse ou Série;\nCotas Seniores: as cotas de subclasse sênior de quaisquer séries emitidas pelo\nFUNDO, que não se subordinam às demais classes de Cotas\npara efeito de amortização, resgate e distribuição de\nrendimentos da carteira do FUNDO;\nCotas Subordinadas: as Cotas Subordinadas Júnior e as Cotas Subordinadas\nMezanino, quando referidas em conjunto;\nCotas Subordinadas Júnior: as cotas de subclasse sub',
#   'ordinada emitidas pelo FUNDO, que\nse subordinam às Cotas Seniores para efeito de amortização,\nresgate e distribuição de rendimentos da carteira do FUNDO;\nCotas Subordinadas Mezanino: as cotas de subclasse subordinada mezanino de quaisquer\nséries emitidas pelo FUNDO, que se subordinam às Cotas\nSeniores e que têm prioridade em relação às Cotas\nSubordinadas Junior para efeito de amortização, resgate e\ndistribuição dos rendimentos da carteira do FUNDO;\nCotista: o investidor que venha adquirir Cotas de emissão do FUNDO;\nCotista Sênior: o investidor que venha adquirir Cotas Seniores de emissão do\nFUNDO;\nCotista Subordinado Júnior: o investidor que venha adquirir Cotas Subordinadas Júnior de\nemissão do FUNDO;\nCotista Subordinado Mezanino: o investidor que venha adquirir Cotas Subordinadas Mezanino\nde emissão do FUNDO;\nCUSTODIANTE: BANCO DAYCOVAL S.A., instituição financeira autorizada pela\nCVM para o exercício profissional de custódia de valores\nmobiliários por meio do Ato Declaratório CVM nº',
#   ' 1.085, de 30\nde agosto de 1989, com sede na cidade de São Paulo, Estado\nde São Paulo, na Avenida Paulista, nº 1.793, CEP 01311-200,\ninscrita no CNPJ sob o nº 62.232.889/0001-90, ou seu sucessor\na qualquer título;\nCVM: a Comissão de Valores Mobiliários;\nDia Útil: todo e qualquer dia que não seja sábado, domingo ou feriado\nnacional ou, ainda, dias em que, por qualquer motivo, não haja\nexpediente bancário ou dias em que não funcionar o mercado\nfinanceiro em âmbito nacional, na cidade São Paulo/SP;\nEncargos: despesas específicas que podem ser debitadas diretamente da\nClasse de Cotas, não estando inclusas nas taxas destinadas aos\nprestadores de serviços essenciais;\nEventos de Liquidação do Fundo: as situações descritas no Capítulo XIII da Parte Geral;\nFUNDO: o FUNDO DE INVESTIMENTO EM DIREITOS CREDITÓRIOS\nCONCRÉDITO RESPONSABILIDADE ILIMITADA;\nGESTORA: CULTINVEST ASSET MANAGEMENT LTDA., sociedade\nautorizada pela CVM para o exercício profissional de\nadministração de carteiras de valores mob',
#   'iliários, na categoria\nde gestor de recursos, por meio do Ato Declaratório CVM nº\n11.321, de 8 de outubro de 2010, com sede na cidade de São\nPaulo, Estado de São Paulo, na Rua Afonso de Freitas, nº 559,\nconjunto 41, CEP 04006-052, inscrita no CNPJ sob o nº\n12.160.857/0001-58, ou sua sucessora a qualquer título;\nInstrução CVM 489: a Instrução CVM nº 489, de 14 de janeiro de 2011 e suas\nalterações;\nInvestidor Profissional: são os investidores profissionais, conforme definidos na\nResolução CVM 30;\nInvestidor Qualificado: são os investidores qualificados, conforme definidos na\nResolução CVM 30;\nManual de Provisionamento: é a Política Interna de Metodologias de Provisão de Perdas da\nADMINISTRADORA registrado junto a ANBIMA;\nOferta Automática: é toda e qualquer distribuição pública de Cotas sob o regime\ndo rito de registro automático de distribuição, nos termos da\nResolução CVM 160;\nOferta Ordinária: é toda e qualquer distribuição pública de Cotas sob o regime\ndo rito de registro ordinário d',
# ...
#   {'chunk_index': 149, 'source': 'Regulamento FIDC GVN (1).pdf'},
#   {'chunk_index': 150, 'source': 'Regulamento FIDC GVN (1).pdf'},
#   {'source': 'Regulamento FIDC GVN (1).pdf', 'chunk_index': 151},
#   {'source': 'Regulamento FIDC GVN (1).pdf', 'chunk_index': 152},
#   {'source': 'Regulamento FIDC GVN (1).pdf', 'chunk_index': 153},
#   {'chunk_index': 154, 'source': 'Regulamento FIDC GVN (1).pdf'},
#   {'source': 'Regulamento FIDC GVN (1).pdf', 'chunk_index': 155},
#   {'source': 'Regulamento FIDC GVN (1).pdf', 'chunk_index': 156},
#   {'source': 'Regulamento FIDC GVN (1).pdf', 'chunk_index': 157},
#   {'chunk_index': 158, 'source': 'Regulamento FIDC GVN (1).pdf'},
#   {'chunk_index': 159, 'source': 'Regulamento FIDC GVN (1).pdf'},
#   {'chunk_index': 160, 'source': 'Regulamento FIDC GVN (1).pdf'},
#   {'source': 'Regulamento FIDC GVN (1).pdf', 'chunk_index': 161},
#   {'source': 'Regulamento FIDC GVN (1).pdf', 'chunk_index': 162},
#   {'chunk_index': 0, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 1},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 2},
#   {'chunk_index': 3, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 4},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 5},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 6},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 7},
#   {'chunk_index': 8, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 9, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 10},
#   {'chunk_index': 11, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 12, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 13, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 14},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 15},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 16},
#   {'chunk_index': 17, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 18, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 19},
#   {'chunk_index': 20, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 21},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 22},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 23},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 24},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 25},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 26},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 27},
#   {'chunk_index': 28, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 29, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 30},
#   {'chunk_index': 31, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 32, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 33, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 34, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 35, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 36},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 37},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 38},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 39},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 40},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 41},
#   {'chunk_index': 42, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 43},
#   {'chunk_index': 44, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 45, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 46, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 47},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 48},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 49},
#   {'chunk_index': 50, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 51},
#   {'chunk_index': 52, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 53},
#   {'chunk_index': 54, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 55},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 56},
#   {'chunk_index': 57, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 58, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 59},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 60},
#   {'chunk_index': 61, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 62},
#   {'chunk_index': 63, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 64},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 65},
#   {'chunk_index': 66, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 67},
#   {'chunk_index': 68, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 69},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 70},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 71},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 72},
#   {'chunk_index': 73, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 74, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 75, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 76, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 77},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 78},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 79},
#   {'chunk_index': 80, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 81, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 82, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 83},
#   {'chunk_index': 84, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 85},
#   {'chunk_index': 86, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 87},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 88},
#   {'chunk_index': 89, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 90, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 91, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 92, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 93},
#   {'chunk_index': 94, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 95},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 96},
#   {'chunk_index': 97, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 98, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 99, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 100, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 101},
#   {'chunk_index': 102, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 103},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 104},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 105},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 106},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 107},
#   {'chunk_index': 108, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 109, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 110},
#   {'chunk_index': 111, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 112},
#   {'chunk_index': 113, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 114},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 115},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 116},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 117},
#   {'chunk_index': 118, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 119},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 120},
#   {'chunk_index': 121, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 122},
#   {'chunk_index': 123, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 124, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 125},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 126},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 127},
#   {'chunk_index': 128, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 129},
#   {'chunk_index': 130, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 131},
#   {'chunk_index': 132, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 133, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 134, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 135},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 136},
#   {'chunk_index': 137, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 138, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 139},
#   {'chunk_index': 140, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 141},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 142},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 143},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 144},
#   {'chunk_index': 145, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 146, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 147, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 148},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 149},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 150},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 151},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 152},
#   {'chunk_index': 153, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 154, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 155},
#   {'chunk_index': 156, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 157},
#   {'chunk_index': 158, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 159},
#   {'chunk_index': 160, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 161},
#   {'chunk_index': 162, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 163, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 164, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 165},
#   {'chunk_index': 166, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 167, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 168},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 169},
#   {'chunk_index': 170, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 171, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 172},
#   {'chunk_index': 173, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 174},
#   {'chunk_index': 175, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 176, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 177, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 178, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 179},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 180},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 181},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 182},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 183},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 184},
#   {'chunk_index': 185, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 186, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 187},
#   {'chunk_index': 188, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 189, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 190, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 191, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 192, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 193, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 194},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 195},
#   {'chunk_index': 196, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 197},
#   {'chunk_index': 198, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'chunk_index': 199, 'source': 'Regulamento Poupacred 24.04.2024.pdf'},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 200},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 201},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 202},
#   {'source': 'Regulamento Poupacred 24.04.2024.pdf', 'chunk_index': 203},
#   {'chunk_index': 204, 'source': 'Regulamento Poupacred 24.04.2024.pdf'}]}

# %%
def delete_existing_chunks(source):
    existing_chunks = collection.get()["ids"]

    for chunk_id in existing_chunks:
        if chunk_id.startswith(source):
            collection.delete(ids=[chunk_id])
            print(f"Chunk {chunk_id} deletado.")

# Exemplo: Deletar apenas os chunks do documento "CONCRETO-CONSIGNADO"
#delete_existing_chunks("CONCRETO-CONSIGNADO FUNDO DE INVESTIMENTO")

# %% [markdown]
# # Implementação da RAG

# %%
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_openai import ChatOpenAI

def detect_document_mention(query, available_sources):
    for source in available_sources:
        if re.search(re.escape(source), query, re.IGNORECASE):  # Busca pelo nome do documento na pergunta
            return source
    return None  # Retorna None se nenhum documento for encontrado

# Função que pesquisa pelos documentos relevantes baseando-se no contexto da pergunta
def search_document(question, client):

    print("Pesquisando documentos relevantes...")

    query_embedding = get_embedding_openai(question, client)

    results = collection.query(
        query_embeddings= [query_embedding],
        n_results= 20
    )

    for doc, meta in zip(results["documents"][0], results["metadatas"][0]):
        print(f"\nFonte: {meta['source']} - Tipo: {meta['type']}")
        print(doc[:1000])  

def ask_llm(query, client):

    stored_data = collection.get(include=["metadatas"])
    available_sources = {meta["source"] for meta in stored_data["metadatas"]}  # Obtém nomes únicos dos documentos

    # Verifica se o usuário mencionou um documento específico
    specific_document = detect_document_mention(query, available_sources)

    # Definição do filtro para busca no ChromaDB
    search_filter = {"source": specific_document} if specific_document else None  # Filtra apenas se um documento for citado

    # Busca informações no ChromaDB
    embedding = get_embedding_openai(query, client)

    results = collection.query(
        query_embeddings=[embedding],
        n_results=20,
        where= search_filter
    )

    # Organiza os resultados agrupando por 'source' (nome do documento)
    retrieved_docs = results["documents"][0]
    metadatas = results["metadatas"][0]

    grouped_docs = {}  # Dicionário para agrupar os chunks pelo nome do documento

    for doc, meta in zip(retrieved_docs, metadatas):
        source = meta["source"]  # Nome do documento original
        if source not in grouped_docs:
            grouped_docs[source] = []
        grouped_docs[source].append(doc)  # Adiciona o chunk ao documento correspondente

    # Criar um contexto consolidado por documento
    context = "\n\n".join([
        f"🔹 Documento: {source}\n" + "\n".join(chunks)
        for source, chunks in grouped_docs.items()
    ])

    modelo = ChatOpenAI(model = "gpt-4o-mini", temperature= 0, max_tokens= 4096)

    prompt = f"""
    Você é um assistente especializado em responder perguntas sobre vários documentos PDF armazenados em um banco de dados.
    Cada documento está dividido em múltiplos IDs, diferenciando-se apenas pelo número ao final.
    Documentos cujos IDs tenham nomes diferente não possuem relação alguma um com o outro.
    Quando for dado o nome de um fundo de investimento, forneça informação contida apenas naquele chunk. Não misture informação de diferentes documentos
    Considere os seguintes documentos: 
    {context}
    
    Caso não seja mencionado nenhum nome de fundo, responda considerando **todos** os documentos mencionados acima.
    
    Cite todas as fontes utilizadas quando fornecer a informação.
    Se não for encontrado nenhum documento semelhante ao nome dado, informe.
    """
    messages=[
    SystemMessage(content= prompt),
    HumanMessage( content= query)
    ]

    answer = modelo.invoke(messages)

    return answer.content
    # return response["choices"][0]["message"]["content"]

# %% [markdown]
# # Aplicação do LLM

# %%
# question = """
# Quais são os gestores dos fundos Concreto e Concrédito II?
# """

question = """
Qual o tipo de recebível que o FIDC GVN pode comprar?
"""

print(ask_llm(question, openai_client))
# Out:
# O GVN Fundo de Investimento em Direitos Creditórios pode adquirir Direitos Creditórios representados por Cédulas de Crédito Bancário (CCB), decorrentes de operações de empréstimo realizadas entre a Cedente e os Devedores. Esses direitos são garantidos pela cessão fiduciária dos direitos que os Devedores possuem a saques-aniversário do FGTS, conforme a Lei nº 8.036/90.
#
# Fonte: Regulamento FIDC GVN (1).pdf.

# %% [markdown]
# ## Aplicação do LLM (ANTIGO)

# %%
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_openai import ChatOpenAI

modelo_antigo = ChatOpenAI(model = "gpt-4o-mini", temperature= 0, max_tokens= 4096)

prompt = """Você é um assistente de IA que responde as dúvidas dos usuários com bases nos documentos abaixo.
Os documentos abaixo apresentam as fontes atualizadas e devem ser consideradas como verdade. Sempre que uma
pergunta oferecer o nome de um FIDC, você deve procurar pela melhor correspondência deste nome na lista de documentos.
Cite a fonte quando fornecer a informação.
Documentos:
{documents}
""" #Caso o nome citado na pergunta não exista na lista de documentos, responda que ele não foi encontrado.

prompt = prompt.format(documents= documents_str)

messages=[
  SystemMessage(content= prompt),
  HumanMessage(content= question)
]

# %%
answer = modelo_antigo.invoke(messages)

# %%
answer.content
