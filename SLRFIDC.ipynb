# %% [markdown]
# # Preparação dos Documentos

# %%
import PyPDF2
import chromadb
import uuid
import os
import openai
from openai import OpenAI
from langchain_openai import OpenAIEmbeddings
from getpass import getpass

# %%
# Definição do tamanho dos blocos no ChromaDB
CHUNK_SIZE = 1000
OFFSET = 200

# Conexão com a API da OpenAI
with open('G:/Drives compartilhados/RISCO E COMPLIANCE/Relatórios de Risco/Risco/FIDCS/SCRIPTS_RISCO/Projeto IA/OPENAI_API_KEY.txt', 'r', encoding='utf-8') as file:
    openai_key = file.read()

openai_client = OpenAI(api_key= os.environ["OPENAI_API_KEY"])
# openai_client = OpenAI(api_key= openai_key)
# openai.api_key = os.getenv('OPENAI_API_KEY')

# Conexão com o cliente do banco de dados ChromaDB
chromadb_path = "G:/Drives compartilhados/RISCO E COMPLIANCE/Relatórios de Risco/Risco/FIDCS/SCRIPTS_RISCO/Projeto IA/Base ChromaDB/"
chroma_client = chromadb.PersistentClient(path= chromadb_path)
collection    = chroma_client.get_or_create_collection(name= "Regulamentos_FIDC_PLN")

# %%
# Checa todo o conteúdo inserido no ChromaDB
collection.get()
# Out:
# {'ids': ['1b7358a8-6bc9-4b35-a7dd-2b121b7ba07f',
#   '8a2a82ab-ac60-4492-b652-f9714384e507',
#   'aa052f41-cebe-466c-afd1-346a09b89890',
#   'f697d68d-2c34-4b8f-86db-56d990fc2469',
#   '50b984c2-bed3-4ba4-9104-a2030a64c2ef',
#   'e5efd7e9-4070-447d-9f98-c3b94ea80279',
#   '90bddcfd-ab88-44db-9a89-259fef839af4',
#   '646a4c08-bfb2-40d7-81fc-b98008a31d2a',
#   '2a6b0aa1-c98d-4d7c-882d-4bbc0078652b',
#   '80ea8fb4-e3c5-4aab-8ff7-d3c5119adb3d',
#   '628e8790-9297-4992-844f-4cfe9130e267',
#   'efa9a8b7-8228-4e7e-a292-e691be089d20',
#   '59336941-9a64-470c-bcdf-a825d9ce3e21',
#   'fd44754a-306e-423b-9473-c0fde5554953',
#   '238495d1-e8c7-4758-b20d-471bd1cfb8c3',
#   'a3435a08-d476-4ce2-b282-d4966edfbc9b',
#   '93a3de5f-3e27-4a8d-a9ed-65ed9da37d75',
#   'e4b8fb1f-cf67-4a9a-bd09-03a9fda1c1d4',
#   'a995eaf0-4f7b-4853-b8d2-ed0740165d4d',
#   'd14d9e37-f559-4f9c-9874-37ccba5b330d',
#   'fcc1b1c5-6348-4bfb-ab58-9b681c3054f3',
#   '8a8e4172-6630-480b-a17c-c267c5f42c6e',
#   'a26c0ec3-41d6-4242-ad98-f055bc581930',
#   'd0ac6c6d-4610-49e5-99a1-53229e787f65',
#   '03b324ea-adcd-4921-b0e4-4d81317d08e3',
#   'ab2f441e-cfcd-4b1d-b7c5-53eb4b5f94cc',
#   '378d1be7-b9ba-41a4-9d5b-c249c6867c04',
#   '2c015303-663b-4271-9849-124408aada28',
#   'b843561b-e4a1-4d30-8f47-c06a17861e3d',
#   '419cdc5f-8b42-4e1e-bfcc-3e853a8aeb4b',
#   'bdec659c-051a-4cd7-9bc8-c412c4114998',
#   'dae2cf7a-1039-411b-99b1-2505143b06dc',
#   'a4d1a5b6-ff24-472a-8328-e62a9a822053',
#   '2c444d8a-9da9-4928-ae3b-dc7b95c593d6',
#   'e079cce1-23c7-4c87-b1c6-0a531e797064',
#   '636e69bf-827c-4c4d-a390-79777c7a2485',
#   '77ab6789-aee6-4792-9ae7-e0f67201ca13',
#   '8cf88ef7-a274-441c-8bb2-bd7f861e6c6a',
#   '6d7a74c8-0b87-4412-ae95-6cea320806a9',
#   '632f303b-a0e5-43c8-abc2-6036ae780e37',
#   '4eacc76f-df8f-4bfb-ada6-feebc5754c68',
#   '3e92d2a1-4cbc-4c60-9327-a7fa5712ee89',
#   'd5184748-58b6-4213-b520-7a33d09b3856',
#   '92b720a4-7ffe-436a-b6a7-ba873bf8000a',
#   '4bc4709f-3f19-4c28-96a5-90e60a42ffb8',
#   '6f899683-0e91-473f-b793-701d3d116be1',
#   'e1f60de5-a830-4804-989b-745cf9537aef',
#   'a8e131fa-4772-4a13-bdf2-b8a45dd9dd3e',
#   '60db6d26-475c-4b31-bd53-019ba629eb22',
#   'e822c632-abe7-44da-a3d5-9e6628e1257a',
#   'f145ce24-cca7-48b0-aacb-c34c3e84e882',
#   '19a6b3a6-0eef-4333-9f6a-4f2974e01ec1',
#   '81817fb0-26eb-413d-a367-0362876f4083',
#   'ef9cf229-0fa9-4920-a374-67ccdfa4b563',
#   'a4c2292a-dfea-4675-8e7e-44a1f07973d2',
#   '56cf82c9-c5b0-4fe0-b85c-ed36961774dd',
#   '0d33df30-03b4-4ca9-aa06-916daefe1984',
#   '8432864e-be6f-4c83-8acb-eb6ea27572dc',
#   'a600229d-38d2-4dc9-b62f-f87e22b534f4',
#   '8fe31cd4-c395-4c83-98a8-1df44ddbf07f',
#   '2054774e-7186-46a1-ad3f-4f8c328436bc',
#   '00f1e9aa-4e5f-428f-9276-6a8038b3417c',
#   '03db311c-6acb-453f-bc79-702e4856c408',
#   '16b57d2e-eb44-4207-a881-c0bc0d09725a',
#   '37b4552e-d20d-4796-b03d-b1acd7c6a4f3',
#   '4bff281c-411a-455c-a4bf-c2fb2587739c',
#   'e038e0ee-defc-42a8-afb3-82d8c75dca3c',
#   '14163cd5-6b01-4262-87da-fe7cff0ea4aa',
#   '9eb006c1-7095-4480-99dd-3bb5c1b64430',
#   'bb834a6e-d3e6-465b-a261-28292897328b',
#   '4555b8af-0042-4345-b7ce-3e36e6f2233d',
#   'bf91ad84-6c22-4235-9eeb-d56a1911a546',
#   '77b8b728-dd4b-4d1a-ae84-3d2cb93611e2',
#   '107aa1f5-39f1-4303-9a2e-8830a96d53d3',
#   '82edad5b-c842-48a1-90bd-cde9db8fae2b',
#   '2c489896-3a6e-4b7b-bb94-a0e2e9553a7b',
#   'f2caa81d-6f5a-4494-b5b5-69acd1ef2715',
#   '18421233-d244-449d-941e-5cce5b4d50a3',
#   'c143a77b-4e78-44b5-8df8-0b8f5d80ab0e',
#   '8a25c35a-cf14-4efa-a172-3b8bb1e04841',
#   '4ad2533d-521a-447e-bdca-fc676ac88d40',
#   'd0a435b5-9c1a-402b-aef4-cc2cdf8b70d1',
#   '7268a15e-07c5-4a78-8e04-3bee2d9cfe9e',
#   '413f66b0-4855-451d-a63f-12b051eaac1b',
#   '9d70f196-05ed-4e16-825d-7c1ce942da3e',
#   '4deb677f-b551-49c2-b328-f7339b8f39b3',
#   '968237db-9f6a-4c55-8b0e-81e5f63c1428',
#   'e0d87e4c-9c7c-4dfd-8a3c-8598a5345a0e',
#   'fee242a0-d23b-4abf-950f-3609d8f8bca4',
#   '2be6b155-adc2-4de1-980b-9eb4086cce64',
#   '7fb34bae-096b-43ce-ba45-b24e5f2a9165',
#   '1bc56486-b80e-4b80-b088-6ad6fc09d1b5',
#   'b76a9b1b-5755-4ad2-a045-005f2295eef0',
#   'd033cd01-8d83-440f-af3b-ebda1d22fac3',
#   '0c5dbacb-f393-4bc1-801b-27c7568c4b77',
#   'a76a3ef4-e1c1-4776-9e52-4d0a7eef3c5b',
#   'a7de7c0f-8b62-4b25-be5d-eeae9377d70c',
#   '2e7e1e3a-ef9f-43e3-9aa8-7cc7c4668853',
#   'cc6eade3-9e61-4aab-88ed-cfb434a697ce',
#   '7efa86be-25e6-4ae2-8401-858cebb82c56',
#   'cf94322f-e727-4a79-8c38-f4ee90af4d8e',
#   'f289f9ec-f870-4744-8b1a-003718f15b10',
#   'be7c54c3-0690-4d22-b41f-bbdff93aa85f',
#   'ace0f165-bbba-4d92-a567-80e75c2613ea',
#   '8476529f-ff0d-411d-b8ef-bce78de0426b',
#   '0728f3db-827e-4991-8b16-6dd43ac25970',
#   '198019de-13b7-4cc9-a9ab-dd832a945a2e',
#   '03a44fe1-5329-45b7-a0ea-dbb60d11babe',
#   '1a6ccbfe-4299-4575-917c-4b3d329c69f4',
#   'eab1d44b-ef51-4b3d-a719-93c21dd58da3',
#   '760c9ce6-243b-4bbe-a575-9901e5951693',
#   '18ddbf75-f350-4c1c-aa9f-3b3d1a77bf09',
#   'b37d3dfa-9198-4f6b-9140-e1cbde73a59b',
#   '51324a35-9f16-4d25-b33f-041e1cb6ffcb',
#   '79b37240-3e0b-41d0-8ecb-cb37796d353d',
#   '724ee9b1-ffe5-4888-9f80-09d47259802c',
#   'e71aafe2-a1ba-4009-bf71-73dd761d93cc',
#   '68f96a7d-d3e7-40ed-95a4-db1bd1f73f41',
#   '323d95a6-cd9c-415a-8b49-b8b2d3ee93f2',
#   'fc4bf4fd-93ab-45f2-8d03-5ed5b83ef877',
#   '32e6079c-7282-40a5-95e6-7f41f58c4c5a',
#   '11a3af59-2a94-4990-b194-fcace875b0d2',
#   '149e1fde-dbd0-4706-a658-d0aacbff2435',
#   'b98bc7b4-5abf-4d80-b177-6b248ca7c667',
#   'aca725ea-e697-4812-8f0e-132bef2dc343',
#   'eebc4638-bfaf-45a0-a150-8c03846a9b0f',
#   '47a43624-ceaf-45df-bd10-3c611a2316f7',
#   'a408b8a6-abc8-4390-81ec-ea0c432f02ea',
#   'ef5dab73-3718-44d8-ad14-ce608ed48376',
#   '401651b7-131d-4816-bfc6-6ad3859e44d0',
#   'e8d06943-df59-4602-84ac-06addd749b3d',
#   '98c2946c-00af-4687-8fd1-0ede5eb403e0',
#   'd7d1916b-7e74-43ff-8017-3e549d5d9f91',
#   'af49219d-e7ad-4a6d-94c8-d6e8f93c7bff',
#   '76be7106-3c83-4987-8e94-3af0526cc49c',
#   'cd1e9002-93db-4fbf-9f03-dc87e3cc3f21',
#   'e5166658-94d1-4d3c-858e-bff8c6eadeaa',
#   'a4c76ddf-d75b-456d-9925-e94947e9a849',
#   'baa0604c-8204-4c6f-9c0b-ae1f3d82179a',
#   'f0d98f9f-da19-472f-b820-240ec83d755a',
#   '1d64c975-d4b0-4420-90dd-b38004b747de',
#   '1e2963db-46a5-441d-a1dc-7220acb01491',
#   '03c77abe-f5bf-4ca2-8c98-0e5ea1aa9311',
#   '73f832cc-bbf3-4c96-a0e5-9a5ceaa896f5',
#   '60c66152-1532-4e1b-b2cb-9c85b6db71b2',
#   '0f10bc87-6e99-4e52-ae62-2587b22ae776',
#   '32330729-a459-49be-aec0-05f7714836b2',
#   'd4b0cacf-55e9-4548-b89a-85ea6a73e380',
#   '8ba1f70d-490b-42e0-aa3a-8035c58a7da9',
#   '10b34bf4-82a1-4a7d-aabf-11a4c9e77248',
#   'b7177d0a-8123-41fc-a2c9-2cce7fb9b788',
#   '15163404-057f-4c43-8885-b3b98bfbea31',
#   '2cc7eebc-4ea9-4ec8-b8b3-9e5c5844ef17',
#   'f41b7861-35f0-4e7b-9797-a8013488d53d',
#   'd14c6f5e-36f8-40e7-ad69-bb79401d94cc',
#   '71509688-f6fd-4569-955b-238d38afa499',
#   '445c5774-2392-480e-9c3e-8395e1fa3bf9',
#   'de3f71bb-18ce-4a19-8ff1-fa8bc222a665',
#   '6b7f38af-9b91-450b-a5ca-1ec41f2c4c78',
#   'b8c11df5-d3c9-490b-82a8-873abc1351c5',
#   'f12fb391-c7e5-4080-81aa-0d021457512c',
#   '52133deb-6a8b-49e1-82ef-3d295f6b5787',
#   'e09cdada-2a56-4085-b247-e1f93fd2d4e6',
#   'e14df287-b92d-491f-b55c-5f1c0ca9e1ec',
#   '5c4451f3-11e2-492a-8b5b-0e2f9a634e1c',
#   '85ee021d-d097-4c02-b65d-715e9290ca06',
#   '6a317f60-f22a-47f5-8ef2-63f78271d810',
#   '1ed32008-460b-42a8-8631-10e0ddb38093',
#   'a70255df-bf19-4731-b116-30da10160792',
#   'bc6bfaa4-97b5-4e9e-a9f2-8a8542dfb768',
#   '31fb3194-56cc-45aa-aad5-36200744985e',
#   'e9fca6c3-dfc1-4046-ae03-f57cf94d3dd0',
#   '2040700f-79e7-4150-949e-8a5faa778f8d',
#   '2b4d7edc-2049-44d8-8cab-27c89d3cad61',
#   '3662a45c-fcc5-4a03-a0df-eb0cbb6ea550',
#   '64c0902d-11c5-4610-86f8-7aa7ecaa7c34',
#   'abac48b8-8429-4d05-b5d5-5552d7ebe457',
#   'af3f1c46-5391-4d61-ba8b-0bab824f1f31',
#   '4616a4b5-020f-47eb-a3e3-938621271cda',
#   '4727e3f7-ec4d-409a-acfc-ea2504fb0366',
#   'e9464235-c182-456d-86d7-eb47924e4a67',
#   'e3dc92ed-f520-4543-8bc9-8d08a884a8e2',
#   'ed8cb8c5-4c72-4162-ae88-b558e4e04ef8',
#   'ee3d01a9-cf1c-401b-ac92-c200ebbd2d51',
#   '9beb38fe-ae02-45a5-a26f-354bf43c1968',
#   '40dd559c-4d95-478f-af69-3e5a860fa4af',
#   'aadad9ee-3fa0-4f54-860a-859ce4ed357d',
#   '1792f13c-3ed9-4e24-821a-f5637cbe63fa',
#   '8f1b6dad-4a9b-413d-8d03-9e30a50067d0',
#   '2830f35f-fcf8-4016-a162-89461961d046',
#   'd1edc055-fa5d-49c6-b55d-e3b0838be578',
#   'c9dddcc2-095f-426f-a953-0d14d7e52f46',
#   '93dbbad0-498f-4df6-9480-917f5b8581b6',
#   '3d85ba37-be70-4db1-9670-4c2d255b54c7',
#   '3c793dbb-3be9-4d14-8377-6b06f40b4e44',
#   'b1d383e3-4eed-4645-ad91-7acd5c3807b5',
#   '45b7ae5b-cdf0-441a-9dc6-4a4ea01afee0',
#   '3a030edd-668e-45b2-8bed-1973f25df36f',
#   '662631e2-8478-498d-b387-826a794b51c8',
#   '3ee33d4f-d7d4-420a-931d-98881266a7ee',
#   'b2a32720-970a-4e55-809e-2820162ecd7b',
#   '4c53f8b0-3f6d-44c3-bd55-db6c959804e4',
#   'bd4f19a6-3d24-48f8-859f-abcdeecf8c94',
#   '5c261482-1de6-4cf6-906a-dbe676ebb239',
#   '73919634-c825-42d0-9709-1dd5dad61eb2',
#   'bc74fd08-cd5b-448c-bbe6-e9097e98a051',
#   '64fd3049-e84a-44f3-a6a5-044b19a4b6a1',
#   'f81e70a8-0e19-45b6-9399-9b5987aa6ac9',
#   '52ea17a2-833f-438d-b0f2-b51ddc668134',
#   '126f500d-717f-4afe-81f2-22e6b323ad36',
#   'a04278d0-4269-46fd-80ed-da1c4ddb3be9',
#   '17f991f1-1144-4e40-a9a7-ff0ae6583aea',
#   'a8e9d42b-c2e7-4ebd-8ed2-b1d57aa9b96e',
#   '47423645-25a6-4541-80f3-149136c5856b',
#   'e7e8ed99-4c9e-4a8a-bff8-cf1691b5252a',
#   '9d24d956-b310-4ff8-a155-dd402448626f',
#   '1f6d2b27-39d9-4ed6-a3d7-40f5ed0461c7',
#   '49f89baa-81db-405c-b87e-27dfa9c82fe7',
#   'c11d6d0c-1290-43ed-92cc-75fa982adfec',
#   '2cbd9ff9-9dc9-4d32-a4a5-cca2b9191dfc',
#   '3351d2ed-8b1b-4ff7-970a-9c4427850342',
#   '2a37f890-6e7e-4b80-acf8-fe61bfba8be5',
#   '51ce570e-080d-4d61-ac54-372035991f0e',
#   'b5663041-d050-4287-a2ed-5943b53ccdca',
#   '39b9d43e-0197-48f5-a4a6-4868be06ed8f',
#   '4809679e-b2bf-460b-ba1a-ccc471d5fa96',
#   'bc2fa3e5-b2e9-4efd-842a-28ee176bd55a',
#   '2c542415-6780-40d0-ab76-691786b966ba',
#   'ce842b34-6bdc-4ea9-bca1-1ac8ab0d053b',
#   '19c6e62a-c7dd-47d2-b714-f7f0a3358483',
#   'acd536d7-6175-46bb-a74c-57827a54ca48',
#   'd393a92e-2fb1-4bde-bcd7-1c621883a4fa',
#   '9545ad42-77e8-4836-974e-e3f299328558',
#   '6ca1aad7-a912-46c6-9474-4ee39d6196c7',
#   'cae44d91-51aa-4c0b-ab5b-f31b60f0df41',
#   '84d81534-ee4a-47d3-bca2-f5541c864d26',
#   '5fe59563-885d-406d-9a06-71dbfd5d0cbd',
#   'f88c4ab7-7558-486f-af0f-3dad247876c2',
#   'baba70b1-6d8d-4637-b6cd-8bb6bbdf15a4',
#   '89e93aad-b15d-4886-9c6b-552696fd3dbc',
#   'd184fe8c-6f71-4caa-a73c-ec005a1dcbe9',
#   '1347353c-c83a-4fff-973e-f56a9103d4fe',
#   '684304fc-7e49-42a3-b6a3-fd3c45d1ff5e',
#   'a758820d-9174-43c4-ac08-95eb59cafea6',
#   '38e474f6-fc27-49a6-a3ae-c09418db2b15',
#   'a1ec5b65-e97f-4623-962a-fa73993533df',
#   '6b724754-ba2d-4552-8887-709c3bd1db85',
#   'c7fd3c0f-6fc5-4180-914c-5900fa273fcb',
#   '0d2c91b3-8dde-4c5f-9316-5008580c165c',
#   '006a4bb2-2974-46a9-bec1-5ce2e27cc37b',
#   '551ee310-2ab3-4b9c-a4fa-62371003e110',
#   '3aaa6def-b721-4642-96bd-50f0753f01c0',
#   '54f0841c-6944-406b-95de-5e41e0c0921b',
#   '8677b4f0-025f-4d47-a534-5554290d672e',
#   '966e03e7-6158-4503-ab90-3d7d71a2e926',
#   '948d0357-42b9-4987-8e5a-a01cb3015c6d',
#   '48431579-5a2d-4121-a767-3c1f872f38b2',
#   'edbdc3e2-ec9c-4d54-aad0-3e6a049be269',
#   '280c14d1-4b3e-44bc-a732-7f21ff03d649',
#   '1e0a6ee7-e6a6-4c58-bcf3-e6468ca2858c',
#   '5c212386-3916-4204-9836-edf54bd3b6bf',
#   '1a6d55fa-147c-418f-9157-7e83122dbe78',
#   'c0cbf794-0af0-4df7-9e65-855234b6a2aa',
#   '3c888fe9-e850-4d0d-b8de-413ea4dc9696',
#   '30ff9727-ff83-4edc-94ce-557e69c0ca04',
#   'cc59f2d0-7651-462d-aa45-231a6363f1df',
#   '2d28eee8-0a77-4fe8-95a3-5bba214a25e4',
#   '55853304-25c2-4c6b-9916-93fd367ff9b0',
#   'f425554b-ef08-4f36-aaa7-2bfca5584cc7',
#   'ae77b7e7-a513-48f6-aeae-504dce8d2d90',
#   'e129c0da-32df-41db-ac47-e9b67cad3dc6',
#   '8c060597-91ec-4dd3-ad09-a6f0725e07ba',
#   'dc9bf1f8-8554-462d-8d35-688163bdf673',
#   'ae25e44d-1e74-4778-b68d-ed185866444c',
#   '854c34d1-32f6-4675-b141-85e45cc41bd1',
#   '0f4be45a-b1f8-4b0e-92fe-b8f0d0a8eefc',
#   'b6d0794c-bbd6-4e20-bdaf-9cb63081bc06',
#   '843b0c2c-0e01-4157-9a82-8ab34c2c0d0b',
#   '55ddba1a-ce70-431f-9f80-c3638bf30fb5',
#   'e80f410c-c782-4fff-b150-25bdf4400eeb',
#   '1fb45a3c-7a1a-47a1-86d6-f366af9d5868',
#   'cae9a17d-66c4-4491-82b0-0bfa8b949f79',
#   '920b9b24-28d6-408b-bf52-131bbda2e7c7',
#   'db25b861-ee61-4b64-80b2-ba7de8867365',
#   'b67d7a58-5dc5-4a6f-b506-bb1d4e93ffd8',
#   '322fe89a-be6c-4428-9fcc-e74512a996da',
#   'cfe236f8-13eb-40dd-837d-720b21de8717',
#   'afd29aa1-b20c-48df-bb38-02ed5921fe7a',
#   'fc99bc45-c5e9-4d80-a995-5ed886ae89e5',
#   '028e8da8-df3b-401a-8cf1-e6a8541774ac',
#   '1134eb7d-58f4-442e-b0b2-3ac3be3c4ebd',
#   '234e6a9e-945a-4948-b01a-27361c527ef8',
#   'dca23787-b7c7-4360-aa93-d1a0ea7b45da',
#   '30467f34-ffce-46d7-b189-7441fa3ad6ae',
#   'ce4d056d-8123-4b1b-bf53-7d6f3388a5bb',
#   '876a075d-3216-43b1-8f57-3c464f9c7ef8',
#   'ef22cd89-d952-4b9b-9dde-e63c3ab7d051',
#   '83e79331-bd80-48fd-8cab-c26b7c3c97b3',
#   '0086ca0a-7d43-42d8-95cc-2b5adbe3f8a6',
#   'af149577-bcb6-485e-83fa-06bc41d87933',
#   'e3e9cc9e-ab96-4a42-90ab-1f8c49f5edd8',
#   '798a9e9f-9347-4eb3-be87-f7d433a3e6c5',
#   'ad6e6545-acc8-4b0c-9f44-1e76a091f7d8',
#   '83153069-aa1e-4112-b5b1-341b658419f7',
#   'b8323f9d-145f-4326-9e98-6e1fd1ae30fd',
#   'a1f89ae2-51de-4ba6-ad9c-255f87d52c6d',
#   '2b8aee24-8b34-49ec-a94f-f2e3f9d63fb9',
#   'b750a019-e89c-4bfb-a557-e8b9b1cb9f50',
#   '3d508f0b-7a9e-4586-a095-9bfa41f1bc85',
#   '9b49a494-44af-47f8-9213-199fe8ab1f3a',
#   '702c9bbf-784f-4524-ada7-9e2ddc9d1145',
#   '9113926e-f387-44aa-902c-91a6f0929dc9',
#   '77ffd0dd-13b3-4cdb-bfb6-5fc02eb483fa',
#   'db6b517f-6761-47bf-9a40-fced3560349e',
#   '1eaf3a8a-bdd0-4d75-a7f5-4db84802dfbe',
#   '14c6aedf-cb03-4156-986d-f143348f9fb2',
#   'bddc658b-0d51-4da6-b0bc-2b9c925f65e4',
#   '7528abae-1db9-4001-a5e8-6d1ee4df8347',
#   '500ace5a-9fd0-49dc-84fc-50e02b65a4d0',
#   'e586e105-da51-4e12-9f0a-ec5146c46dda',
#   '99e29d48-5b2e-47bc-88c3-bfb486310af0',
#   'd564fdeb-bc5a-426f-9da5-07ef891672e4',
#   '552867ba-20dc-4b7f-960f-c10674bf90a1',
#   '7cd092a9-aa23-496d-a768-070b84666549',
#   'c86d1d5a-fcb9-4594-b238-6445bcacfc14',
#   '7e5e6a95-4960-4fe1-bbb5-ff1d9a2a5a6e',
#   'd99ec4cb-1f55-477f-957c-5d18e6236da7',
#   '5b000c16-26c8-43a6-94e7-aad77aa30c93',
#   '0ed88d40-d362-4b5f-8e3c-86c5b302684f',
#   '23cbad87-cf63-4dc6-baf5-0ab6439d50cf',
#   '4b8ed2aa-101b-4145-98eb-989ab2f119e1',
#   '27ddad43-404f-4e8b-8a1f-27a734ce0a76',
#   'a36472e1-6e93-4fbb-b17e-007d766c7c2c',
#   'b6e286c7-0c4b-42f2-93c9-1b3c30e96782',
#   '9157a861-af6a-4799-8a3c-5a6437bf9460',
#   'aec5ff08-61dc-411a-be5f-9a2281b784c1',
#   'fd3eca90-1254-4ab7-a20f-d3006d9b4e49',
#   '1359ad5f-3ddc-4c84-9243-196d7b3a8b0f',
#   'c792f22f-6f88-4c12-ac0e-88255dce8d2c',
#   '89877602-0782-440d-9f3c-d7b34079dbad',
#   '724c052a-c238-45b0-b482-052e50bfbfd4',
#   '5730d04e-1f1b-4f51-b26e-45bd51eaeaf7',
#   '4400ff5d-28ac-4e40-a4bb-b27be79397ca',
#   'b401d822-4c32-4374-91a9-90641473673f',
#   '86eba3fd-17d5-450e-b303-60e6804ad58d',
#   '7fe77e54-46a2-40f6-8c0c-395dd5b96a70',
#   'e7073a23-cb78-449f-aa2b-dd5a84d04a20',
#   '05c546e8-ecd0-46e8-a79a-d4355c6a9d6b',
#   'b75a8d47-16e9-4a96-a606-b4d7132b9a26',
#   'bfd5d718-c9b0-49ac-b899-3e7d1ac735aa',
#   'f173549e-c830-4505-9220-4c3f51952138',
#   '9c9f147c-5680-422f-adfa-a257fba1d387',
#   'f14a120d-6d75-4e5c-8376-ae286eb771d0',
#   '8a544294-6fd8-4504-9c46-7b284ed997cc',
#   '7f070af8-5ae1-4040-aa40-d903da3ac7ca',
#   '06737422-fc58-42c0-9af8-de58cafa0f46',
#   'ff5a1b39-f9d6-423f-9dcc-22e556cace5c',
#   '3aa13d27-2e1e-4f88-8190-6b16bc681cac',
#   'a630d526-d03d-4f94-8d2e-3d102554b8f9',
#   '7f9c1b1a-c44d-4c4e-967c-76e941fc99b5',
#   '6fa8c2f0-3f4e-4f97-88ed-234b869c0cad',
#   '66f87030-fd15-410c-b677-4ced2a8964ca',
#   'e688f096-c09b-4933-b983-fe4f6927d2d6',
#   'a3b4bd81-afdc-4b46-b116-836ddf5594e4',
#   'ed4d5662-e48a-464a-8c18-05329ff7a38f',
#   'e0269f78-6650-404b-b145-62fe6a0f0186',
#   'c75d66ac-fc1c-451f-8a05-c6c24a368922',
#   'e6e4b86a-d25f-45a5-861a-51820ba40822',
#   'a7a51225-4945-410b-a7da-e5bc6513eec2',
#   '99ddd0ca-c7f3-48d2-a3c3-dd8fb751de75',
#   '13b03add-249d-4a9d-9473-4ad2fdf70b12',
#   '4036abe3-3edf-446a-a5f9-0200c6dd2d17',
#   'a5d8ef53-4757-4556-8db5-17f3b32d4cd7',
#   '48709fc5-b54e-4373-bd59-a28b0c0e2c71',
#   'f0d7be1c-4908-43d3-a39c-d7a219285c36',
#   'fff6d4b4-9462-4bd6-affc-511c046d45c4',
#   'bf579108-c2c7-4dbf-9ad2-f068c8bb6d79',
#   '05d4abaf-de1e-4118-8148-3c473462a824',
#   'ed58cba9-4330-4d2b-b635-916cbe7d6bca',
#   'c44cd00e-1123-46c1-aeee-083dce95f93f',
#   '27ddb92f-ad72-44b8-b5c4-6c9ffd071280',
#   'eeaf4813-1676-4156-9c24-9f516a3c3e0c',
#   '79c99f07-0d46-44d5-8c6f-79592d8b87a0',
#   'd00b0eeb-6a4b-41b4-a397-9a4e7b6eb4d0',
#   '851c55e9-8555-4132-9e03-6815a4f69b80',
#   'c8159f82-0c91-45d9-9a17-2bb6e90f9be4',
#   '365d4d5b-d407-46cb-9ba0-564438616be5',
#   '17179ed5-fe03-4a01-a813-70228f16fb91',
#   '96899fa4-98a5-43bc-8985-5624d9bd7e97',
#   'cada7e32-1e4f-4f69-85be-7de56629dc57',
#   '2ae3cbbb-5360-49e7-a762-9083322bcb91',
#   '98172624-d850-47bd-966f-53eefd40b921',
#   '461e72f9-1f2b-4390-bf09-35847233418d',
#   '89be64c2-86d4-4c4a-8c81-1986d809b23c',
#   '055d75cf-2d7d-4a1c-b9cc-3680aa597b22',
#   '27ec0f8e-af91-4dea-a461-08170fea9dea',
#   '44e0f68d-aad2-4836-819c-82fcead331b8',
#   '266f45ab-aa85-42bc-9c72-2b23e44d0e27',
#   '2ff8678a-e7cb-4701-acb5-0c5b32f10190',
#   '8ba44157-f9dd-4cf6-87bf-e218ce79e19b',
#   'b0d366ba-0398-4c6f-9d82-5315cc235ec3',
#   'cc8f8bf7-ff38-4a72-b4e1-83636c6f2d95',
#   '6cd665fa-731f-4bea-b50d-f535f3d7156c',
#   '7effa3be-c555-40dd-9624-3fd160658757',
#   '2169646d-c5fd-469d-a1dd-c4f303ec52dc',
#   'deebb9ce-0035-4892-8a9a-20f0d1f8f0da',
#   '91c48a18-402e-4446-8b8a-7b51b6d3e9d1',
#   'e40bb773-103d-49a1-9446-b411282ed971',
#   '28a2515a-52e9-4cee-94fe-b26ef5884fb4',
#   'ada3acc7-04da-4efa-99a2-305bf945a857',
#   '82427da0-eacd-4834-98e0-8bb3296c2c59',
#   '3018747c-159e-42f0-802d-49917cd6a47f',
#   'ff8c4e9c-f691-4b14-82c9-3ffae9cbddf2',
#   '3eff61ab-bf6d-43e7-8846-15a76d8cccf0',
#   '33e33471-fd8c-4bf0-9454-a0f00f32a7b5',
#   'e514c83a-799b-498a-8d60-ae079cf50a4a',
#   'cf556e5c-ee06-4c65-a44b-302231370eb1',
#   '1bc4aa1e-a99a-4acc-afce-3fb6092fcc9f',
#   '2ad1c23d-1e4f-4e9f-8499-2cec0fa6f774',
#   '8eb3332b-f4e3-4a79-a3cf-12a9027abc61',
#   '54ca7dd8-8326-465b-81f2-fdb98cc9530d',
#   '60308e81-09f0-4bcb-9687-6c409dde01f8',
#   '3f3206a9-5883-4508-9207-475190e4cced',
#   '4452026f-8f68-4ee1-baf7-1daa45760ead',
#   '6200100f-df2d-4603-ba3c-90a953b77234',
#   '6c6b010e-c067-4be9-92e3-927eb037534a',
#   '4394e58b-066b-4f74-a89d-f770a5428aa1',
#   'd7c990d2-7753-4a38-a931-318b9439c458',
#   '4efc4bad-a861-4a6f-b9c0-9295f78dd261',
#   '3a80b739-d48f-4f46-a60b-5c6ea001b8b4',
#   'e85b9efc-6235-403d-9e6a-f0ff3ecfe6c8',
#   'dd776ad4-7724-4d0c-a7aa-0d865ad1da99',
#   '11950dce-1437-468e-ac9b-fd7137e2c1cc',
#   'e929acf4-9f1b-4282-8a10-c0c57cc67411',
#   '04d0da33-b747-4e15-8850-eb4d89f7d3dd',
#   '5e12c156-f9a7-4d13-a406-fecf4fe65263',
#   '3ecd8080-bbb6-4602-a9b7-535fefd0901a',
#   '3767f8b3-f205-47f0-8d77-0db654f57e01',
#   '343e6e47-6b39-464e-b7d4-189a77236206',
#   '0cbbc253-ec63-42fb-8764-ba3c39d62a0c',
#   'd066da2c-3b1c-477c-b530-57be4a86b23c',
#   'e44b19c4-c8a5-40c8-a31b-4df03e00820e',
#   '0498e97e-743c-4dd3-bef2-72e46b1391b1',
#   '07f28bf0-7e68-40f9-afe7-d4f9114b2a46',
#   '8f1edf19-94d2-4c75-97c6-da5a5734577c',
#   '258f80ca-fb80-46fc-ab32-206105490b1d',
#   '5a6f299c-4691-4f5b-b33d-cd94c882597c',
#   '71a136aa-55ad-4c20-a244-5824745b5fe4',
#   '05232c17-1b40-414d-a2b9-1f8f29b9416b',
#   '49f88f94-3d16-42ae-a73f-ef1463b01dc6',
#   'ceb66cd7-d3dc-444e-9a5e-bba623a0aa1e',
#   '996037c1-aeb3-4c98-855b-60a4560649da',
#   '57e44605-9fec-4fd6-b75f-365b9d2ff6ae',
#   'cb0d7d52-8efa-4dca-90fc-a200d36cc941',
#   'e40dbec1-8699-4c4a-8f8f-bd2d529e9339',
#   '74e45f55-450e-4393-8301-b7e42f2c787c',
#   '0a9e0390-905a-408d-9dcb-a10cb9a8e7e9',
#   '08675d4a-1f15-4e43-ac0e-f96affe00677',
#   '4240a907-3737-4b7e-a4e5-a9bc18ebcd54',
#   '05056101-2f18-4791-b225-957aba20ade2',
#   '551bfdf1-efca-4479-9499-893be6356768',
#   '91ec0e6d-fdc8-4249-8a89-9a15d326b904',
#   'e858b912-bb64-4178-a481-19bafea9c910',
#   '56aa4fab-20cc-4904-819f-9e9d767d8a9f',
#   'c7ac3a46-f4f7-4097-b8db-3bbba4372a36',
#   'ffc615ea-b7b1-4a3c-a0de-24c3782ac66a',
#   'f5070ac2-e4ce-4484-8c2c-4a79c5ac96a2',
#   '61aa7424-6e82-4579-a901-7f38fd3bac39',
#   '9029b404-5c62-4c52-bc85-7b1869cb5a67',
#   '0df126c2-7a91-4d75-88b0-2d00c1460541',
#   '270cbe44-24ad-4e12-82c7-313e156ef002',
#   '97f704ea-c3b0-4a2b-afa0-8db4cff439d2',
#   '3b4fcaff-65be-44e8-bb14-98b27fbb0c7d',
#   'e4690b17-d1d7-4cde-b689-a286c848a8fb',
#   'f30706f1-7204-4cab-ab1c-9470518fcd25',
#   '4fc4190c-c8ed-4e5d-8ea3-00276c3e9ea0',
#   '7599798d-490c-42f7-8a7a-4c9af4b064ae',
#   'e0eb4487-7926-4eb2-9b43-9ce39ff12c71',
#   'dfb3d975-ab8d-4e19-8e70-e3af99c7ae04',
#   'fedf64d1-1ba0-4688-98ce-4d82945f593e',
#   '74131588-2321-4ea7-a8f1-a058dfcbfcb6',
#   'd9c6187c-87e4-4e2f-ba46-f6ee609b529f',
#   '0605549a-85c4-4bb6-b6f1-9dd428671fde',
#   'e8ab7afe-7dfa-40fb-88ec-09388956622e',
#   '4bd3bf5e-6cc9-4d7b-8c2e-21a79fcce5c0',
#   '58dd6607-9a38-4b60-b010-ae3b018fd509',
#   '3bff6810-9493-4f96-bea6-b3c95aa8134c',
#   '2768b29e-bce3-403b-ac5b-9889c8e0d1fe',
#   '902afc25-6fe7-4f85-84d0-cef438013f23',
#   '5ba7d8b9-ca14-4a0d-a5bf-12ae4d91c9c2',
#   '2d73ec17-b931-43d3-8701-66ebc89fef6d',
#   'baad96a1-2298-4de9-8041-b214cce9c45e',
#   'e0c7e885-1bf2-46fe-b197-5ff53b70c56e',
#   '99a90058-23bb-47e0-adf2-67d636149a65',
#   '9fe1d3f2-174b-480c-a65c-db68d7e534fa',
#   '7949c757-9102-4357-a15c-7b1a189e90e2',
#   '5e23beb7-2bec-44aa-8910-3ce44322cb8e',
#   'd7f8b96f-0e72-4860-bae9-b98feca9b9ed',
#   '82adfe02-fb42-4ad3-9286-0b25ae38656b',
#   '0cc783c1-b697-405f-a288-3f525bf29381',
#   '2612ca6c-0458-4ed4-b2f1-370dd5fd9fb3',
#   'c5482bde-13c1-4a2d-b66a-207336a2d865',
#   'e937844c-6fff-478e-bade-d192e784088f',
#   '7a8d33cd-f8db-4bff-bed3-1daab19299dd',
#   '0f74c695-4aed-4748-ac5a-75e3e576076a',
#   '651c5e00-1977-41f0-9c08-aea10fcf8c08',
#   '2dfb65fb-3c5c-4546-af0d-972712760f2b',
#   '0dd8838c-ada5-440f-9c1c-832309478407',
#   '60be78bf-2d5f-48b1-a255-d9f6f2bf7d8a',
#   '970ffe7b-4d27-49c4-a6b5-5e76ad77dc1b',
#   'd885992f-89bd-4a44-ae47-b31d5a8cf2aa',
#   '5eacaf2f-6037-4a22-aa77-0af09480673f',
#   '7bd98286-0172-40aa-baae-0ca6416e4eed',
#   '591bed8c-02e6-4e9c-b123-efb669e4cc28',
#   'e0194a37-0f29-4dcf-994c-7c1936adb9dd',
#   '45b7d41b-2e4c-4db3-a22c-09c50d633a0e',
#   '86ed4274-3b0d-46e9-b930-0e85a609d63e',
#   '0420918d-972c-4b88-be8a-f20aea1258c3',
#   '606c75f3-e8f4-4c40-a0f8-76a8082d0910',
#   '7e6aad3d-907b-4015-af40-bd6c99388f28',
#   '40289274-1406-4e96-ba35-ad75b5c9e826',
#   '478d2189-896e-4b3a-aeb1-8620232f16ad',
#   '4fb51fe6-680e-4cf0-8a9a-33ee5f76d705',
#   'b873645e-8327-4fa1-b488-513db4aecf48',
#   '91ab91d5-5d27-408c-9196-b69aec426b04',
#   'ce55696f-02c0-4152-9388-dde2e5b71db2',
#   '0ccc4738-4765-4068-8216-f5a7febc4e8b',
#   'c901a941-42ba-40cc-9dd3-e2e9f49716ab',
#   'fe575e65-211f-461e-bea5-cd1b622a8111',
#   '43d5e461-42eb-4d41-b3e3-3cd9fcedb80f',
#   'ce5b7983-0dfa-4ba8-9d4b-8cc6b1632784',
#   '3ff02b37-6306-4ae2-8cfe-c751e2f77e36',
#   '01a9e0b5-813a-4bd4-8f07-1008389f013d',
#   'a8e3be5c-87c4-40b9-840b-8caf23a96899',
#   'fa17ccd6-49dd-4894-b4ae-a6f7a512741a',
#   'd4ef68c9-110c-486b-819c-8385d10e487b',
#   '5080d2cc-7772-4b39-8e4f-bd428cb72da9',
#   'e25866c3-e966-4a88-aeeb-ca47f7f67bb6',
#   'c1a467e2-e1c1-4162-a46e-a212545461aa',
#   '19f37f03-6ca7-474e-8d2e-4d07239ddf56',
#   'd3028233-8b52-46b3-8306-c8d257c24fe3',
#   '3cf08407-cb53-4aa2-9dfb-fa9797d37633',
#   'fab20aba-6d4f-40e5-b2e0-5a6ab92ef82d',
#   '6747bf0d-1656-4e6c-9e05-2dae7e34e4e3',
#   '78eac0e9-0c62-41b6-a58d-ab31b10c53f7',
#   'ef68fc2a-f758-48ae-b5e0-b138001e974c',
#   'e5feaa03-07c1-46b1-9030-af628f446023',
#   'f3f91f5a-a698-4389-918c-0b4e0666d139',
#   'e79f54a6-efa1-48e2-9eee-5bb5e7f7a045',
#   '0432a717-85c6-4cbf-8bed-91834b1d8dea',
#   'dc9622fc-b31e-4f74-a784-ebfeca0ec47c',
#   '23388ed0-fb14-445c-a4ea-b26095b59707',
#   '5032b844-91db-4f04-a0f8-6ca7a749476f',
#   '145d9d2d-d0a1-4ca0-a323-37318baa4a83',
#   '2ecce3cc-5d34-4f94-b755-8d077c5c670d',
#   '4cfaaf4e-9d46-4249-b697-43915cced7ab',
#   'a191f7f9-a409-4476-999e-e139c8c22526',
#   '699988b0-a78e-42d1-b28e-5ba5d4ec0d99',
#   '97843b53-ae6a-4320-9217-de87ea6db11a',
#   '388ea226-491e-4f44-ad4f-119b3f74bdb2',
#   '6591b54d-bcf3-4a1c-89a3-31c60ac0899c',
#   '98ebdd9a-d579-4f41-93b1-f7b7c857f5c7',
#   'c1b5fe00-5327-4d25-9bd8-716161c64699',
#   '63dcaea7-8782-423e-ab43-607151d361c5',
#   'a37a35f4-9139-4c19-922e-76f30ba1657c',
#   'e3b5b869-4e40-425c-9b26-8381a0637456',
#   'd7e69419-4744-415f-b8f4-e3f7b39132bc',
#   '170ebba9-84db-4729-bf1f-b1265753d42a',
#   '355f93e7-c7cb-4a5b-b3e5-51bc8f8881ad',
#   'a3cd64e6-2517-4a8e-b604-291de050aed5',
#   '562eeb4d-9725-49c8-8bf9-01369f3f7851',
#   '6e292be8-bffd-423c-a131-e18f895afb41',
#   '4089701e-3dd5-4b4d-a7bb-1c8265eaece5',
#   '2577cfa9-65cd-498a-a396-d6a9d3b3e9c4',
#   'a05eda63-8631-45bd-bbe3-ccf7799243fd',
#   '53d2739a-c5f7-441c-ae77-396765daf0ce',
#   'a5b9a809-283b-4921-a3f2-79226b3cef5b',
#   '35843304-c447-4288-b07e-1c631f2a9f09',
#   '78513476-8cb4-4fbc-b203-5d9ad48c9098',
#   'db97c208-c16e-46cc-b4c2-8326b6e736ff',
#   '2ad27a13-6664-44b0-819f-b4e592f6862c',
#   '181ee720-aced-4313-a7dc-c52857098498',
#   'd97cbe40-011d-4c69-8bd3-2184b6623530',
#   'db3178a3-d13a-4ecd-bc53-a9face457802',
#   '124ccb61-0ce4-400c-b93c-25325f7507de',
#   'a605b0e3-d454-461e-9260-4c673465378c',
#   '64f2209f-fdd9-43b8-9a3d-9cb14c5a4f90',
#   '589a215c-8988-4aca-92a6-e4b2fc779901',
#   '0fd61b61-e83b-47a5-880d-1e226a01a3f4',
#   '983611ee-28f2-4c91-b654-9d1b5d6f81a6',
#   'c474371f-0997-4520-9f8d-d5a97c51f90f',
#   '71eefe6c-7a51-47e8-9bf9-9c4449bd5ea1',
#   '53ef19e4-a76e-489a-8407-522a73d1c722',
#   'de5bcfb0-cc12-48c6-8c69-4dcad6753479',
#   '9f0868a9-9405-4e22-8ece-7f15574a7c7c',
#   'ee5a22a5-b035-44e3-bb67-d6b7bdf5c3ae',
#   '20761f3c-c493-4579-93cd-207fa335f3bc',
#   'b99021ca-2fd9-4f54-aeff-7285644d98b0',
#   '408d5c1c-4d53-44a3-870a-e72329ed077f',
#   '0e602f0a-df1e-490f-a9d2-77f2e01600c1',
#   '251fb599-ea31-4f32-bc01-d19147ae38e8',
#   'db321190-5fc9-4b72-83a9-bac4f98c6362',
#   'b256bc18-ac93-4443-bee8-4fdc327e578e',
#   'b1a451ae-773e-4bad-8ea0-a524d13197fa',
#   '039de918-31d1-40d5-aa2b-1509f4f9a4b4',
#   'b584e486-1927-49a6-84a2-050949789f5e',
#   'f02d6c73-7f60-454d-ad6b-b8e45b61a481',
#   'e0a7905c-7e87-4cf7-bf92-d2bebf28631c',
#   'e63b0c97-24be-495a-908a-ae407bf04da4',
#   'a6cb02ec-bb17-4097-b223-585250b9aa8f',
#   '5d7fa2b8-2649-4492-830e-4358ccf75d73',
#   'fca2cc26-c42b-41b5-a5a5-ab8b706083af',
#   '731a446c-05eb-481f-9928-fda3913e851a',
#   'a180c88f-77ce-4456-8051-1aa21cd8b5a8',
#   'b0c06693-02b5-43f6-88d1-2fc8e0424e79',
#   'd5982c44-0548-426f-b007-bfede0900ad5',
#   '1815ab78-382b-4103-a3e8-06a61c43aafc',
#   '4b490200-f115-4690-a19e-fed014544e03',
#   '8475c93c-4fd2-4260-b698-0ff7915a871e',
#   'a8fc9adf-6876-4219-83ca-a5794e286bc0',
#   '4e5ceb9b-f2b2-43c2-8ad7-1e0b37befd30',
#   '82dea8d5-039b-49e5-8b4a-defc739e5057',
#   'ec3ed0d7-bc42-476d-afce-1439d75500cb',
#   '8f37ed30-0519-4a15-94e9-d2d226ea8aea',
#   '282b70b8-ee24-453e-8617-e7829de348f5',
#   'e44f3744-6632-4fc1-afe9-bc0ee56d6b7f',
#   'b2a37b65-8515-4b7e-b487-431929cd23c5',
#   '768a60ed-1167-4f7e-b11a-df93bdf47ca5',
#   '4f526088-8fc5-4fa0-a1da-845208631f6f',
#   '438adc36-87c4-42e6-8845-f3a6b7a56670',
#   'eebba758-237a-4b09-bda3-acbadb3a7fc4',
#   '4cf26069-fd6e-4607-ab7e-cb7d133ad848',
#   '3245d6ec-7b7d-4e4f-bb9e-c736d487f458',
#   'b08c280c-082c-4890-ad4c-238f7d3ee4e9',
#   'ad94e672-8772-4224-a245-910f55095d9d',
#   'fd1d73cc-123f-46ba-ba21-33fba85887d7',
#   '4a5c444f-ea63-4c9a-890b-35915ccb308a',
#   '72784b60-a41f-42ac-885a-34c1e0382e41',
#   'd6a4c4c1-4622-4dde-aa10-f79b900dbcec',
#   '33985b67-6490-4390-8b91-fb5f66cfc7c6',
#   '0b81277a-a85f-47e8-becb-656cf7160bb1',
#   'b343d082-bc94-4040-b89c-5e7826473c9f',
#   '0ac55d13-16a1-4a7b-a559-d96fca6667b9',
#   'a268569b-9a23-47a4-9b43-698b7a9df054',
#   '0603adf5-ed60-400f-8c46-aac85ee9f30a',
#   '0c1a7532-a72d-42a5-ae6d-a0dca8f64472',
#   '90ca3d6a-6644-4c74-85fc-497e32b3ddb9',
#   '092a6463-506b-4e88-8291-f9c9998ec748',
#   'b4983192-679c-432f-a51a-058607654dbc',
#   '522d0c8e-290d-4158-a5b3-2f2d2dc14fbe',
#   'e0370581-01a2-4a6c-ada7-f18236249785',
#   '255fe83a-755e-47f2-a7e6-39e794a92685',
#   'e126505e-45c0-4209-ae26-2dfd991cd27c',
#   'bcac94b8-7ed9-4a99-8f34-c3a5ea332d96',
#   'b0202c84-171d-4414-b251-a50e86204e95',
#   '7d5b97c4-cd65-4326-b77d-a44a6d9a2ef3',
#   '41f90936-1f25-445f-9c32-c148ae1b7430',
#   'aedc3366-5c20-46c9-bc2f-efb79f33e012',
#   '4e32a713-f2d6-4a99-a0f2-ad572e61b13a',
#   'd718f10d-446e-4bc8-a349-ae470d240736',
#   '2c427cf4-f79e-475e-861c-80d302c49cba',
#   '70cb688f-fc20-4415-8b5e-bddf28d43f11',
#   'c072eec0-b020-4fdd-87ac-61360aa17278',
#   'ee908fe6-ff82-483d-bf28-bc7c9c5639b7',
#   '2f875ca3-5e49-4bf2-9aae-e36488525e51',
#   '997f5786-8386-4b96-acb9-890fb5846577',
#   '7d22d877-29fe-41db-80ca-4eb02444be4a',
#   '332080be-2460-4b8e-8231-b7f751b88099',
#   '6556eebb-32a1-44ae-a505-6b880b75cd19',
#   '184789b9-5713-43f9-bd3a-bf8b6c4fa5b8',
#   'dd91617f-effd-4deb-9cf2-8fa3047ec8b6',
#   '41ddd04c-c972-4c8b-bf30-914e548844f4',
#   'c6e08970-82e3-49ef-aa42-7c59ef35f56a',
#   '4d3ff513-2245-46da-bd00-d4ec06977288',
#   '807d5d7e-b662-46da-bc66-496ec2bc5084',
#   'f8c9ddac-b468-4432-b356-a7d6f2bab4b4',
#   '48e8f485-3eea-4a64-8476-b6ddadc52a3d',
#   '8e814281-a7ff-45ac-9a53-ae11f6977f3c',
#   '080dfeb9-127e-482f-a7bd-f53bd87a6565',
#   'f0632308-2a10-4037-af2c-f6ebaff2f340',
#   'cd679675-17ad-4cb5-9e32-2d3954e3b9de',
#   'ac0846ca-3897-46df-bc38-c510a5ef86be',
#   'f4d50e05-684b-4560-b5d0-a3aa3940a2ad',
#   'ab5cffe0-d549-4877-9873-e9fe8059c0bf',
#   'e78065f8-db92-4983-a222-02126c32e302',
#   '3f3a8bfa-e2a0-4b0d-97f8-ea293350ae77',
#   'd8cf87cc-f7ca-4b1f-a5da-31fbcc370b8f',
#   'd9d28cd9-6ec8-4204-9c0d-03e0e09bcd59',
#   '580bd271-8885-41a5-967c-815ad36ec475',
#   '7caee6ce-4f4f-4051-a194-7ef37270f74e',
#   'c8314840-de72-4020-8854-58d468cfff54',
#   '9296ca8a-072a-4f16-92b2-da743f626e62',
#   'a503cd7c-37f2-44d7-a487-dcc6a25a2f37',
#   '145fe615-d17d-42aa-a964-e7ba1b7d71c5',
#   'c00e326e-3e37-4096-b8e3-1b7a0e972c82',
#   'b969888e-cdf4-4fec-a6d3-e9078b46d4fb',
#   '8438d0df-ca55-495a-9a41-b9dca7c777bc',
#   '68874201-fad8-4c74-8c1d-6c548dbf736e',
#   '45918ba6-9f29-43cd-9305-deddc415d8f5',
#   '36d11793-ac96-4f1f-8c51-7438e255103e',
#   'ee8b8d9b-6978-46f5-86f7-0b43339c33e2',
#   '6f920024-0abc-4255-a70d-86d70fa6b188',
#   '7ed72111-230a-4460-930a-4f3655548754',
#   'c56b7e5c-809d-4ed3-954e-d1ceee389707',
#   'e7b889cb-6676-40e2-8987-9038a9f01b9f',
#   '675e6833-930e-4a1e-808e-54ac569f30e9',
#   '01e76127-8348-4b3b-ba5c-9695ac6c5582',
#   '6bc04d83-f303-4751-9e30-23666a19c19c',
#   '36676f14-8880-4d11-8c21-4484428181a0',
#   'a5d421e9-f9fd-4ee1-b57d-2391764633e0',
#   '5feb3d1a-7df2-43c9-985a-2dc439905515',
#   '9c7b03aa-4d57-4fea-a9cb-96250fc6f175',
#   'affcc526-9e54-4ec2-bc0f-bf4c06e7ac15',
#   'efa84e99-aa94-4563-9b6e-ec0010867d55',
#   '97e4b2ed-3842-4484-aa1c-6ec622a68062',
#   '8d67f068-8804-4e43-9940-2d30fd6187b3',
#   'c9a2faac-fd3f-4141-8373-3ab71b448310',
#   'b6d0d07d-63d0-4f0d-9fb8-06562bc476e5',
#   'a90aa01c-b81f-48c8-bc7d-be688b1219b5',
#   'b75903bd-b71a-4cf0-bdfd-7b59eea6f030',
#   'e1ea7430-b42e-4861-bb43-c2d9e586595d',
#   '4e1b21d8-b66f-4766-b60a-d61dc43686aa',
#   'bb972d5a-936d-470c-b595-f538a9f34ebe',
#   'b7901190-160c-45a7-b692-1966ad9e43cd',
#   '7abb693b-8a57-4d31-bf14-10b14ae6165d',
#   'a21a244b-2275-4c1a-b9a1-76d266069c39',
#   'd5f84a69-66d7-425d-8cfb-e445f711a8a4',
#   'eadc7d59-4e9d-49a2-aefc-f3d45b022cd0',
#   '20cde6fa-cec9-49fb-b084-67abb4d7bdbe',
#   '2ca44e4d-1314-4d9c-b0f8-342afd45a362',
#   '6885a7c2-5ba0-40ce-98da-c7d96e40df59',
#   '085b7588-3db5-47b6-afe5-7a83bb0a067c',
#   'b88dd587-fbf4-4062-b55c-d730cf1a7ee4',
#   'a7aa121b-d359-4976-aed9-85efecae0b19',
#   'd1c1b240-e99f-47de-a431-324fa1042c47',
#   '44bdc786-d680-4de4-a8af-fbbd4fdde0a5',
#   'ed22d5aa-958c-4ec2-9789-ca51834912cf',
#   '6b4ebe9e-ca85-4eb0-addb-e1d544f420dc',
#   '91a3beb4-ca29-42fd-914b-c54ce85c504c',
#   '41b8fe44-039b-4446-879a-4c4073919366',
#   'e2b333d8-f0aa-45ce-8eea-ba08c0a24587',
#   'ffc42ce1-7985-4a63-8fa1-4d546d384350',
#   '7444e31a-45b1-411c-9ed9-bd8208973663',
#   '65760be1-fffc-4680-91ed-04612a79cd45',
#   '8bd43edb-8ea0-46d1-86ca-677431e31df5',
#   'e0504186-9970-45dd-8aa0-a2799c28032b',
#   'eddcb758-5cf1-4d8c-9163-f404c235c2ab',
#   'dd1f8e44-2252-42d0-b95b-34d41c68f613',
#   'e55670a1-e2c8-421b-b404-e10988adc43f',
#   '0fa73479-cd5c-4cf1-90cc-0011f829ca0d',
#   '27c69c92-61ed-4cdb-b204-b0a178c78f67',
#   '8f3d9699-5f3c-4197-9b97-9bae274d9352',
#   '6c2e6df8-d7db-48de-ba98-ddc8d9655acf',
#   '6d55944f-988e-4d34-93b8-82528dd1b2c0',
#   '7c902da0-5c5a-4c89-85f8-7f4f4d1b5551',
#   'b408c197-820c-4ab8-b8c7-c539e6355854',
#   '2f715dfb-66de-4e95-9a9f-928117cb9ee5',
#   '210494c7-039c-42fe-a084-719dce293ebc',
#   '4b6a9f7d-32ac-4f6d-8b8f-8064981768da',
#   '7802ae69-b0fa-4d32-994c-d0cc5758cae9',
#   '2aefe97d-e045-4324-8a00-1c8679054c96',
#   '77549de7-00ea-42f7-854a-06f1dbcae338',
#   '2e5f5ab3-eb71-4281-bc0e-2d40020465bc',
#   '137a8b95-33a0-4e91-b742-f8fac20e1471',
#   '02a51c5d-2736-4aa3-9c86-86e02dbc555d',
#   'f27d76a2-ca06-4c10-baa7-3a04817bd65c',
#   '34dc5e27-38ec-40af-8936-3dc7ce32d3f8',
#   'dcbdbf8d-48e6-4951-9963-d65c53916742',
#   '5aa0b38c-0ddc-4d67-b22c-fb56aebafd97',
#   '18d9a882-bac2-43fd-8a10-ba552bdefb0e',
#   'c38bc930-0e5f-4ce1-a6cd-92bb76ee42a4',
#   '9c0e0624-1d0f-4484-8ebd-4f52c01b49b0',
#   '4b2ac9db-44f2-4d05-b4c0-d2ac3e8d2d63',
#   'd1e0606b-69e3-4593-8d34-c055bfbb0f98',
#   '32d5eb10-3e3a-4887-884a-50440dee4972',
#   'bb49342f-4dca-464b-9d16-2cd1e8b5d9d7',
#   '44425ccd-c57a-479a-a729-098884afd74d',
#   'e423010e-0a40-43e7-9787-164f070bdf5a',
#   '9a657cd4-2b8b-4d6c-b6c0-a68f98082ed4',
#   'cd942712-5fed-480c-a4ad-2bc7418f21a3',
#   'b16ec8f8-3755-4223-a910-ea49d1ef5821',
#   'acbf2872-e058-4959-b381-09fcec11793b',
#   '7447c056-e654-458b-85dc-b94ada0645de',
#   'eff0cea7-b5a8-4ebc-b249-8cc30ae21795',
#   '517d703f-7ce4-4625-bee6-f9de6fe7a299',
#   '0ac45eeb-4884-4870-a3e1-598ea48eeec6',
#   'f3bfd27d-837e-4624-a786-92f6c186a01f',
#   '35e853b3-a3a9-4ed8-a048-158e277144a1',
#   '77541d67-a506-45b1-83b3-5ba24dcbd7f7',
#   '578ab7f8-31bd-4543-bedd-1d21b77c1bb7',
#   '3301f0b5-92dd-40d3-9fd0-561905543e12',
#   '2875de14-bebe-4f76-81b7-9d6d1f15cd8b',
#   '208fe2d4-7e58-4783-bc4f-bca56693142e',
#   'deac31b5-68ed-4e9a-8f1c-bbad32d8e258',
#   '4837b8ae-68fd-4a89-9878-9211d8aa2566',
#   '55301959-edf5-418f-9492-7553d7bcbf26',
#   'e057cc30-4e97-455d-81ac-8b49305a6356',
#   '392a6d70-78d4-4e1e-9974-37fd6939d0c0',
#   'c5bba527-e2e0-4bfa-8dd8-778ff6bfdf1c',
#   'f3c72506-e906-4186-9d19-67246bc75c5e',
#   '7e98a261-1054-4b46-84a3-c0c3b0a3c80a',
#   '07b292a4-0d99-4204-b7e0-d7f2af4bf497',
#   '33db8432-a75d-471b-9b54-4a5873ecc69f',
#   '6522d0f1-fbd9-4635-b41e-732214dfc5f2',
#   'a019a8c0-631e-41de-9de0-d90403b27d50',
#   '76b0f6ce-ebbb-4d75-b502-f691d8af0a8b',
#   'e83c90ef-4ea1-4535-8992-fb32423bf453',
#   '37bf900c-dfca-4bd4-a91f-576abd5b068d',
#   '98313774-3dc0-4f57-a1f1-dc70f773a59c',
#   '60f3b15d-72a2-43f1-bc82-3d68ee35f385',
#   '596a3e96-5041-45f4-8315-fe0434f35446',
#   'ebd189d6-331d-4c5d-8f43-a0d5dcce270e',
#   'bd42b1b4-3e93-4623-8ca8-10d960c33b23',
#   '4563b92f-60ef-4d6a-a907-7e414d16132f',
#   '7b7abee4-bf16-4a01-ad5f-147fe0b8de79',
#   'a1977ae0-3ace-40c3-93b8-ee9c29e7ba42',
#   'ec5573f6-8052-4166-8365-c50f95d569c6',
#   '67371714-34ea-4759-8536-490562173b57',
#   '794e43e3-3caa-4d83-9717-e8f63203cdb2',
#   '58a6f4a0-e78d-4e6b-af29-720e541fa60f',
#   'bc9855cc-8571-49f0-84b8-ce4eda141b94',
#   '352f6cab-f024-4016-b902-afe4ab323ddf',
#   'a7aba5f1-94fc-4f66-99fa-3db9d3549e14',
#   'dece2f7f-1cde-4cb9-a7b3-5c459e6b8ffa',
#   '2694c045-9d17-4adf-84ec-8ebc13ec30e2',
#   'a08d41b5-333d-48e5-b164-91e2f99753d2',
#   '6b967ffa-4976-4fd6-b5c4-4ffccce37046',
#   '59ec7d98-328f-4f28-a3ce-756beaf04c49',
#   '93627813-a713-4b47-a89f-985c98d136f5',
#   'a72f447a-a402-465b-a32e-ef2524c257f0',
#   '84956690-7761-479e-ab73-68520a67fe89',
#   'a8e3763d-14f5-4d91-a37e-57e6bfaed512',
#   '56404a43-d7eb-4737-9bbd-5361c5470a07',
#   '6489d526-6f99-4b05-b505-6137a36c6bc7',
#   'd7fe21ca-99cd-49a4-ac2d-0047edff4e86',
#   '47039e58-f501-459b-80ca-eea1ead6c730',
#   '88c1e823-deb0-4413-9f26-e5957cb4d9d0',
#   'dd9ed0c6-41bc-4cd3-9f3a-8c29b89ff1f4',
#   '22ac7c38-c265-4a43-b72a-7523419c2fe2',
#   'd62afeb4-b3d9-480e-885a-6aa0e03044dd',
#   '0f514c60-3eca-4e56-96e0-b0e634beae9a',
#   '34a942f1-a27a-4c84-b7ee-f4075073dacf',
#   '2728ba0c-7997-47e9-bdf3-537ea6a530b3',
#   '09427cf1-aacc-440a-81b5-513131f3f961',
#   'b23b8b9a-04c1-4a85-aed3-784324c401e5',
#   'a9fd9ebd-3145-44b0-8eec-4fcd6acf4bd1',
#   'e25942ef-a09f-475d-b5df-420dfbc75d41',
#   'e10f4a4b-16ee-41e2-80e4-b0cd89a0c380',
#   '965088b7-0062-4259-9a22-73fc0b3f33e3',
#   'b2f72e13-3465-460e-9d8a-264a4b953bec',
#   '64698d51-4f67-480c-82f0-36f8a0b091da',
#   '58a38068-b314-4ba1-a99e-28c7c4913524',
#   '33b2f63e-0eee-4faa-b789-30e0dee246e0',
#   '95d845bf-9c44-44a4-a2ef-a9514914844c',
#   'a5ac0dac-751d-452d-bdae-408d0eceb1f0',
#   '6c99e659-f449-4872-b739-e9250e21f584',
#   'd5695f16-71f4-4f6d-8c0f-bf88c20f4948',
#   '7e684fb7-0eaf-4a29-8007-7b6ebb31d224',
#   'bbc2c7bf-c20e-4659-95f7-832cff98cac8',
#   '5fdc977f-39b4-43f2-843b-96efb452fa3a',
#   'ec32efb3-fc9d-4d26-a81f-de6289a6ea3f',
#   'f637191a-2829-4430-add2-af1b193d8e42',
#   'd7ecb7a2-1000-4285-938c-55f73222219d',
#   '752e4320-fec5-45fc-a259-802665480629',
#   'aa5cc03a-20a8-4cb4-9fc8-512bcd0607f3',
#   'fa982d0b-ea00-4910-b911-d2c3e86fd64c',
#   'fdfe0df6-f053-431c-9ab1-5f5360b63af5',
#   '08e9f657-1997-40c6-b22d-3ebe455908fe',
#   '75157fb0-bc56-455b-9f65-e6b93ecd4ef8',
#   '91c5f778-0d8e-493e-bd25-070bc28635f6',
#   'e4b2efff-a806-427e-9dde-ef09aa2af6cd',
#   'ed77034f-14ac-4722-9f0e-d56fb30e4ee6',
#   'b6b6bd25-81c9-40e8-bc7e-c78c9796dccd',
#   'ade06684-4534-4774-9057-1b8fa497897b',
#   'ba92e71f-2091-4771-a85d-9f79072e75d2',
#   '87716c44-f922-4232-a57f-f7d733cc5eb5',
#   'f35772b9-0edd-4a75-82cf-fee0422be509',
#   'cf218ca3-0826-411d-9ab5-e2cfe032a637',
#   '384f3cc9-0535-4f6e-a0dd-61e1060ddcc7',
#   'e85a1d2b-cbec-42ce-be5f-e7d22c96bfb7',
#   '426a9126-944c-4dbf-bc3d-405c16365874',
#   'd2f6a0a2-7ff9-43bc-a574-2e42901183ff',
#   '11566e67-a5b1-43ef-be33-fd658ef5497d',
#   '0e268f75-fe72-4be0-bc52-1dfa3c032345',
#   '81b45c24-61e5-4ccf-94e2-7a6d89ce8443',
#   '76b25bb3-e0c0-473d-83f3-7c5c0fb06f88',
#   '10dabdab-b0d8-451a-ba8b-60ab3a08e561',
#   '2516dcf6-b970-4574-aaf8-32e4dbcae999',
#   'b0003cf3-af9d-4466-857b-2404819c5a41',
#   'fa1d582e-4ed1-4bdc-a59c-9f2f99163306',
#   '7bec0468-d99f-4640-909a-565b20dc7d5c',
#   '2c59872a-8406-4527-8165-08742b732bfa',
#   '1a214632-0b1a-49bb-b9b7-9c65d43e678b',
#   '8af50136-f64b-4332-8e71-b18a307e5e01',
#   'caaa1210-3203-46f5-9a3f-23473ef22113',
#   '454c535f-d8ad-408e-b52f-88ec1150e621',
#   '21be32dc-c7dd-4e21-be0e-cdc3071abe42',
#   'de0c787d-9256-4433-b27f-de091ad4c5f8',
#   '5023a9ee-cf0d-42f5-bfaf-f765a47fe40a',
#   'e591c593-41c6-47cc-abd6-157ac2445ee9',
#   '941d4b97-9c07-4582-8610-4029ddb619d4',
#   '08e2ae81-0f9a-4484-9ec6-0c2d0d703818',
#   '053c2aab-b2ed-4225-84e3-bd1c658f59cc',
#   '323751fe-de78-48de-9186-43ee75f05e57',
#   'ec32efc3-7f99-4644-b2e5-08542fa252bb',
#   '25cdd697-6776-438e-98fb-c33b10aa7ffa',
#   '44c3b352-bc32-4e33-bde9-e1e722473d5c',
#   '60e5b294-111b-4bcc-812c-e77d47847886',
#   'af82656c-2c8d-4cbf-af06-2af5d2b5af11',
#   '54eee645-ff02-4f6d-bc43-5fd2db3896b8',
#   '21dafe8c-90e1-4660-835d-2c08c51942fd',
#   '11cbd278-9757-4546-9b86-b4ffa398c996',
#   '343796eb-1b17-4754-9e6c-8d8e0e4a9784',
#   'eadf155a-340d-45c9-b982-806c10671d69',
#   '513f28b5-82a1-47a4-981e-7b7e832a7bd4',
#   'd37b8622-deca-42a2-a538-944301fa5b9d',
#   '9385b70e-b832-4b54-8ff7-fc66f422c187',
#   'a92a52c7-89f8-4255-9026-e1d12f00f708',
#   'b9e17fc9-598e-4e8d-8b5b-8abd7e9f351a',
#   '5f2cfe09-1025-40b5-973f-ddd2d07a8071',
#   'db6c0400-2f10-4977-8952-4705117b2711',
#   '4aebdb1a-c526-44fe-b454-8a939842ef6c',
#   '32506fac-7cdf-4197-8082-1d65a074c5c7',
#   '0ad3c435-4c76-4522-9659-d1717cab03be',
#   'b70c74c7-925f-4ee4-8730-abb9dde39f22',
#   '9b530fdf-74ab-4701-af6a-5b8227f391ae',
#   '09da3f4c-a9b0-440a-8b61-44717a0e2f32',
#   'ae522d49-2ea9-4835-9faf-dc36149e610a',
#   '55967c29-da4b-482e-a768-6913a1b5568c',
#   'b47a970d-376b-4c55-a3f2-de5510c2b8ce',
#   '06258cfc-d64f-4867-9a4b-fd41b5b518d6',
#   '76153ccd-7ede-4402-8812-e1bb93b12ae9',
#   'b99f8b4b-d08f-40b2-9c40-f6ede3bf02e7',
#   '2766503f-34cc-45d0-804d-4da2a6eb46d1',
#   'bad2a73b-fabf-4f84-b11f-9c1d5e9e0d64',
#   'fd67cc34-5567-4e98-8b39-8b1977a96c2c',
#   '2c11d232-1f8a-4fef-9dcc-ee376947c25f',
#   '08424fa7-93bc-48fd-ace3-f31a8df03dff',
#   '811851cd-d1e7-485f-a8ef-78437ede37f5',
#   'ff3bfa18-a1e5-49c2-af69-fa205c252dd8',
#   'e3e89e82-2684-4c65-a1fa-a5f4c31fd931',
#   'a7ed067f-1dcb-47a3-8eaa-4f16cda6d9ed',
#   '263454c1-6d3a-4c88-85d0-0a5031d268d4',
#   '9d7d05f4-1da9-440d-8fe8-30cce94e0f0c',
#   'a830b400-e944-44bf-afb5-342e4cc1676a',
#   'f57ab572-1566-438a-8e1a-601167bde364',
#   '6caacb40-c238-4485-9cf6-f4d5a98edfbe',
#   '40db3b8a-6928-48e8-8d68-ae7629ac1449',
#   'b4c64e76-fc6a-4801-ade4-b2b968142a82',
#   '5c5d57b2-cfb3-4d26-a0ae-964dc59b8cdc',
#   '2b40c6e8-5b1c-40c0-9535-db5ad2112f0e',
#   '88170099-71e6-424b-9cc6-233298bf6cf6',
#   '2acd0cf7-f2dd-4e07-83c4-a7f44092ea6b',
#   'fd02f425-a1da-45e5-97d9-3ff39d4d2577',
#   '12433ecf-1730-4526-80b8-c10eff61920c',
#   '4d0d582b-0e91-4586-9627-974c72b7f34f',
#   '0308d449-0e8e-4d07-8582-003e80531f12',
#   '1604dd4b-1f3b-4408-9887-ea2b8a967a30',
#   '99d51b0c-ef2f-4ef2-89f0-ea23b1c1a625',
#   '4872e5cc-1910-4bdf-9ccb-9eac563b3cd5',
#   'c07edbe5-f7ff-49a4-8580-d6fdd804b334',
#   '2d54357c-445e-4e8e-96bf-03e6d51998e4',
#   'ee7f9809-10ef-44f1-b73e-73d004b4d6e5',
#   'b9b238d7-5306-47de-b6a8-fa5a33cb54bb',
#   '45f35896-49e6-48a2-9a4f-1bd74c9ce010',
#   '62585635-e4a8-4d3f-9a04-cebb6e39a55c',
#   '18858cb6-301a-4561-ad18-e70c9bbe2f36',
#   '7077cada-46e5-425b-ba66-3f8592857b40',
#   '9577cbb5-9d99-4db0-ab1c-0fbaa490175c',
#   'd566e475-2da5-49d9-9c4b-27097630f5f2',
#   'd65bc177-8c87-46b8-ad2c-79559ef1ca48',
#   '4f448db0-7c32-4e57-9daa-4ff0342fc1f3',
#   'c13bed7e-34b1-4a88-9f24-665e03fc8956',
#   '91842cc8-8c15-42e1-9ad9-3abd5b8cb6ed',
#   '14c3568d-59ce-4716-b046-74584cf9ccb5',
#   '6a83ee1c-29b2-4e05-88ae-7cea1f288cfc',
#   'cac7b1e8-e619-43e3-be02-c6f33802c4f2',
#   '7ca4f6f1-934b-41a2-ba45-87a5d8023660',
#   'b4dcdc92-b056-43e5-af63-ab31ac48f562',
#   '44775aaa-ae5e-4db8-9d95-8be8cc02273e',
#   '3f036a72-90b9-4b43-af8a-6c9f146ebad6',
#   '1b98d1e4-ce2d-40be-a272-1573ebfa2a73',
#   '33da6ba1-ae86-4471-8c2f-78f111934e0e',
#   '58a111dd-93aa-40de-8eb2-f8beca42930a',
#   '8703e1af-c975-4c94-9d6e-18e9600ad45c',
#   '129a3c48-56ab-45b1-8745-2537006b5588',
#   'bc37f3ae-4af8-4799-adfa-73cd4950913c',
#   '7ebd93d6-3604-4140-b7bd-3ea1686a3c99',
#   '869a7294-50b5-4f0c-a66c-c52e4e6de62e',
#   '14d58936-5c72-4e18-bb29-2126f3e09b22',
#   'f92d12fd-fa05-46c1-a51f-6925b3ec8cdc',
#   'bdec63b1-a59c-4b6f-a7e0-2f6b118371b6',
#   '71380952-7d40-4671-82e0-09a4d0d60098',
#   'eb88a6c4-c466-416d-935e-f428cb6c8994',
#   '089cb4d7-3e65-4ddd-a342-321260161c67',
#   '6fe4c006-fc71-4b58-8c2a-415fade7c281',
#   '09442a58-58c1-43fb-9512-3fe06a1baecc',
#   '5e586614-b00d-4327-9bcf-1cd34a983680',
#   '63f2c80d-376b-440d-880d-72d878474b44',
#   '05e6efb8-07e3-4e07-824e-769b32355ed7',
#   ...],
#  'embeddings': None,
#  'documents': [' \nJUR_SP - 49623760v3 - 12556002.519828   \n \n \n \n \n \n \n \n \n \n \n \nREGULAMENTO  \n \nDO \n \nHBCJ  FUNDO DE INVESTIMENTO EM DIREITOS  CREDITÓRIOS  – \nRESPONSABILIDADE LIMITADA  \n \n \n \n \n \n \n \n \n \n \n \n \n________________________  \n17 de setembro  de 2024  \n________________________  \n   \n 2 \nJUR_SP - 49623760v3 - 12556002.519828  REGULAMENTO DO  HBCJ  FUNDO DE INVESTIMENTO EM DIREITOS \nCREDITÓRIOS  – RESPONSABILIDADE LIMITADA  \n \n1. CAPÍTULO  PRIMEIRO - DEFINIÇÕES  \n \n1.1. Para  fins do disposto neste Regulamento e em seus Anexos, os termos \ne expressões iniciados em letra maiúscula neste Regulamento e/ou em seus Anexos, \nno singular ou no plural, terão os significados a eles atribuídos abaixo. Além disso, \n(a) quando exigido pelo contexto, as definições contidas neste Capítulo Primeiro aplicar -\nse-ão tanto ao singular quanto ao plural e o masculino incluirá o feminino e vice versa; \n(b) referências a qualquer documento ou outros instrumentos incluem todas as suas \nalterações, substitui ções, ',
#   'e-ão tanto ao singular quanto ao plural e o masculino incluirá o feminino e vice versa; \n(b) referências a qualquer documento ou outros instrumentos incluem todas as suas \nalterações, substitui ções, consolidações e respectivas complementações, salvo se \nexpressamente disposto em contrário; (c) referências a disposições legais serão \ninterpretadas como referências a tais disposições conforme alteradas, estendidas, \nconsolidadas ou reformuladas; (d) salvo se de outra forma expressamente estabelecido \nneste Regulamento, referências a itens ou anexos aplicam -se a itens ou anexos deste \nRegulamento; (e) todas as referências a quaisquer partes incluem seus sucessores, \nrepresentantes e cessionários autorizad os; e (f) salvo disposição em contrário, todos os \nprazos previstos neste Regulamento serão contados na forma prevista no artigo 224 do \nCódigo de Processo Civil, isto é, excluindo -se o dia do começo e incluindo -se o dia do \nvencimento.  \n \n“Administradora ” \n significa a  QI DISTRIB',
#   'UIDORA DE TÍTULOS E \nVALORES MOBILIÁRIOS LTDA ., instituição financeira \ndevidamente autorizada pela CVM para o exercício \nprofissional de administração de carteiras de valores \nmobiliários, na categoria de administrador fiduciário, nos \ntermos do Ato Declaratório CVM  nº 20.679, de 15 de \nmarço de 2023 , com sede na Cidade de São Paulo, \nEstado de São Paulo, na Rua Gilberto Sabino, nº 215 , \n14º Andar , Pinheiros , CEP 05425 -020, inscrita  no CNPJ \nsob o nº 46.955.383/0001 -52. \n \n“Agência Classificadora \nde Risco ” \n significa qualquer agência de classificação de risco \nautorizada a prestar tais serviços junto à CVM que seja \ncontratada para a classificação de risco das Cotas,  que \npoderá  ser contratada pela Gestora , em nome do Fundo .  \n \n“ANBIMA ” significa a Associação Brasileira das Entidades dos \nMercados Financeiro e de Capitais.  \n  \n 3 \nJUR_SP - 49623760v3 - 12556002.519828  “Anexo ” significa qualquer anexo a este Regulamento, os quais \nconstituem parte integrante e inse',
#   'parável do presente \nRegulamento, incluindo o Anexo Descritivo e os \nApêndices.  \n \n“Anexo Descritivo ” significa o anexo descritivo da cota classe única do \nFundo, sendo este essencial à sua constituição, o qual \nconstará anexo a este Regulamento.   \n \n“Anexo Normativo II ” significa o anexo normativo II da Resolução CVM \n175/22, conforme em vigor.  \n \n“Apêndices ” significam os apêndices integrantes do Anexo \nDescritivo,  os quais descreverão as características , os \ndireitos, assim como as condições de emissão, \nsubscrição, integralização, remuneração, amortização e \nresgate  de cada Subclasse de Cotas para a Classe \nÚnica do Fundo , e cujos anexos  dos Apêndices  \ndescreverão as condições específicas das séries de \ncada Subclasse .  \n \n“Assembleia Especial ”  significa a assembleia especial de Cotistas d e uma  \nClasse e de suas respectivas Subclasses, para a qual \nserão convocados apenas os cotistas da respectiva \nClasse e de suas respectivas Subclasses e cuja \ncompetência estará ',
#   'restrita às deliberações e matérias \nde interesse exclusivo da respectiva Classe Única e de \nsuas respectivas Subclasses, conforme o caso.  \n \n“Assembleia Geral ” significa a assembleia geral de Cotistas, para a qual \nserão convocados todos os Cotistas do Fundo, realizada \nnos termos do Capítulo Nono deste Regulamento , \nobservado o disposto no Artigo  9.1 deste Regulamento .  \n \n“Auditor Independente ” significa a empresa que prestará os serviços de auditoria \ndas demonstrações financeiras  do Fundo , devidamente \nautorizada pela CVM para exercer tal atividade . \n \n“B3” significa a  B3 S.A. – BRASIL, BOLSA, BALCÃO , \ncompanhia aberta com sede na Cidade de São Paulo,  \n 4 \nJUR_SP - 49623760v3 - 12556002.519828  Estado de São Paulo, na Praça Antônio Prado, nº  48, 7º \nandar, inscrita no CNPJ sob o nº  09.346.601/0001 -25. \n \n“BACEN ” Banco Central do Brasil.  \n \n“Classes ” \n significa a Classe Única, bem como as demais classes \nde Cotas do Fundo, as quais, nos termos da Resolução \n175/2',
# ...
#   {'partition': 110,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 111,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 112,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 113,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 114,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 115,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 116,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 117,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 118,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 119,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 120,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 121,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 122,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 123,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 124,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 125,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 126,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 127,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 128,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 129,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 130,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 131,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 132,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 133,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 134,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 135,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 136,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 137,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 138,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 139,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 140,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 141,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 142,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 143,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 144,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 145,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 146,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 147,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 148,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 149,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 150,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 151,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 152,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 153,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 154,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 155,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 156,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 157,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 158,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 159,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 160,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 161,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 162,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 163,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 164,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 165,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 166,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 167,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 168,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 169,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 170,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 171,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 172,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 173,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 174,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 175,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 176,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 177,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 178,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 179,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 180,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 181,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 182,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 183,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 184,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 185,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 186,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 187,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 188,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 189,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 190,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 191,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 192,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 193,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 194,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 195,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 196,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 197,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 198,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 199,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 200,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 201,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 202,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 203,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 204,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 205,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 206,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 207,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 208,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 209,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 210,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 211,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 212,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 213,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 214,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 215,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 216,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 217,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 218,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 219,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 220,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 221,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 222,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 223,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 224,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 225,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 226,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 227,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 228,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 229,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 230,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 231,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 232,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 233,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 234,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 235,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 236,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 237,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 238,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 239,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 240,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 241,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 242,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 243,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 244,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 245,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 246,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 247,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 248,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 249,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 250,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 251,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 252,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 253,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 254,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 255,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 256,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 257,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 258,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 259,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 260,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 261,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 262,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 263,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 264,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 265,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 266,
#    'source': 'IC LESTE PROSOLUTTI CRÉDITOS TRABALHISTAS FIDC 1.pdf'},
#   {'partition': 0, 'source': 'ICRED INSS RESP LIMITADA FIDC 1.pdf'},
#   {'partition': 1, 'source': 'ICRED INSS RESP LIMITADA FIDC 1.pdf'},
#   {'partition': 2, 'source': 'ICRED INSS RESP LIMITADA FIDC 1.pdf'},
#   {'partition': 3, 'source': 'ICRED INSS RESP LIMITADA FIDC 1.pdf'},
#   {'partition': 4, 'source': 'ICRED INSS RESP LIMITADA FIDC 1.pdf'},
#   {'partition': 5, 'source': 'ICRED INSS RESP LIMITADA FIDC 1.pdf'},
#   {'partition': 6, 'source': 'ICRED INSS RESP LIMITADA FIDC 1.pdf'},
#   {'partition': 7, 'source': 'ICRED INSS RESP LIMITADA FIDC 1.pdf'},
#   {'partition': 8, 'source': 'ICRED INSS RESP LIMITADA FIDC 1.pdf'},
#   {'partition': 9, 'source': 'ICRED INSS RESP LIMITADA FIDC 1.pdf'},
#   {'partition': 10, 'source': 'ICRED INSS RESP LIMITADA FIDC 1.pdf'},
#   {'partition': 11, 'source': 'ICRED INSS RESP LIMITADA FIDC 1.pdf'},
#   {'partition': 12, 'source': 'ICRED INSS RESP LIMITADA FIDC 1.pdf'},
#   {'partition': 13, 'source': 'ICRED INSS RESP LIMITADA FIDC 1.pdf'},
#   {'partition': 14, 'source': 'ICRED INSS RESP LIMITADA FIDC 1.pdf'},
#   {'partition': 15, 'source': 'ICRED INSS RESP LIMITADA FIDC 1.pdf'},
#   {'partition': 16, 'source': 'ICRED INSS RESP LIMITADA FIDC 1.pdf'},
#   {'partition': 17, 'source': 'ICRED INSS RESP LIMITADA FIDC 1.pdf'},
#   {'partition': 18, 'source': 'ICRED INSS RESP LIMITADA FIDC 1.pdf'},
#   {'partition': 19, 'source': 'ICRED INSS RESP LIMITADA FIDC 1.pdf'},
#   {'partition': 20, 'source': 'ICRED INSS RESP LIMITADA FIDC 1.pdf'},
#   {'partition': 21, 'source': 'ICRED INSS RESP LIMITADA FIDC 1.pdf'},
#   {'partition': 22, 'source': 'ICRED INSS RESP LIMITADA FIDC 1.pdf'},
#   ...],
#  'included': [<IncludeEnum.documents: 'documents'>,
#   <IncludeEnum.metadatas: 'metadatas'>]}

# %%
# Recebe um documento PDF e retorna seu conteúdo em uma String
def get_document(document_path):
    file = open(document_path, 'rb')
    reader = PyPDF2.PdfReader(file)

    document_text = ""
    for i in range(len(reader.pages)):
        page = reader.pages[i]
        content = page.extract_text()
        document_text += content

    len(document_text)

    return document_text

# Divide o conteúdo em String do documento em partes do tamanho CHUNK_SIZE
def split_document(document_text):
    documents = []
    for i in range(0, len(document_text), CHUNK_SIZE):
        start = i
        end = i + CHUNK_SIZE
        if start != 0:
            start = start - OFFSET
            end =  end - OFFSET
        documents.append(document_text[start: end])
    return documents

# Chamada da API OpenAI para transformação do texto em vetor utilizando text-embedding
def get_embedding(text):

    embedding = OpenAIEmbeddings(
        model= "text-embedding-ada-002",
        chunk_size= CHUNK_SIZE
    )

    emb = embedding.embed_query(text)

    return emb

# Preparação do embedding e metadados dos documentos
def prepare_documents(documents, document_name):
    embeddings = []
    metadatas = []
    for i, doc in enumerate(documents):
        embeddings.append(get_embedding(doc))
        metadatas.append({"source": document_name, "partition" : i})

    return embeddings, metadatas

# Cria uma chave primária de ID para cada documento
def create_ids(documents):
    return [uuid.uuid4() for _ in documents]

# Inserção dos dados preparados no ChromaDB
def insert_data(documents, embeddings, metadatas, ids):

    collection.add(
        embeddings= embeddings,
        documents=  documents,
        metadatas=  metadatas,
        ids= ids
    )

    print(f"Dados inseridos com sucesso! {len(documents)} Chunks")

# %%
documents = []
embeddings = []
metadatas = []

def run():
    print("Preparando Documentos...")
    data_path = 'G:/Drives compartilhados/GESTAO/_Operacional/Planilhas Gestão/Scripts/temp/temp_regulamentos'

    documents_names = [f for f in os.listdir(data_path) if f.endswith('.pdf')]
    documents_names_size = len(documents_names)

    for i, document_name in enumerate(documents_names):

        print(f"{i+1}/{documents_names_size}: {document_name}")

        document = get_document(os.path.join(data_path, document_name))
        document_chunks = split_document(document)
        document_embeddings, document_metadatas = prepare_documents(document_chunks, document_name)
        documents.extend(document_chunks)
        embeddings.extend(document_embeddings)
        metadatas.extend(document_metadatas)

    ids = create_ids(documents)
    ids = [str(uuid.uuid4()) for _ in documents]

    insert_data(documents, embeddings, metadatas, ids)

if __name__ == "__main__":
    #run()
    pass

# %%
# Checa todo o conteúdo inserido no ChromaDB
collection.get()

# %% [markdown]
# # Implementação da RAG

# %%
# Função que pesquisa pelos documentos relevantes baseando-se no contexto da pergunta
def search_document(question):

    print("Pesquisando documentos relevantes...")

    query_embedding = get_embedding(question)
    results = collection.query(
        query_embeddings= [query_embedding],
        n_results= 3
    )

    return results

# Função auxiliar que formata a lista de documentos para uma String
def format_search_result(relevant_documents):

    formatted_list = []
    for i, doc in enumerate(relevant_documents["documents"][0]):
        formatted_list.append("[{}]: {}".format(relevant_documents["metadatas"][0][i]["source"], doc))

    documents_str = "\n".join(formatted_list)

    print(documents_str)

    return documents_str

# %% [markdown]
# # Aplicação do LLM

# %%
question = """Acesse todos os documentos em sua base e pesquise quais deles incluem os seguintes termos:
'Saque aniversário', 'FGTS', 'INSS', 'Consignado', 'Saque-Aniversário FGTS'.
Retorne uma lista com todos os documentos únicos que possuírem qualquer um destes termos citados pelo menos uma vez."""

relevant_documents = search_document(question)
documents_str = format_search_result(relevant_documents)
# Out:
# Pesquisando documentos relevantes...
# [MORE 051 RESP LIMITADA FICFIDC ÚNICA 1.pdf]: AS DE FUNDOS DE
# INVESTIMENTO EM  DIREITOS CREDITÓRIOS  RESPONSABILIDADE LIMITADA
# CNPJ nº
# BTG Pactual
# SAC: 0800 772 28 27 - Ouvidoria: 0800 722 00 48 - btgpactual.com  3
#
# processo de recuperação judicial ou extrajudicial, desde que cumulativamente atend am aos seguintes
# requisitos: (a) não sejam originados por contratos mercantis de compra e venda de produtos, mercadorias e
# serviços para entrega ou prestação futura; e (b) a sociedade esteja sujeita a plano de recuperação homologado
# em juízo, independentem ente do trânsito em julgado da homologação do plano de recuperação judicial ou
# extrajudicial; e (ii) os precatórios federais, desde que cumulativamente atendam aos seguintes requisitos: a)
# não apresentem nenhuma impugnação, judicial ou não; e (b) já tenham  sido expedidos e remetidos ao Tribunal
# Regional Federal competente;
# “Documentos Comprobatórios ”: documentação  necessária  para o exercício  das prerrogativas  decorrentes
# da titularidade  dos ativos , e capaz
# [MORE 051 RESP LIMITADA FICFIDC ÚNICA 1.pdf]: mente, pelo ADMINISTRADOR;
# “Devedores ”: pessoa natural ou jurídica, ente despersonalizado ou patrimônio separado na forma da lei,
# obrigado ou coobrigado pelo pagamento dos Direitos Creditórios;
# “Dia Útil ”: é qualquer dia exceto: (i) sábados, domingos ou feriados nacionais, no Estado ou na Cidade de São
# Paulo; e (ii) aqueles sem expediente na B3;
# “Direitos Creditórios Inadimplidos ”: os Direitos Creditórios, de titularidade da Classe, vencidos e não pagos;
# “Direitos Creditórios ”: Cotas de FIDCs.
# “Direitos Creditórios Não -Padronizados ”: Direitos Creditórios que possuam ao menos uma das seguintes
# características: (a) estejam vencidos e pendentes de pagamento quando da cessão; (b) decorrentes de receitas
# públicas or iginárias ou derivadas da União, dos Estados, do Distrito Federal e dos Municípios, bem como de
# suas autarquias e fundações; (c) resultem de ações judiciais ou procedimentos arbitrais em curso, constituam
# seu objeto de litígio, tenham sido judicialmente pe
# [MOVE BRASIL FIAGRO FIDC 1.pdf]: grupo, expressas na forma percentual ao ano, base 252 (duzentos
# e cinquenta e dois) Dias Úteis, calculadas e divulgadas pela B3, no informativo
# diário disponível em  sua página na internet (www.b3.com.br);
#
# LXXXV.  “Taxa Máxima de Custódia”:  significa a taxa cobrada do Fundo, representativa do
# montante total para remuneração do Custodiante, conforme prevista neste Anexo;
#
#
#
# 67
#
#
# LXXXVI.  “Termo de Adesão”:  significa documento elaborado nos termos do artigo 29 da
# Resolução CVM 175, por meio do qual o Cotista adere a este Anexo e que deve ser
# firmado quando de seu ingresso na Classe, declarando, inclusive, sem se limitar a,
# ter pleno conhecimento dos riscos e nvolvidos na operação, inclusive da possibilidade
# de perda total do capital investido, e da ausência de classificação de risco das Cotas
# subscritas , se for o caso ;
#
# LXXXVII.  “Valor Nominal Unitário”:  significa, (i) na Data da 1ª Integralização, o valor
# individual das Cotas indicado no respectivo Apêndic

# %%
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_openai import ChatOpenAI

modelo = ChatOpenAI(model = "gpt-4o-mini", temperature= 0, max_tokens= 4096)

prompt = """Você é um assistente de IA que responde as dúvidas dos usuários com bases nos documentos abaixo.
Os documentos abaixo apresentam as fontes atualizadas e devem ser consideradas como verdade. Sempre que uma
pergunta oferecer o nome de um FIDC, você deve procurar pela melhor correspondência deste nome na lista de documentos.
Cite a fonte quando fornecer a informação.
Documentos:
{documents}
""" #Caso o nome citado na pergunta não exista na lista de documentos, responda que ele não foi encontrado.

prompt = prompt.format(documents= documents_str)

messages=[
  SystemMessage(content= prompt),
  HumanMessage(content= question)
]

# %%
answer = modelo.invoke(messages)

# %%
answer.content
# Out:
# "Com base nos documentos disponíveis, não encontrei menções aos termos 'Saque aniversário', 'FGTS', 'INSS', 'Consignado' ou 'Saque-Aniversário FGTS'. Portanto, não há documentos que incluam qualquer um desses termos."
